# %% [markdown]
# ## Parts of Speech Tagging using spaCy

# %% [markdown]
# Parts of Speech tagging is the next step of the tokenization. Once we have done tokenization, spaCy can parse and tag a given Doc. **spaCy** is pre-trained using statistical modelling. This model consists of binary data and is trained on enough examples to make predictions that generalize across the language. Example, a word following “the” in English is most likely a noun.

# %% [markdown]
# It is always challenging to find the correct **parts of speech** due to the following reasons:
#
# * Enabling machine to understand and process raw text is not easy.
# * Same word plays differently in different context of a sentence.
# * Sometime words which are completely different, tells almost the same meaning.
# * Even splitting text into useful word-like units can be difficult in many languages.
# * While it’s possible to solve some problems starting from only the raw characters, it’s usually better to use linguistic knowledge to add useful information.
# * **That’s exactly what *spaCy* is designed to do: you put in raw text, and get back a Doc object, that comes with a variety of annotations.**
#
# Reference <a href = "https://spacy.io/">spacy.io/</a>

# %% [markdown]
# In this section we'll cover **coarse POS tags (noun, verb, adjective)**,  **fine-grained tags (plural noun, past-tense verb, superlative adjective** and **Dependency Parsing**

# %% [markdown]
# ## Coarse-grained Part-of-speech Tags
# Every token is assigned a POS Tag from the following list:
#
#
# <table><tr><th>POS</th><th>DESCRIPTION</th><th>EXAMPLES</th></tr>
#
# <tr><td>ADJ</td><td>adjective</td><td>*big, old, green, incomprehensible, first*</td></tr>
# <tr><td>ADP</td><td>adposition</td><td>*in, to, during*</td></tr>
# <tr><td>ADV</td><td>adverb</td><td>*very, tomorrow, down, where, there*</td></tr>
# <tr><td>AUX</td><td>auxiliary</td><td>*is, has (done), will (do), should (do)*</td></tr>
# <tr><td>CONJ</td><td>conjunction</td><td>*and, or, but*</td></tr>
# <tr><td>CCONJ</td><td>coordinating conjunction</td><td>*and, or, but*</td></tr>
# <tr><td>DET</td><td>determiner</td><td>*a, an, the*</td></tr>
# <tr><td>INTJ</td><td>interjection</td><td>*psst, ouch, bravo, hello*</td></tr>
# <tr><td>NOUN</td><td>noun</td><td>*girl, cat, tree, air, beauty*</td></tr>
# <tr><td>NUM</td><td>numeral</td><td>*1, 2017, one, seventy-seven, IV, MMXIV*</td></tr>
# <tr><td>PART</td><td>particle</td><td>*'s, not,*</td></tr>
# <tr><td>PRON</td><td>pronoun</td><td>*I, you, he, she, myself, themselves, somebody*</td></tr>
# <tr><td>PROPN</td><td>proper noun</td><td>*Mary, John, London, NATO, HBO*</td></tr>
# <tr><td>PUNCT</td><td>punctuation</td><td>*., (, ), ?*</td></tr>
# <tr><td>SCONJ</td><td>subordinating conjunction</td><td>*if, while, that*</td></tr>
# <tr><td>SYM</td><td>symbol</td><td>*$, %, §, ©, +, −, ×, ÷, =, :), 😝*</td></tr>
# <tr><td>VERB</td><td>verb</td><td>*run, runs, running, eat, ate, eating*</td></tr>
# <tr><td>X</td><td>other</td><td>*sfpksdpsxmsa*</td></tr>
# <tr><td>SPACE</td><td>space</td></tr>

# %% [markdown]
# ___
# ## Fine-grained Part-of-speech Tags
# Tokens are subsequently given a fine-grained tag as determined by morphology:
# <table>
# <tr><th>POS</th><th>Description</th><th>Fine-grained Tag</th><th>Description</th><th>Morphology</th></tr>
# <tr><td>ADJ</td><td>adjective</td><td>AFX</td><td>affix</td><td>Hyph=yes</td></tr>
# <tr><td>ADJ</td><td></td><td>JJ</td><td>adjective</td><td>Degree=pos</td></tr>
# <tr><td>ADJ</td><td></td><td>JJR</td><td>adjective, comparative</td><td>Degree=comp</td></tr>
# <tr><td>ADJ</td><td></td><td>JJS</td><td>adjective, superlative</td><td>Degree=sup</td></tr>
# <tr><td>ADJ</td><td></td><td>PDT</td><td>predeterminer</td><td>AdjType=pdt PronType=prn</td></tr>
# <tr><td>ADJ</td><td></td><td>PRP\$</td><td>pronoun, possessive</td><td>PronType=prs Poss=yes</td></tr>
# <tr><td>ADJ</td><td></td><td>WDT</td><td>wh-determiner</td><td>PronType=int rel</td></tr>
# <tr><td>ADJ</td><td></td><td>WP\$</td><td>wh-pronoun, possessive</td><td>Poss=yes PronType=int rel</td></tr>
# <tr><td>ADP</td><td>adposition</td><td>IN</td><td>conjunction, subordinating or preposition</td><td></td></tr>
# <tr><td>ADV</td><td>adverb</td><td>EX</td><td>existential there</td><td>AdvType=ex</td></tr>
# <tr><td>ADV</td><td></td><td>RB</td><td>adverb</td><td>Degree=pos</td></tr>
# <tr><td>ADV</td><td></td><td>RBR</td><td>adverb, comparative</td><td>Degree=comp</td></tr>
# <tr><td>ADV</td><td></td><td>RBS</td><td>adverb, superlative</td><td>Degree=sup</td></tr>
# <tr><td>ADV</td><td></td><td>WRB</td><td>wh-adverb</td><td>PronType=int rel</td></tr>
# <tr><td>CONJ</td><td>conjunction</td><td>CC</td><td>conjunction, coordinating</td><td>ConjType=coor</td></tr>
# <tr><td>DET</td><td>determiner</td><td>DT</td><td>determiner</td><td></td></tr>
# <tr><td>INTJ</td><td>interjection</td><td>UH</td><td>interjection</td><td></td></tr>
# <tr><td>NOUN</td><td>noun</td><td>NN</td><td>noun, singular or mass</td><td>Number=sing</td></tr>
# <tr><td>NOUN</td><td></td><td>NNS</td><td>noun, plural</td><td>Number=plur</td></tr>
# <tr><td>NOUN</td><td></td><td>WP</td><td>wh-pronoun, personal</td><td>PronType=int rel</td></tr>
# <tr><td>NUM</td><td>numeral</td><td>CD</td><td>cardinal number</td><td>NumType=card</td></tr>
# <tr><td>PART</td><td>particle</td><td>POS</td><td>possessive ending</td><td>Poss=yes</td></tr>
# <tr><td>PART</td><td></td><td>RP</td><td>adverb, particle</td><td></td></tr>
# <tr><td>PART</td><td></td><td>TO</td><td>infinitival to</td><td>PartType=inf VerbForm=inf</td></tr>
# <tr><td>PRON</td><td>pronoun</td><td>PRP</td><td>pronoun, personal</td><td>PronType=prs</td></tr>
# <tr><td>PROPN</td><td>proper noun</td><td>NNP</td><td>noun, proper singular</td><td>NounType=prop Number=sign</td></tr>
# <tr><td>PROPN</td><td></td><td>NNPS</td><td>noun, proper plural</td><td>NounType=prop Number=plur</td></tr>
# <tr><td>PUNCT</td><td>punctuation</td><td>-LRB-</td><td>left round bracket</td><td>PunctType=brck PunctSide=ini</td></tr>
# <tr><td>PUNCT</td><td></td><td>-RRB-</td><td>right round bracket</td><td>PunctType=brck PunctSide=fin</td></tr>
# <tr><td>PUNCT</td><td></td><td>,</td><td>punctuation mark, comma</td><td>PunctType=comm</td></tr>
# <tr><td>PUNCT</td><td></td><td>:</td><td>punctuation mark, colon or ellipsis</td><td></td></tr>
# <tr><td>PUNCT</td><td></td><td>.</td><td>punctuation mark, sentence closer</td><td>PunctType=peri</td></tr>
# <tr><td>PUNCT</td><td></td><td>''</td><td>closing quotation mark</td><td>PunctType=quot PunctSide=fin</td></tr>
# <tr><td>PUNCT</td><td></td><td>""</td><td>closing quotation mark</td><td>PunctType=quot PunctSide=fin</td></tr>
# <tr><td>PUNCT</td><td></td><td>``</td><td>opening quotation mark</td><td>PunctType=quot PunctSide=ini</td></tr>
# <tr><td>PUNCT</td><td></td><td>HYPH</td><td>punctuation mark, hyphen</td><td>PunctType=dash</td></tr>
# <tr><td>PUNCT</td><td></td><td>LS</td><td>list item marker</td><td>NumType=ord</td></tr>
# <tr><td>PUNCT</td><td></td><td>NFP</td><td>superfluous punctuation</td><td></td></tr>
# <tr><td>SYM</td><td>symbol</td><td>#</td><td>symbol, number sign</td><td>SymType=numbersign</td></tr>
# <tr><td>SYM</td><td></td><td>\$</td><td>symbol, currency</td><td>SymType=currency</td></tr>
# <tr><td>SYM</td><td></td><td>SYM</td><td>symbol</td><td></td></tr>
# <tr><td>VERB</td><td>verb</td><td>BES</td><td>auxiliary "be"</td><td></td></tr>
# <tr><td>VERB</td><td></td><td>HVS</td><td>forms of "have"</td><td></td></tr>
# <tr><td>VERB</td><td></td><td>MD</td><td>verb, modal auxiliary</td><td>VerbType=mod</td></tr>
# <tr><td>VERB</td><td></td><td>VB</td><td>verb, base form</td><td>VerbForm=inf</td></tr>
# <tr><td>VERB</td><td></td><td>VBD</td><td>verb, past tense</td><td>VerbForm=fin Tense=past</td></tr>
# <tr><td>VERB</td><td></td><td>VBG</td><td>verb, gerund or present participle</td><td>VerbForm=part Tense=pres Aspect=prog</td></tr>
# <tr><td>VERB</td><td></td><td>VBN</td><td>verb, past participle</td><td>VerbForm=part Tense=past Aspect=perf</td></tr>
# <tr><td>VERB</td><td></td><td>VBP</td><td>verb, non-3rd person singular present</td><td>VerbForm=fin Tense=pres</td></tr>
# <tr><td>VERB</td><td></td><td>VBZ</td><td>verb, 3rd person singular present</td><td>VerbForm=fin Tense=pres Number=sing Person=3</td></tr>
# <tr><td>X</td><td>other</td><td>ADD</td><td>email</td><td></td></tr>
# <tr><td>X</td><td></td><td>FW</td><td>foreign word</td><td>Foreign=yes</td></tr>
# <tr><td>X</td><td></td><td>GW</td><td>additional word in multi-word expression</td><td></td></tr>
# <tr><td>X</td><td></td><td>XX</td><td>unknown</td><td></td></tr>
# <tr><td>SPACE</td><td>space</td><td>_SP</td><td>space</td><td></td></tr>
# <tr><td></td><td></td><td>NIL</td><td>missing tag</td><td></td></tr>
# </table>

# %% [markdown]
# **Now Let's understand POS with some examples**

# %%
# import spacy and load english language model
import spacy
nlp = spacy.load('pt_core_news_lg')

# %%
# Create a simple Doc object
doc_texto = '''Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.

"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.

O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei. O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País. O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.

Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida. Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.

Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal. Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.

Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto. "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura. Não vou conversar com a imprensa antes de conversar com o governo", disse.

Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado. O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.

Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.'''

doc = nlp(doc_texto)

# %% [markdown]
# ## View token tags
# Recall <a href = "https://ashutoshtripathi.com/2020/04/06/guide-to-tokenization-lemmatization-stop-words-and-phrase-matching-using-spacy/">Tokenization</a>
# We can obtain a particular token by its index position.
#
# * To view the **coarse POS** tag use `token.pos_`
# * To view the **fine-grained** tag use `token.tag_`
# * To view the description of either type of tag use `spacy.explain(tag)`
#
# <div class="alert alert-info">
# spaCy encodes all strings to hash values to reduce memory usage and improve efficiency. So to get the readable string representation of an attribute, we need to add an underscore _ to its name:
#
# Note that `token.pos` and `token.tag` return integer hash values; by adding the underscores we get the text equivalent that lives in **doc.vocab**.
# </div>

# %%
# Print the full text:
print(doc.text)
# Out:
# Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
#
# "Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
#
# O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei. O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País. O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
#
# Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida. Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
#
# Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal. Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
#
# Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto. "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura. Não vou conversar com a imprensa antes de conversar com o governo", disse.
#
# Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado. O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
#
# Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.

# %%
# Print the fifth word and associated tags:
print(doc[4].text, doc[4].pos_, doc[4].tag_, spacy.explain(doc[4].tag_))
# Out:
# mercado NOUN NOUN__Gender=Masc|Number=Sing None

# %% [markdown]
# **Applying this to the entire `doc` object**

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}')
# Out:
# Defendida  VERB       VERB__Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass None
# por        ADP        ADP        adposition
# agentes    NOUN       NOUN__Gender=Masc|Number=Plur None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# mercado    NOUN       NOUN__Gender=Masc|Number=Sing None
# financeiro ADJ        ADJ__Gender=Masc|Number=Sing None
# e          CCONJ      CCONJ      coordinating conjunction
# uma        NUM        NUM__NumType=Card None
# das        DET        ADP_DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art None
# bandeiras  NOUN       NOUN__Gender=Fem|Number=Plur None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# equipe     NOUN       NOUN__Gender=Fem|Number=Sing None
# econômica  ADJ        ADJ__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# Jair       PROPN      PROPN__Gender=Masc|Number=Sing None
# Bolsonaro  PROPN      PROPN__Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# projeto    NOUN       NOUN__Gender=Masc|Number=Sing None
# de         ADP        ADP        adposition
# autonomia  NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Banco      PROPN      PROPN__Gender=Masc|Number=Sing None
# Central    PROPN      PROPN__Number=Sing None
# (          PUNCT      PUNCT      punctuation
# BC         PROPN      PROPN__Gender=Masc|Number=Sing None
# )          PUNCT      PUNCT      punctuation
# deve       VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# avançar    VERB       VERB__VerbForm=Inf None
# na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Câmara     NOUN       NOUN__Gender=Fem|Number=Sing None
# só         ADV        ADV        adverb
# após       ADP        ADP        adposition
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# reforma    NOUN       NOUN__Gender=Fem|Number=Sing None
# tributária ADJ        ADJ__Gender=Fem|Number=Sing None
# andar      VERB       VERB__VerbForm=Inf None
# ,          PUNCT      PUNCT      punctuation
# no         ADP        ADP_PRON__Gender=Masc|Number=Sing|PronType=Dem None
# que        PRON       PRON__Gender=Masc|Number=Sing|PronType=Rel None
# depender   VERB       VERB__VerbForm=Inf None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# presidente NOUN       NOUN__Gender=Masc|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Casa       NOUN       NOUN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Rodrigo    PROPN      PROPN__Gender=Masc|Number=Sing None
# Maia       PROPN      PROPN__Number=Sing None
# (          PUNCT      PUNCT      punctuation
# DEM-RJ     PROPN      PROPN__Gender=Masc|Number=Sing None
# )          PUNCT      PUNCT      punctuation
# .          PUNCT      PUNCT      punctuation
# Para       ADP        ADP        adposition
# ele        PRON       PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs None
# ,          PUNCT      PUNCT      punctuation
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# projeto    NOUN       NOUN__Gender=Masc|Number=Sing None
# sobre      ADP        ADP        adposition
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# instituição NOUN       NOUN__Gender=Fem|Number=Sing None
# presidida  VERB       VERB__Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass None
# por        ADP        ADP        adposition
# Roberto    PROPN      PROPN__Gender=Masc|Number=Sing None
# Campos     PROPN      PROPN__Number=Sing None
# Neto       PROPN      PROPN__Number=Sing None
# não        ADV        ADV__Polarity=Neg None
# é          AUX        AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# urgente    ADJ        ADJ__Gender=Masc|Number=Sing None
# no         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# curto      ADJ        ADJ__Gender=Masc|Number=Sing None
# prazo      NOUN       NOUN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# "          PUNCT      PUNCT      punctuation
# Aceito     VERB       VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin None
# votar      VERB       VERB__Mood=Sub|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin None
# autonomia  NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Banco      PROPN      PROPN__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# aceito     VERB       VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin None
# ,          PUNCT      PUNCT      punctuation
# é          AUX        AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# claro      ADJ        ADJ__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# votar      VERB       VERB__VerbForm=Inf None
# os         DET        DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# depósitos  NOUN       NOUN__Gender=Masc|Number=Plur None
# voluntários ADJ        ADJ__Gender=Masc|Number=Plur None
# ,          PUNCT      PUNCT      punctuation
# mas        CCONJ      CCONJ      coordinating conjunction
# aí         ADV        ADV        adverb
# temos      VERB       VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin None
# que        SCONJ      SCONJ      subordinating conjunction
# organizar  VERB       VERB__VerbForm=Inf None
# melhor     ADV        ADV        adverb
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# pauta      NOUN       NOUN__Gender=Fem|Number=Sing None
# até        ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# fim        NOUN       NOUN__Gender=Masc|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# ano        NOUN       NOUN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# É          AUX        AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# só         ADV        ADV        adverb
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# ter        VERB       VERB__VerbForm=Inf None
# boa        ADJ        ADJ__Gender=Fem|Number=Sing None
# vontade    NOUN       NOUN__Gender=Fem|Number=Sing None
# na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# reforma    NOUN       NOUN__Gender=Fem|Number=Sing None
# tributária ADJ        ADJ__Gender=Fem|Number=Sing None
# "          PUNCT      PUNCT      punctuation
# ,          PUNCT      PUNCT      punctuation
# disse      VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# Maia       PROPN      PROPN__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# ao         SCONJ      SCONJ_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# participar VERB       VERB__VerbForm=Inf None
# de         ADP        ADP        adposition
# evento     NOUN       NOUN__Gender=Masc|Number=Sing None
# organizado VERB       VERB__Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass None
# pelo       DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Itaú       PROPN      PROPN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# "          PUNCT      PUNCT      punctuation
# A          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# reforma    NOUN       NOUN__Gender=Fem|Number=Sing None
# tributária ADJ        ADJ__Gender=Fem|Number=Sing None
# tem        VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# importância NOUN       NOUN__Gender=Fem|Number=Sing None
# muito      ADV        ADV        adverb
# maior      ADJ        ADJ__Gender=Fem|Number=Sing None
# que        PRON       PRON__Gender=Fem|Number=Sing|PronType=Rel None
# autonomia  NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Banco      PROPN      PROPN__Gender=Masc|Number=Sing None
# Central    PROPN      PROPN__Number=Sing None
# "          PROPN      PROPN__Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# comentou   VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# O          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# projeto    NOUN       NOUN__Gender=Masc|Number=Sing None
# de         ADP        ADP        adposition
# autonomia  NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# BC         PROPN      PROPN__Gender=Masc|Number=Sing None
# foi        AUX        AUX__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# aprovado   VERB       VERB__Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass None
# na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# terça-feira NOUN       NOUN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# 3          NUM        NUM__NumType=Card None
# ,          PUNCT      PUNCT      punctuation
# pelo       DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Senado     NOUN       NOUN__Gender=Masc|Number=Sing None
# e          CCONJ      CCONJ      coordinating conjunction
# agora      ADV        ADV        adverb
# precisa    VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# aval       NOUN       NOUN__Gender=Masc|Number=Sing None
# dos        ADP        ADP_DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# deputados  NOUN       NOUN__Gender=Masc|Number=Plur None
# para       SCONJ      SCONJ      subordinating conjunction
# virar      VERB       VERB__VerbForm=Inf None
# lei        NOUN       NOUN__Gender=Fem|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# O          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# texto      NOUN       NOUN__Gender=Masc|Number=Sing None
# mantém     VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# controle   NOUN       NOUN__Gender=Masc|Number=Sing None
# dos        ADP        ADP_DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# preços     NOUN       NOUN__Gender=Masc|Number=Plur None
# como       ADP        ADP        adposition
# objetivo   NOUN       NOUN__Gender=Masc|Number=Sing None
# central    ADJ        ADJ__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# mas        CCONJ      CCONJ      coordinating conjunction
# inclui     VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# ainda      ADV        ADV        adverb
# duas       NUM        NUM__NumType=Card None
# novas      ADJ        ADJ__Gender=Fem|Number=Plur None
# metas      NOUN       NOUN__Gender=Fem|Number=Plur None
# acessórias ADJ        ADJ__Gender=Fem|Number=Plur None
# ,          PUNCT      PUNCT      punctuation
# sem        ADP        ADP        adposition
# prejuízo   NOUN       NOUN__Gender=Masc|Number=Sing None
# à          DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# principal  NOUN       NOUN__Gender=Fem|Number=Sing None
# :          PUNCT      PUNCT      punctuation
# suavizar   VERB       VERB__VerbForm=Inf None
# as         DET        DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art None
# flutuações NOUN       NOUN__Gender=Fem|Number=Plur None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# nível      NOUN       NOUN__Gender=Masc|Number=Sing None
# de         ADP        ADP        adposition
# atividade  NOUN       NOUN__Gender=Fem|Number=Sing None
# econômica  ADJ        ADJ__Gender=Fem|Number=Sing None
# e          CCONJ      CCONJ      coordinating conjunction
# fomentar   VERB       VERB__VerbForm=Inf None
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# pleno      ADJ        ADJ__Gender=Masc|Number=Sing None
# emprego    NOUN       NOUN__Gender=Masc|Number=Sing None
# no         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# País       NOUN       NOUN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# O          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# concordou  VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# com        ADP        ADP        adposition
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# redação    NOUN       NOUN__Gender=Fem|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# proposta   NOUN       NOUN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# apesar     ADV        ADV        adverb
# de         ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# BC         PROPN      PROPN__Gender=Masc|Number=Sing None
# ser        AUX        AUX__Number=Sing|Person=3|VerbForm=Inf None
# historicamente ADV        ADV        adverb
# contrário  ADV        ADV        adverb
# a          SCONJ      SCONJ      subordinating conjunction
# ampliar    VERB       VERB__VerbForm=Inf None
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# escopo     NOUN       NOUN__Gender=Masc|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# atuação    NOUN       NOUN__Gender=Fem|Number=Sing None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# Maia       PROPN      PROPN__Gender=Masc|Number=Sing None
# já         ADV        ADV        adverb
# reclamou   VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# outras     DET        DET__Gender=Fem|Number=Plur|PronType=Ind None
# vezes      NOUN       NOUN__Gender=Fem|Number=Plur None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# falta      NOUN       NOUN__Gender=Fem|Number=Sing None
# de         ADP        ADP        adposition
# empenho    NOUN       NOUN__Gender=Masc|Number=Sing None
# e          CCONJ      CCONJ      coordinating conjunction
# atuação    NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# para       SCONJ      SCONJ      subordinating conjunction
# se         PRON       PRON__Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs None
# aprovar    VERB       VERB__Number=Sing|Person=3|VerbForm=Inf None
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# medida     NOUN       NOUN__Gender=Fem|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# Na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# semana     NOUN       NOUN__Gender=Fem|Number=Sing None
# passada    ADJ        ADJ__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# acusou     VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# presidente NOUN       NOUN__Gender=Masc|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Banco      PROPN      PROPN__Gender=Masc|Number=Sing None
# Central    PROPN      PROPN__Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Roberto    PROPN      PROPN__Gender=Masc|Number=Sing None
# Campos     PROPN      PROPN__Number=Sing None
# Neto       PROPN      PROPN__Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# de         SCONJ      SCONJ      subordinating conjunction
# ter        AUX        AUX__VerbForm=Inf None
# vazado     VERB       VERB__VerbForm=Part None
# informações NOUN       NOUN__Gender=Fem|Number=Plur None
# sobre      ADP        ADP        adposition
# conversa   NOUN       NOUN__Gender=Fem|Number=Sing None
# que        SCONJ      SCONJ      subordinating conjunction
# os         DET        DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# dois       NUM        NUM__NumType=Card None
# tiveram    VERB       VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin None
# no         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# dia        NOUN       NOUN__Gender=Masc|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# decisão    NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Comitê     PROPN      PROPN__Gender=Masc|Number=Sing None
# de         ADP        ADP        adposition
# Política   PROPN      PROPN__Number=Sing None
# Monetária  PROPN      PROPN__Number=Sing None
# (          PUNCT      PUNCT      punctuation
# Copom      PROPN      PROPN__Gender=Masc|Number=Sing None
# )          PUNCT      PUNCT      punctuation
# ,          PUNCT      PUNCT      punctuation
# que        PRON       PRON__Gender=Masc|Number=Sing|PronType=Rel None
# manteve    VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# taxa       NOUN       NOUN__Gender=Fem|Number=Sing None
# Selic      PROPN      PROPN__Gender=Fem|Number=Sing None
# em         ADP        ADP        adposition
# 2          NUM        NUM__NumType=Card None
# %          SYM        SYM        symbol
# ao         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# ano        NOUN       NOUN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# Ao         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# jornal     NOUN       NOUN__Gender=Masc|Number=Sing None
# O          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Estado     NOUN       NOUN__Gender=Masc|Number=Sing None
# de         ADP        ADP        adposition
# S.         PROPN      PROPN__Gender=Masc|Number=Sing None
# Paulo      PROPN      PROPN__Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Maia       PROPN      PROPN__Gender=Masc|Number=Sing None
# criticou   VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# articulação NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# presidente NOUN       NOUN__Gender=Masc|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# BC         PROPN      PROPN__Gender=Masc|Number=Sing None
# em         SCONJ      SCONJ      subordinating conjunction
# alertar    VERB       VERB__VerbForm=Inf None
# sobre      ADP        ADP        adposition
# os         DET        DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# reflexos   NOUN       NOUN__Gender=Masc|Number=Plur None
# para       ADP        ADP        adposition
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# economia   NOUN       NOUN__Gender=Fem|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# dificuldade NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Congresso  NOUN       NOUN__Gender=Masc|Number=Sing None
# em         SCONJ      SCONJ      subordinating conjunction
# avançar    VERB       VERB__VerbForm=Inf None
# com        ADP        ADP        adposition
# as         DET        DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art None
# votações   NOUN       NOUN__Gender=Fem|Number=Plur None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# pauta      NOUN       NOUN__Gender=Fem|Number=Sing None
# de         ADP        ADP        adposition
# ajuste     NOUN       NOUN__Gender=Masc|Number=Sing None
# fiscal     ADJ        ADJ__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# Segundo    ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# presidente NOUN       NOUN__Gender=Masc|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Câmara     NOUN       NOUN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Campos     PROPN      PROPN__Gender=Masc|Number=Sing None
# Neto       PROPN      PROPN__Number=Sing None
# tentou     VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# fazer      VERB       VERB__VerbForm=Inf None
# uma        DET        DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art None
# articulação NOUN       NOUN__Gender=Fem|Number=Sing None
# política   ADJ        ADJ__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# sem        SCONJ      SCONJ      subordinating conjunction
# combinar   VERB       VERB__VerbForm=Inf None
# ,          PUNCT      PUNCT      punctuation
# o          PRON       PRON__Gender=Masc|Number=Sing|PronType=Dem None
# que        PRON       PRON__Gender=Masc|Number=Sing|PronType=Rel None
# não        ADV        ADV__Polarity=Neg None
# seria      AUX        AUX__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin None
# papel      NOUN       NOUN__Gender=Masc|Number=Sing None
# dele       ADP        ADP_PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs None
# ,          PUNCT      PUNCT      punctuation
# mas        CCONJ      CCONJ      coordinating conjunction
# dos        ADP        ADP_DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# ministros  NOUN       NOUN__Gender=Masc|Number=Plur None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Economia   PROPN      PROPN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Paulo      PROPN      PROPN__Gender=Masc|Number=Sing None
# Guedes     PROPN      PROPN__Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# e          CCONJ      CCONJ      coordinating conjunction
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# articulação NOUN       NOUN__Gender=Fem|Number=Sing None
# política   ADJ        ADJ__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Luiz       PROPN      PROPN__Gender=Masc|Number=Sing None
# Eduardo    PROPN      PROPN__Number=Sing None
# Ramos      PROPN      PROPN__Number=Sing None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# Nesta      ADP        ADP_DET__Gender=Fem|Number=Sing|PronType=Dem None
# sexta-feira NOUN       NOUN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# presidente NOUN       NOUN__Gender=Masc|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Câmara     NOUN       NOUN__Gender=Fem|Number=Sing None
# lembrou    VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# que        SCONJ      SCONJ      subordinating conjunction
# havia      VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin None
# uma        DET        DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art None
# proposta   NOUN       NOUN__Gender=Fem|Number=Sing None
# de         ADP        ADP        adposition
# autonomia  NOUN       NOUN__Gender=Fem|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# BC         PROPN      PROPN__Gender=Masc|Number=Sing None
# semelhante ADJ        ADJ__Gender=Masc|Number=Sing None
# na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Câmara     PROPN      PROPN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# mas        CCONJ      CCONJ      coordinating conjunction
# que        PRON       PRON__Gender=Masc|Number=Sing|PronType=Rel None
# não        ADV        ADV__Polarity=Neg None
# foi        AUX        AUX__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# votada     VERB       VERB__Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass None
# ,          PUNCT      PUNCT      punctuation
# e          CCONJ      CCONJ      coordinating conjunction
# disse      VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# que        SCONJ      SCONJ      subordinating conjunction
# não        ADV        ADV__Polarity=Neg None
# comentou   VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# até        ADP        ADP        adposition
# agora      ADV        ADV        adverb
# sobre      ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# tema       NOUN       NOUN__Gender=Masc|Number=Sing None
# porque     SCONJ      SCONJ      subordinating conjunction
# não        ADV        ADV__Polarity=Neg None
# foi        AUX        AUX__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# procurado  VERB       VERB__Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass None
# pelo       DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# para       SCONJ      SCONJ      subordinating conjunction
# falar      VERB       VERB__VerbForm=Inf None
# sobre      ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# assunto    NOUN       NOUN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# "          PUNCT      PUNCT      punctuation
# Se         SCONJ      SCONJ      subordinating conjunction
# eu         PRON       PRON__Case=Nom|Gender=Unsp|Number=Sing|Person=1|PronType=Prs None
# conseguisse VERB       VERB__Mood=Sub|Number=Sing|Person=1|Tense=Imp|VerbForm=Fin None
# conversar  VERB       VERB__VerbForm=Inf None
# com        ADP        ADP        adposition
# alguém     PRON       PRON__Gender=Masc|Number=Sing|PronType=Ind None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# eu         PRON       PRON__Case=Nom|Gender=Fem|Number=Sing|Person=1|PronType=Prs None
# poderia    VERB       VERB__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin None
# te         PRON       PRON__Case=Dat|Gender=Masc|Number=Sing|Person=3|PronType=Prs None
# responder  VERB       VERB__VerbForm=Inf None
# ,          PUNCT      PUNCT      punctuation
# mas        CCONJ      CCONJ      coordinating conjunction
# ninguém    PRON       PRON__Gender=Masc|Number=Sing|PronType=Ind None
# me         PRON       PRON__Case=Acc|Gender=Unsp|Number=Sing|Person=1|PronType=Prs None
# procura    VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# .          PUNCT      PUNCT      punctuation
# Não        ADV        ADV__Polarity=Neg None
# vou        AUX        AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin None
# conversar  VERB       VERB__VerbForm=Inf None
# com        ADP        ADP        adposition
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# imprensa   NOUN       NOUN__Gender=Fem|Number=Sing None
# antes      ADV        ADV        adverb
# de         ADP        ADP        adposition
# conversar  VERB       VERB__VerbForm=Inf None
# com        ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# governo    NOUN       NOUN__Gender=Masc|Number=Sing None
# "          PUNCT      PUNCT      punctuation
# ,          PUNCT      PUNCT      punctuation
# disse      VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# Como       ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Broadcast  PROPN      PROPN__Gender=Masc|Number=Sing None
# (          PUNCT      PUNCT      punctuation
# sistema    NOUN       NOUN__Gender=Masc|Number=Sing None
# de         ADP        ADP        adposition
# notícias   NOUN       NOUN__Gender=Fem|Number=Plur None
# em         ADP        ADP        adposition
# tempo      NOUN       NOUN__Gender=Masc|Number=Sing None
# real       ADJ        ADJ__Gender=Masc|Number=Sing None
# do         DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Grupo      PROPN      PROPN__Gender=Masc|Number=Sing None
# Estado     PROPN      PROPN__Number=Sing None
# )          PUNCT      PUNCT      punctuation
# mostrou    VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# quinta-feira NOUN       NOUN__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# deputados  NOUN       NOUN__Gender=Masc|Number=Plur None
# já         ADV        ADV        adverb
# se         PRON       PRON__Case=Acc|Gender=Masc|Number=Plur|Person=3|PronType=Prs None
# articulam  VERB       VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin None
# na         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Câmara     NOUN       NOUN__Gender=Fem|Number=Sing None
# para       SCONJ      SCONJ      subordinating conjunction
# modificar  VERB       VERB__VerbForm=Inf None
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# projeto    NOUN       NOUN__Gender=Masc|Number=Sing None
# aprovado   VERB       VERB__Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass None
# pelo       DET        ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Senado     NOUN       NOUN__Gender=Masc|Number=Sing None
# .          PUNCT      PUNCT      punctuation
# O          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# partido    NOUN       NOUN__Gender=Masc|Number=Sing None
# Novo       ADJ        ADJ__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# por        ADP        ADP        adposition
# exemplo    NOUN       NOUN__Gender=Masc|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# quer       VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# enxugar    VERB       VERB__VerbForm=Inf None
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# proposta   NOUN       NOUN__Gender=Fem|Number=Sing None
# que        PRON       PRON__Gender=Fem|Number=Sing|PronType=Rel None
# recebeu    VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# aval       NOUN       NOUN__Gender=Masc|Number=Sing None
# dos        ADP        ADP_DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# senadores  NOUN       NOUN__Gender=Masc|Number=Plur None
# para       SCONJ      SCONJ      subordinating conjunction
# reduzir    VERB       VERB__VerbForm=Inf None
# os         DET        DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art None
# chamados   ADJ        ADJ__Gender=Masc|Number=Plur None
# acessórios NOUN       NOUN__Gender=Masc|Number=Plur None
# que        PRON       PRON__Gender=Masc|Number=Plur|PronType=Rel None
# foram      AUX        AUX__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin None
# colocados  VERB       VERB__Gender=Masc|Number=Plur|VerbForm=Part|Voice=Pass None
# para       ADP        ADP        adposition
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# Banco      PROPN      PROPN__Gender=Masc|Number=Sing None
# Central    PROPN      PROPN__Number=Sing None
# .          PUNCT      PUNCT      punctuation
#
#
#          SPACE      _SP        None
# Sobre      ADP        ADP        adposition
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# reforma    NOUN       NOUN__Gender=Fem|Number=Sing None
# tributária ADJ        ADJ__Gender=Fem|Number=Sing None
# ,          PUNCT      PUNCT      punctuation
# Maia       PROPN      PROPN__Gender=Masc|Number=Sing None
# deu        VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin None
# sinais     NOUN       NOUN__Gender=Masc|Number=Plur None
# de         SCONJ      SCONJ      subordinating conjunction
# que        SCONJ      SCONJ      subordinating conjunction
# quer       VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# aprovar    VERB       VERB__VerbForm=Inf None
# o          DET        DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art None
# projeto    NOUN       NOUN__Gender=Masc|Number=Sing None
# antes      ADV        ADV        adverb
# de         ADP        ADP        adposition
# deixar     VERB       VERB__VerbForm=Inf None
# a          DET        DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# presidência NOUN       NOUN__Gender=Fem|Number=Sing None
# da         DET        ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art None
# Casa       PROPN      PROPN__Gender=Fem|Number=Sing None
# e          CCONJ      CCONJ      coordinating conjunction
# acredita   VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# que        SCONJ      SCONJ      subordinating conjunction
# com        ADP        ADP        adposition
# acordo     NOUN       NOUN__Gender=Masc|Number=Sing None
# pode       VERB       VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin None
# fazer      VERB       VERB__VerbForm=Inf None
# isso       PRON       PRON__Gender=Masc|Number=Sing|PronType=Dem None
# rapidamente ADV        ADV        adverb
# .          PUNCT      PUNCT      punctuation

# %% [markdown]
# **Note:** In the above example to format the representation I have added :{10} this is nothing but to give spacing between each token. Just to have better look and feel. No other specific reason. This count start from the first character of the token. You can add any number instead of {10} to have spacing as you wish.

# %% [markdown]
# ## Working with POS Tags
#
# * In the English language, It is very common that the same string of characters can have different meanings, even within the same sentence.
# * For this reason, morphology is important.
# * **spaCy** uses machine learning algorithms to best predict the use of a token in a sentence.
# * Is *"I read books on NLP"* present or past tense?
# * Is *wind* a verb or a noun?

# %% [markdown]
# Let's understand all this with the help of below examples.

# %%
doc = nlp(doc_texto)
r = doc[1]

print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# por        ADP      ADP    adposition

# %%
doc = nlp(doc_texto)
r = doc[1]

print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# por        ADP      ADP    adposition

# %% [markdown]
# In the first example, spaCy assumed that ***read*** was **Present Tense**.<br>
# In the second example the present tense form would be ***I am reading a book***, so spaCy assigned the past tense.

# %% [markdown]
# ## Counting POS Tags
#
# The `Doc.count_by()` method accepts a specific token attribute as its argument, and returns a frequency count of the given attribute as a dictionary object. Keys in the dictionary are the integer values of the given attribute ID, and values are the frequency. Counts of zero are not included.

# %%
doc = nlp(doc_texto)

# Count the frequencies of different coarse-grained POS tags:
POS_counts = doc.count_by(spacy.attrs.POS)
POS_counts
# Out:
# {100: 70,
#  85: 47,
#  92: 111,
#  90: 95,
#  84: 25,
#  89: 12,
#  93: 5,
#  96: 51,
#  97: 70,
#  86: 22,
#  95: 18,
#  87: 11,
#  103: 7,
#  98: 20,
#  99: 1}

# %% [markdown]
# It means tag which has key as 96 is appeared only once and ta with key as 83 has appeared three times in the sentence.
# This isn't very helpful until you decode the attribute ID:

# %%
doc.vocab[83].text
# Out:
# 'LANG'

# %% [markdown]
# ### Create a frequency list of POS tags from the entire document
# Since `POS_counts` returns a dictionary, we can obtain a list of keys with `POS_counts.items()`.<br>By sorting the list we have access to the tag and its count, in order.

# %%
for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 25
# 85. ADP  : 47
# 86. ADV  : 22
# 87. AUX  : 11
# 89. CCONJ: 12
# 90. DET  : 95
# 92. NOUN : 111
# 93. NUM  : 5
# 95. PRON : 18
# 96. PROPN: 51
# 97. PUNCT: 70
# 98. SCONJ: 20
# 99. SYM  : 1
# 100. VERB : 70
# 103. SPACE: 7

# %% [markdown]
# k contains the key number of the tag and v contains the frequency number.

# %% [markdown]
# ## Counting fine-grained Tag

# %%
# Count the different fine-grained tags:
TAG_counts = doc.count_by(spacy.attrs.TAG)

for k,v in sorted(TAG_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{4}}: {v}')
# Out:
# 85. ADP : 40
# 86. ADV : 16
# 89. CCONJ: 12
# 97. PUNCT: 70
# 98. SCONJ: 19
# 99. SYM : 1
# 19706760756614928. DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art: 23
# 37506411736329516. PROPN__Gender=Fem|Number=Sing: 4
# 200353096500367006. VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin: 1
# 241186479898401091. PROPN__Number=Sing: 19
# 786860628783810627. AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin: 1
# 923825831195736815. PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs: 1
# 1182704070608105034. ADJ__Gender=Masc|Number=Sing: 10
# 1204389248178916658. ADP_PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs: 1
# 1244853049173095517. NUM__NumType=Card: 5
# 1851943826059061873. VERB__Gender=Masc|Number=Plur|VerbForm=Part|Voice=Pass: 1
# 1966231466788530083. VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin: 15
# 2432708380621179292. VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin: 10
# 2557482793400667203. ADP_DET__Gender=Fem|Number=Sing|PronType=Dem: 1
# 2576739957777124069. PRON__Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs: 1
# 2636320868373115248. PRON__Case=Nom|Gender=Unsp|Number=Sing|Person=1|PronType=Prs: 1
# 2912612982739039700. NOUN__Gender=Fem|Number=Plur: 7
# 3024036404082953874. VERB__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin: 1
# 3051621230305787049. SCONJ_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art: 1
# 3126574903638732822. VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin: 1
# 3184512349504433708. VERB__Mood=Sub|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin: 1
# 3513323892141332993. ADJ__Gender=Masc|Number=Plur: 2
# 3513574021822476453. ADP_DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art: 21
# 3977684958989494959. ADP_DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art: 1
# 4595143088721212510. VERB__VerbForm=Part: 1
# 4980948325846009909. AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin: 3
# 6249988698375530484. NOUN__Gender=Masc|Number=Plur: 10
# 6893682062797376370. _SP : 7
# 7666508525021631363. AUX__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin: 3
# 7862509086658946094. PRON__Case=Dat|Gender=Masc|Number=Sing|Person=3|PronType=Prs: 1
# 7864757260673665044. PROPN__Gender=Masc|Number=Sing: 28
# 7970050927216405210. VERB__VerbForm=Inf: 26
# 9063101768947287538. VERB__Mood=Sub|Number=Sing|Person=1|Tense=Imp|VerbForm=Fin: 1
# 9236204218973359830. AUX__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin: 1
# 9320222956842691890. NOUN__Gender=Fem|Number=Sing: 45
# 9367639276951572159. VERB__Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass: 3
# 9744929252790920313. NOUN__Gender=Masc|Number=Sing: 49
# 9932394850190536039. PRON__Gender=Masc|Number=Sing|PronType=Dem: 2
# 10125248359581905830. VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin: 2
# 10270791568811240194. ADP_DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art: 4
# 10291993355250963539. DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art: 13
# 10439187063314227356. VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin: 1
# 11103027884377152712. ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art: 28
# 11175997508313538198. VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin: 1
# 11213532077025586871. PRON__Gender=Masc|Number=Sing|PronType=Ind: 2
# 11966412190124123628. DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art: 2
# 12000298213592545554. VERB__Number=Sing|Person=3|VerbForm=Inf: 1
# 12050106565546819263. ADJ__Gender=Fem|Number=Plur: 2
# 12154075310544042108. DET__Gender=Fem|Number=Plur|PronType=Ind: 1
# 12218026380405745863. PRON__Case=Acc|Gender=Unsp|Number=Sing|Person=1|PronType=Prs: 1
# 12666140058252282331. AUX__Number=Sing|Person=3|VerbForm=Inf: 1
# 12934652064941690808. PRON__Gender=Fem|Number=Sing|PronType=Rel: 2
# 13015393714459967670. PRON__Gender=Masc|Number=Sing|PronType=Rel: 4
# 13363021976361088455. VERB__Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass: 4
# 13446417158757488879. PRON__Case=Acc|Gender=Masc|Number=Plur|Person=3|PronType=Prs: 1
# 14072325744960258601. ADP_PRON__Gender=Masc|Number=Sing|PronType=Dem: 1
# 14544263017126569338. ADJ__Gender=Fem|Number=Sing: 11
# 14901960860252854457. PRON__Case=Nom|Gender=Fem|Number=Sing|Person=1|PronType=Prs: 1
# 15232673780748855754. PRON__Gender=Masc|Number=Plur|PronType=Rel: 1
# 16466199626811329376. AUX__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin: 1
# 16709303569312624032. DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art: 2
# 16722906300333592327. AUX__VerbForm=Inf: 1
# 17753204310599929577. ADV__Polarity=Neg: 6
# 18093539131582913503. DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art: 4

# %% [markdown]
# <div class="alert alert-info">**Why did the ID numbers get so big?** In spaCy, certain text values are hardcoded into `Doc.vocab` and take up the first several hundred ID numbers. Strings like 'NOUN' and 'VERB' are used frequently by internal operations. Others, like fine-grained tags, are assigned hash values as needed.</div>
# <div class="alert alert-info">**Why don't SPACE tags appear?** In spaCy, only strings of spaces (two or more) are assigned tokens. Single spaces are not.</div>

# %% [markdown]
# ___
# ## Fine-grained POS Tag Examples
# These are some grammatical examples (shown in **bold**) of specific fine-grained tags. We've removed punctuation and rarely used tags:
# <table>
# <tr><th>POS</th><th>TAG</th><th>DESCRIPTION</th><th>EXAMPLE</th></tr>
# <tr><td>ADJ</td><td>AFX</td><td>affix</td><td>The Flintstones were a **pre**-historic family.</td></tr>
# <tr><td>ADJ</td><td>JJ</td><td>adjective</td><td>This is a **good** sentence.</td></tr>
# <tr><td>ADJ</td><td>JJR</td><td>adjective, comparative</td><td>This is a **better** sentence.</td></tr>
# <tr><td>ADJ</td><td>JJS</td><td>adjective, superlative</td><td>This is the **best** sentence.</td></tr>
# <tr><td>ADJ</td><td>PDT</td><td>predeterminer</td><td>Waking up is **half** the battle.</td></tr>
# <tr><td>ADJ</td><td>PRP\$</td><td>pronoun, possessive</td><td>**His** arm hurts.</td></tr>
# <tr><td>ADJ</td><td>WDT</td><td>wh-determiner</td><td>It's blue, **which** is odd.</td></tr>
# <tr><td>ADJ</td><td>WP\$</td><td>wh-pronoun, possessive</td><td>We don't know **whose** it is.</td></tr>
# <tr><td>ADP</td><td>IN</td><td>conjunction, subordinating or preposition</td><td>It arrived **in** a box.</td></tr>
# <tr><td>ADV</td><td>EX</td><td>existential there</td><td>**There** is cake.</td></tr>
# <tr><td>ADV</td><td>RB</td><td>adverb</td><td>He ran **quickly**.</td></tr>
# <tr><td>ADV</td><td>RBR</td><td>adverb, comparative</td><td>He ran **quicker**.</td></tr>
# <tr><td>ADV</td><td>RBS</td><td>adverb, superlative</td><td>He ran **fastest**.</td></tr>
# <tr><td>ADV</td><td>WRB</td><td>wh-adverb</td><td>**When** was that?</td></tr>
# <tr><td>CONJ</td><td>CC</td><td>conjunction, coordinating</td><td>The balloon popped **and** everyone jumped.</td></tr>
# <tr><td>DET</td><td>DT</td><td>determiner</td><td>**This** is **a** sentence.</td></tr>
# <tr><td>INTJ</td><td>UH</td><td>interjection</td><td>**Um**, I don't know.</td></tr>
# <tr><td>NOUN</td><td>NN</td><td>noun, singular or mass</td><td>This is a **sentence**.</td></tr>
# <tr><td>NOUN</td><td>NNS</td><td>noun, plural</td><td>These are **words**.</td></tr>
# <tr><td>NOUN</td><td>WP</td><td>wh-pronoun, personal</td><td>**Who** was that?</td></tr>
# <tr><td>NUM</td><td>CD</td><td>cardinal number</td><td>I want **three** things.</td></tr>
# <tr><td>PART</td><td>POS</td><td>possessive ending</td><td>Fred**'s** name is short.</td></tr>
# <tr><td>PART</td><td>RP</td><td>adverb, particle</td><td>Put it **back**!</td></tr>
# <tr><td>PART</td><td>TO</td><td>infinitival to</td><td>I want **to** go.</td></tr>
# <tr><td>PRON</td><td>PRP</td><td>pronoun, personal</td><td>**I** want **you** to go.</td></tr>
# <tr><td>PROPN</td><td>NNP</td><td>noun, proper singular</td><td>**Kilroy** was here.</td></tr>
# <tr><td>PROPN</td><td>NNPS</td><td>noun, proper plural</td><td>The **Flintstones** were a pre-historic family.</td></tr>
# <tr><td>VERB</td><td>MD</td><td>verb, modal auxiliary</td><td>This **could** work.</td></tr>
# <tr><td>VERB</td><td>VB</td><td>verb, base form</td><td>I want to **go**.</td></tr>
# <tr><td>VERB</td><td>VBD</td><td>verb, past tense</td><td>This **was** a sentence.</td></tr>
# <tr><td>VERB</td><td>VBG</td><td>verb, gerund or present participle</td><td>I am **going**.</td></tr>
# <tr><td>VERB</td><td>VBN</td><td>verb, past participle</td><td>The treasure was **lost**.</td></tr>
# <tr><td>VERB</td><td>VBP</td><td>verb, non-3rd person singular present</td><td>I **want** to go.</td></tr>
# <tr><td>VERB</td><td>VBZ</td><td>verb, 3rd person singular present</td><td>He **wants** to go.</td></tr>
# </table>

# %% [markdown]
# ## Dependency Parsing

# %% [markdown]
# * Dependency parsing is the process of extracting the dependencies of a sentence to represent its grammatical structure.
# * It defines the dependency relationship between headwords and their dependents.
# * The head of a sentence has no dependency and is called the root of the sentence.
# * The verb is usually the head of the sentence. All other words are linked to the headword.
#
# The dependencies can be mapped in a directed graph representation:
#
# * Words are the nodes.
# * The grammatical relationships are the edges.
# * Dependency parsing helps you know what role a word plays in the text and how different words relate to each other.
# * It’s also used in shallow parsing and named entity recognition.

# %%
# Count the different dependencies:
DEP_counts = doc.count_by(spacy.attrs.DEP)

for k,v in sorted(DEP_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{4}}: {v}')
# Out:
# 0.     : 7
# 399. advcl: 19
# 400. advmod: 19
# 402. amod: 24
# 403. appos: 10
# 405. aux : 3
# 407. cc  : 12
# 408. ccomp: 3
# 410. conj: 12
# 411. cop : 5
# 415. det : 45
# 417. expl: 1
# 422. iobj: 1
# 423. mark: 24
# 426. nmod: 51
# 429. nsubj: 26
# 434. obj : 38
# 435. obl : 21
# 436. parataxis: 5
# 445. punct: 68
# 450. xcomp: 10
# 451. acl : 7
# 341650274070182569. fixed: 5
# 6025759613719693942. acl:relcl: 5
# 7833439085008721140. nsubj:pass: 3
# 8110129090154140942. case: 90
# 8206900633647566924. ROOT: 22
# 11989517400186072643. obl:agent: 6
# 12837356684637874264. nummod: 2
# 17772752594865228322. flat:name: 17
# 18127512502257733094. aux:pass: 4

# %% [markdown]
# Here we've shown `spacy.attrs.POS`, `spacy.attrs.TAG` and `spacy.attrs.DEP`.<br>

# %% [markdown]
# # Visualizing Parts of Speech
# spaCy offers an outstanding visualizer called **displaCy**:

# %%
# Import the displaCy library
from spacy import displacy

# %%
# Create a simple Doc object
sentences = list(doc.sents)
sentences[0]
# Out:
# Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).

# %%
# Render the dependency parse immediately inside Jupyter:
displacy.render(sentences[0], style='dep', jupyter=True, options={'distance': 95})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="890a60617f3a429c94c56c37daf557a1-0" class="displacy" width="4325" height="469.5" direction="ltr" style="max-width: none; height: 469.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Defendida</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="145">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="240">agentes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="335">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="430">mercado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="525">financeiro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="620">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="715">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="810">das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="905">bandeiras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1000">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1095">equipe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1095">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1190">econômica</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1285">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1285">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1380">governo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1475">Jair</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1570">Bolsonaro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1665">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1760">projeto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1855">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1855">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1950">autonomia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2045">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2045">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2140">Banco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2235">Central (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2235">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2330">BC)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2425">deve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2520">avançar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2615">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2615">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2710">Câmara</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2805">só</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2805">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2900">após</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColo

# %% [markdown]
# The dependency parse shows the coarse POS tag for each token, as well as the **dependency tag** if given:

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{7}} {token.dep_:{7}} {spacy.explain(token.dep_)}')
# Out:
# Defendida  VERB    acl     clausal modifier of noun (adjectival clause)
# por        ADP     case    case marking
# agentes    NOUN    obl:agent None
# do         DET     case    case marking
# mercado    NOUN    nmod    modifier of nominal
# financeiro ADJ     amod    adjectival modifier
# e          CCONJ   cc      coordinating conjunction
# uma        NUM     conj    conjunct
# das        DET     case    case marking
# bandeiras  NOUN    nmod    modifier of nominal
# da         DET     case    case marking
# equipe     NOUN    nmod    modifier of nominal
# econômica  ADJ     amod    adjectival modifier
# do         DET     case    case marking
# governo    NOUN    nmod    modifier of nominal
# Jair       PROPN   appos   appositional modifier
# Bolsonaro  PROPN   flat:name None
# ,          PUNCT   punct   punctuation
# o          DET     det     determiner
# projeto    NOUN    nsubj   nominal subject
# de         ADP     case    case marking
# autonomia  NOUN    nmod    modifier of nominal
# do         DET     case    case marking
# Banco      PROPN   nmod    modifier of nominal
# Central    PROPN   flat:name None
# (          PUNCT   punct   punctuation
# BC         PROPN   appos   appositional modifier
# )          PUNCT   punct   punctuation
# deve       VERB    ROOT    None
# avançar    VERB    xcomp   open clausal complement
# na         DET     case    case marking
# Câmara     NOUN    obl     oblique nominal
# só         ADV     advmod  adverbial modifier
# após       ADP     case    case marking
# a          DET     det     determiner
# reforma    NOUN    obl     oblique nominal
# tributária ADJ     amod    adjectival modifier
# andar      VERB    acl     clausal modifier of noun (adjectival clause)
# ,          PUNCT   punct   punctuation
# no         ADP     mark    marker
# que        PRON    fixed   fixed multiword expression
# depender   VERB    advcl   adverbial clause modifier
# do         DET     case    case marking
# presidente NOUN    obj     object
# da         DET     case    case marking
# Casa       NOUN    nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# Rodrigo    PROPN   appos   appositional modifier
# Maia       PROPN   flat:name None
# (          PUNCT   punct   punctuation
# DEM-RJ     PROPN   parataxis parataxis
# )          PUNCT   punct   punctuation
# .          PUNCT   punct   punctuation
# Para       ADP     case    case marking
# ele        PRON    obl     oblique nominal
# ,          PUNCT   punct   punctuation
# o          DET     det     determiner
# projeto    NOUN    nsubj   nominal subject
# sobre      ADP     case    case marking
# a          DET     det     determiner
# instituição NOUN    nmod    modifier of nominal
# presidida  VERB    acl     clausal modifier of noun (adjectival clause)
# por        ADP     case    case marking
# Roberto    PROPN   obl:agent None
# Campos     PROPN   flat:name None
# Neto       PROPN   flat:name None
# não        ADV     advmod  adverbial modifier
# é          AUX     cop     copula
# urgente    ADJ     ROOT    None
# no         DET     case    case marking
# curto      ADJ     amod    adjectival modifier
# prazo      NOUN    obl     oblique nominal
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# "          PUNCT   ROOT    None
# Aceito     VERB    nsubj   nominal subject
# votar      VERB    advcl   adverbial clause modifier
# autonomia  NOUN    obj     object
# do         DET     case    case marking
# Banco      PROPN   nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# aceito     VERB    acl     clausal modifier of noun (adjectival clause)
# ,          PUNCT   punct   punctuation
# é          AUX     cop     copula
# claro      ADJ     ROOT    None
# ,          PUNCT   punct   punctuation
# votar      VERB    advcl   adverbial clause modifier
# os         DET     det     determiner
# depósitos  NOUN    obj     object
# voluntários ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# mas        CCONJ   cc      coordinating conjunction
# aí         ADV     advmod  adverbial modifier
# temos      VERB    aux     auxiliary
# que        SCONJ   mark    marker
# organizar  VERB    conj    conjunct
# melhor     ADV     advmod  adverbial modifier
# a          DET     det     determiner
# pauta      NOUN    obj     object
# até        ADP     case    case marking
# o          DET     det     determiner
# fim        NOUN    obl     oblique nominal
# do         DET     case    case marking
# ano        NOUN    nmod    modifier of nominal
# .          PUNCT   punct   punctuation
# É          AUX     cop     copula
# só         ADV     advmod  adverbial modifier
# o          DET     det     determiner
# governo    NOUN    nsubj   nominal subject
# ter        VERB    parataxis parataxis
# boa        ADJ     amod    adjectival modifier
# vontade    NOUN    obj     object
# na         DET     case    case marking
# reforma    NOUN    obl     oblique nominal
# tributária ADJ     amod    adjectival modifier
# "          PUNCT   punct   punctuation
# ,          PUNCT   punct   punctuation
# disse      VERB    ROOT    None
# Maia       PROPN   nsubj   nominal subject
# ,          PUNCT   punct   punctuation
# ao         SCONJ   mark    marker
# participar VERB    advcl   adverbial clause modifier
# de         ADP     case    case marking
# evento     NOUN    obj     object
# organizado VERB    acl     clausal modifier of noun (adjectival clause)
# pelo       DET     case    case marking
# Itaú       PROPN   obl:agent None
# .          PUNCT   punct   punctuation
# "          PUNCT   ROOT    None
# A          DET     det     determiner
# reforma    NOUN    nsubj   nominal subject
# tributária ADJ     amod    adjectival modifier
# tem        VERB    parataxis parataxis
# importância NOUN    obj     object
# muito      ADV     advmod  adverbial modifier
# maior      ADJ     amod    adjectival modifier
# que        PRON    mark    marker
# autonomia  NOUN    obl     oblique nominal
# do         DET     case    case marking
# Banco      PROPN   nmod    modifier of nominal
# Central    PROPN   flat:name None
# "          PROPN   punct   punctuation
# ,          PUNCT   punct   punctuation
# comentou   VERB    ROOT    None
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# O          DET     det     determiner
# projeto    NOUN    nsubj:pass None
# de         ADP     case    case marking
# autonomia  NOUN    nmod    modifier of nominal
# do         DET     case    case marking
# BC         PROPN   nmod    modifier of nominal
# foi        AUX     aux:pass None
# aprovado   VERB    ROOT    None
# na         DET     case    case marking
# terça-feira NOUN    obl     oblique nominal
# ,          PUNCT   punct   punctuation
# 3          NUM     parataxis parataxis
# ,          PUNCT   punct   punctuation
# pelo       DET     case    case marking
# Senado     NOUN    obl:agent None
# e          CCONJ   cc      coordinating conjunction
# agora      ADV     advmod  adverbial modifier
# precisa    VERB    conj    conjunct
# do         DET     case    case marking
# aval       NOUN    obj     object
# dos        ADP     case    case marking
# deputados  NOUN    nmod    modifier of nominal
# para       SCONJ   mark    marker
# virar      VERB    advcl   adverbial clause modifier
# lei        NOUN    obj     object
# .          PUNCT   punct   punctuation
# O          DET     det     determiner
# texto      NOUN    nsubj   nominal subject
# mantém     VERB    ROOT    None
# o          DET     det     determiner
# controle   NOUN    obj     object
# dos        ADP     case    case marking
# preços     NOUN    nmod    modifier of nominal
# como       ADP     case    case marking
# objetivo   NOUN    xcomp   open clausal complement
# central    ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# mas        CCONJ   cc      coordinating conjunction
# inclui     VERB    conj    conjunct
# ainda      ADV     advmod  adverbial modifier
# duas       NUM     nummod  numeric modifier
# novas      ADJ     amod    adjectival modifier
# metas      NOUN    obj     object
# acessórias ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# sem        ADP     case    case marking
# prejuízo   NOUN    nmod    modifier of nominal
# à          DET     case    case marking
# principal  NOUN    nmod    modifier of nominal
# :          PUNCT   punct   punctuation
# suavizar   VERB    advcl   adverbial clause modifier
# as         DET     det     determiner
# flutuações NOUN    obj     object
# do         DET     case    case marking
# nível      NOUN    nmod    modifier of nominal
# de         ADP     case    case marking
# atividade  NOUN    nmod    modifier of nominal
# econômica  ADJ     amod    adjectival modifier
# e          CCONJ   cc      coordinating conjunction
# fomentar   VERB    conj    conjunct
# o          DET     det     determiner
# pleno      ADJ     amod    adjectival modifier
# emprego    NOUN    obj     object
# no         DET     case    case marking
# País       NOUN    obl     oblique nominal
# .          PUNCT   punct   punctuation
# O          DET     det     determiner
# governo    NOUN    nsubj   nominal subject
# concordou  VERB    ROOT    None
# com        ADP     case    case marking
# a          DET     det     determiner
# redação    NOUN    obj     object
# da         DET     case    case marking
# proposta   NOUN    nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# apesar     ADV     mark    marker
# de         ADP     fixed   fixed multiword expression
# o          DET     det     determiner
# BC         PROPN   nsubj   nominal subject
# ser        AUX     cop     copula
# historicamente ADV     advmod  adverbial modifier
# contrário  ADV     advcl   adverbial clause modifier
# a          SCONJ   mark    marker
# ampliar    VERB    xcomp   open clausal complement
# o          DET     det     determiner
# escopo     NOUN    obj     object
# da         DET     case    case marking
# atuação    NOUN    nmod    modifier of nominal
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# Maia       PROPN   nsubj   nominal subject
# já         ADV     advmod  adverbial modifier
# reclamou   VERB    ROOT    None
# outras     DET     det     determiner
# vezes      NOUN    obj     object
# da         DET     case    case marking
# falta      NOUN    nmod    modifier of nominal
# de         ADP     case    case marking
# empenho    NOUN    nmod    modifier of nominal
# e          CCONJ   cc      coordinating conjunction
# atuação    NOUN    conj    conjunct
# do         DET     case    case marking
# governo    NOUN    nmod    modifier of nominal
# para       SCONJ   mark    marker
# se         PRON    nsubj   nominal subject
# aprovar    VERB    advcl   adverbial clause modifier
# a          DET     det     determiner
# medida     NOUN    obj     object
# .          PUNCT   punct   punctuation
# Na         DET     case    case marking
# semana     NOUN    obl     oblique nominal
# passada    ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# acusou     VERB    ROOT    None
# o          DET     det     determiner
# presidente NOUN    obj     object
# do         DET     case    case marking
# Banco      PROPN   nmod    modifier of nominal
# Central    PROPN   flat:name None
# ,          PUNCT   punct   punctuation
# Roberto    PROPN   appos   appositional modifier
# Campos     PROPN   flat:name None
# Neto       PROPN   flat:name None
# ,          PUNCT   punct   punctuation
# de         SCONJ   mark    marker
# ter        AUX     aux     auxiliary
# vazado     VERB    xcomp   open clausal complement
# informações NOUN    obj     object
# sobre      ADP     case    case marking
# conversa   NOUN    nmod    modifier of nominal
# que        SCONJ   obj     object
# os         DET     det     determiner
# dois       NUM     nsubj   nominal subject
# tiveram    VERB    acl:relcl None
# no         DET     case    case marking
# dia        NOUN    obl     oblique nominal
# da         DET     case    case marking
# decisão    NOUN    nmod    modifier of nominal
# do         DET     case    case marking
# Comitê     PROPN   nmod    modifier of nominal
# de         ADP     case    case marking
# Política   PROPN   nmod    modifier of nominal
# Monetária  PROPN   flat:name None
# (          PUNCT   punct   punctuation
# Copom      PROPN   appos   appositional modifier
# )          PUNCT   punct   punctuation
# ,          PUNCT   punct   punctuation
# que        PRON    nsubj   nominal subject
# manteve    VERB    acl:relcl None
# a          DET     det     determiner
# taxa       NOUN    obj     object
# Selic      PROPN   appos   appositional modifier
# em         ADP     case    case marking
# 2          NUM     nummod  numeric modifier
# %          SYM     obl     oblique nominal
# ao         DET     case    case marking
# ano        NOUN    nmod    modifier of nominal
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# Ao         DET     case    case marking
# jornal     NOUN    ROOT    None
# O          DET     det     determiner
# Estado     NOUN    nsubj   nominal subject
# de         ADP     case    case marking
# S.         PROPN   nmod    modifier of nominal
# Paulo      PROPN   flat:name None
# ,          PUNCT   punct   punctuation
# Maia       PROPN   nsubj   nominal subject
# criticou   VERB    ROOT    None
# a          DET     det     determiner
# articulação NOUN    obj     object
# do         DET     case    case marking
# presidente NOUN    nmod    modifier of nominal
# do         DET     case    case marking
# BC         PROPN   nmod    modifier of nominal
# em         SCONJ   mark    marker
# alertar    VERB    advcl   adverbial clause modifier
# sobre      ADP     case    case marking
# os         DET     det     determiner
# reflexos   NOUN    obl     oblique nominal
# para       ADP     case    case marking
# a          DET     det     determiner
# economia   NOUN    nmod    modifier of nominal
# da         DET     case    case marking
# dificuldade NOUN    nmod    modifier of nominal
# do         DET     case    case marking
# Congresso  NOUN    nmod    modifier of nominal
# em         SCONJ   mark    marker
# avançar    VERB    advcl   adverbial clause modifier
# com        ADP     case    case marking
# as         DET     det     determiner
# votações   NOUN    obl     oblique nominal
# da         DET     case    case marking
# pauta      NOUN    nmod    modifier of nominal
# de         ADP     case    case marking
# ajuste     NOUN    nmod    modifier of nominal
# fiscal     ADJ     amod    adjectival modifier
# .          PUNCT   punct   punctuation
# Segundo    ADP     case    case marking
# o          DET     det     determiner
# presidente NOUN    obl     oblique nominal
# da         DET     case    case marking
# Câmara     NOUN    nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# Campos     PROPN   nsubj   nominal subject
# Neto       PROPN   flat:name None
# tentou     VERB    ROOT    None
# fazer      VERB    xcomp   open clausal complement
# uma        DET     det     determiner
# articulação NOUN    obj     object
# política   ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# sem        SCONJ   mark    marker
# combinar   VERB    advcl   adverbial clause modifier
# ,          PUNCT   punct   punctuation
# o          PRON    appos   appositional modifier
# que        PRON    nsubj   nominal subject
# não        ADV     advmod  adverbial modifier
# seria      AUX     cop     copula
# papel      NOUN    acl:relcl None
# dele       ADP     nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# mas        CCONJ   cc      coordinating conjunction
# dos        ADP     case    case marking
# ministros  NOUN    conj    conjunct
# da         DET     case    case marking
# Economia   PROPN   nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# Paulo      PROPN   appos   appositional modifier
# Guedes     PROPN   flat:name None
# ,          PUNCT   punct   punctuation
# e          CCONJ   cc      coordinating conjunction
# da         DET     case    case marking
# articulação NOUN    conj    conjunct
# política   ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# Luiz       PROPN   appos   appositional modifier
# Eduardo    PROPN   flat:name None
# Ramos      PROPN   flat:name None
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# Nesta      ADP     case    case marking
# sexta-feira NOUN    obl     oblique nominal
# ,          PUNCT   punct   punctuation
# o          DET     det     determiner
# presidente NOUN    nsubj   nominal subject
# da         DET     case    case marking
# Câmara     NOUN    nmod    modifier of nominal
# lembrou    VERB    ROOT    None
# que        SCONJ   mark    marker
# havia      VERB    ccomp   clausal complement
# uma        DET     det     determiner
# proposta   NOUN    obj     object
# de         ADP     case    case marking
# autonomia  NOUN    nmod    modifier of nominal
# do         DET     case    case marking
# BC         PROPN   nmod    modifier of nominal
# semelhante ADJ     amod    adjectival modifier
# na         DET     case    case marking
# Câmara     PROPN   nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# mas        CCONJ   cc      coordinating conjunction
# que        PRON    nsubj:pass None
# não        ADV     advmod  adverbial modifier
# foi        AUX     aux:pass None
# votada     VERB    conj    conjunct
# ,          PUNCT   punct   punctuation
# e          CCONJ   cc      coordinating conjunction
# disse      VERB    conj    conjunct
# que        SCONJ   mark    marker
# não        ADV     advmod  adverbial modifier
# comentou   VERB    ccomp   clausal complement
# até        ADP     case    case marking
# agora      ADV     advmod  adverbial modifier
# sobre      ADP     case    case marking
# o          DET     det     determiner
# tema       NOUN    obj     object
# porque     SCONJ   mark    marker
# não        ADV     advmod  adverbial modifier
# foi        AUX     aux:pass None
# procurado  VERB    advcl   adverbial clause modifier
# pelo       DET     case    case marking
# governo    NOUN    obl:agent None
# para       SCONJ   mark    marker
# falar      VERB    advcl   adverbial clause modifier
# sobre      ADP     case    case marking
# o          DET     det     determiner
# assunto    NOUN    obj     object
# .          PUNCT   punct   punctuation
# "          PUNCT   ROOT    None
# Se         SCONJ   mark    marker
# eu         PRON    nsubj   nominal subject
# conseguisse VERB    advcl   adverbial clause modifier
# conversar  VERB    xcomp   open clausal complement
# com        ADP     case    case marking
# alguém     PRON    obj     object
# do         DET     case    case marking
# governo    NOUN    nmod    modifier of nominal
# ,          PUNCT   punct   punctuation
# eu         PRON    nsubj   nominal subject
# poderia    VERB    ROOT    None
# te         PRON    iobj    indirect object
# responder  VERB    xcomp   open clausal complement
# ,          PUNCT   punct   punctuation
# mas        CCONJ   cc      coordinating conjunction
# ninguém    PRON    nsubj   nominal subject
# me         PRON    obj     object
# procura    VERB    conj    conjunct
# .          PUNCT   punct   punctuation
# Não        ADV     advmod  adverbial modifier
# vou        AUX     aux     auxiliary
# conversar  VERB    parataxis parataxis
# com        ADP     case    case marking
# a          DET     det     determiner
# imprensa   NOUN    obj     object
# antes      ADV     mark    marker
# de         ADP     fixed   fixed multiword expression
# conversar  VERB    advcl   adverbial clause modifier
# com        ADP     case    case marking
# o          DET     det     determiner
# governo    NOUN    obj     object
# "          PUNCT   punct   punctuation
# ,          PUNCT   punct   punctuation
# disse      VERB    ROOT    None
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# Como       ADP     advmod  adverbial modifier
# o          DET     det     determiner
# Broadcast  PROPN   nsubj   nominal subject
# (          PUNCT   punct   punctuation
# sistema    NOUN    appos   appositional modifier
# de         ADP     case    case marking
# notícias   NOUN    nmod    modifier of nominal
# em         ADP     case    case marking
# tempo      NOUN    nmod    modifier of nominal
# real       ADJ     amod    adjectival modifier
# do         DET     case    case marking
# Grupo      PROPN   nmod    modifier of nominal
# Estado     PROPN   flat:name None
# )          PUNCT   punct   punctuation
# mostrou    VERB    advcl   adverbial clause modifier
# na         DET     case    case marking
# quinta-feira NOUN    obl     oblique nominal
# ,          PUNCT   punct   punctuation
# deputados  NOUN    nsubj   nominal subject
# já         ADV     advmod  adverbial modifier
# se         PRON    expl    expletive
# articulam  VERB    ROOT    None
# na         DET     case    case marking
# Câmara     NOUN    obl     oblique nominal
# para       SCONJ   mark    marker
# modificar  VERB    advcl   adverbial clause modifier
# o          DET     det     determiner
# projeto    NOUN    obj     object
# aprovado   VERB    acl     clausal modifier of noun (adjectival clause)
# pelo       DET     case    case marking
# Senado     NOUN    obl:agent None
# .          PUNCT   punct   punctuation
# O          DET     det     determiner
# partido    NOUN    nsubj   nominal subject
# Novo       ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# por        ADP     advmod  adverbial modifier
# exemplo    NOUN    fixed   fixed multiword expression
# ,          PUNCT   punct   punctuation
# quer       VERB    ROOT    None
# enxugar    VERB    xcomp   open clausal complement
# a          DET     det     determiner
# proposta   NOUN    obj     object
# que        PRON    nsubj   nominal subject
# recebeu    VERB    acl:relcl None
# aval       NOUN    obj     object
# dos        ADP     case    case marking
# senadores  NOUN    nmod    modifier of nominal
# para       SCONJ   mark    marker
# reduzir    VERB    advcl   adverbial clause modifier
# os         DET     det     determiner
# chamados   ADJ     amod    adjectival modifier
# acessórios NOUN    obj     object
# que        PRON    nsubj:pass None
# foram      AUX     aux:pass None
# colocados  VERB    acl:relcl None
# para       ADP     case    case marking
# o          DET     det     determiner
# Banco      PROPN   obl     oblique nominal
# Central    PROPN   flat:name None
# .          PUNCT   punct   punctuation
#
#
#          SPACE           None
# Sobre      ADP     case    case marking
# a          DET     det     determiner
# reforma    NOUN    obl     oblique nominal
# tributária ADJ     amod    adjectival modifier
# ,          PUNCT   punct   punctuation
# Maia       PROPN   nsubj   nominal subject
# deu        VERB    ROOT    None
# sinais     NOUN    obj     object
# de         SCONJ   mark    marker
# que        SCONJ   mark    marker
# quer       VERB    acl     clausal modifier of noun (adjectival clause)
# aprovar    VERB    xcomp   open clausal complement
# o          DET     det     determiner
# projeto    NOUN    obj     object
# antes      ADV     mark    marker
# de         ADP     fixed   fixed multiword expression
# deixar     VERB    advcl   adverbial clause modifier
# a          DET     det     determiner
# presidência NOUN    obj     object
# da         DET     case    case marking
# Casa       PROPN   nmod    modifier of nominal
# e          CCONJ   cc      coordinating conjunction
# acredita   VERB    conj    conjunct
# que        SCONJ   mark    marker
# com        ADP     case    case marking
# acordo     NOUN    obl     oblique nominal
# pode       VERB    ccomp   clausal complement
# fazer      VERB    xcomp   open clausal complement
# isso       PRON    obj     object
# rapidamente ADV     amod    adjectival modifier
# .          PUNCT   punct   punctuation

# %% [markdown]
# ___
# ## Handling Large Text
# `displacy.serve()` accepts a single Doc or list of Doc objects. Since large texts are difficult to view in one line, you may want to pass a list of spans instead. Each span will appear on its own line:

# %%
doc2 = nlp(doc_texto)

# Create spans from Doc.sents:
spans = list(doc2.sents)

displacy.render(spans, style='dep',jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="1bff64822a9941fc99804f0844d300c0-0" class="displacy" width="5000" height="522.0" direction="ltr" style="max-width: none; height: 522.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Defendida</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">agentes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">mercado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">financeiro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">bandeiras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">equipe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">econômica</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">governo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Jair</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">Bolsonaro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">projeto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">autonomia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">Banco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">Central (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">BC)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">deve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">avançar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">Câmara</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">só</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">após</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCo

# %% [markdown]
# ___
# ## Customizing the Appearance
# Besides setting the distance between tokens, you can pass other arguments to the `options` parameter:
#
# <table>
# <tr><th>NAME</th><th>TYPE</th><th>DESCRIPTION</th><th>DEFAULT</th></tr>
# <tr><td>`compact`</td><td>bool</td><td>"Compact mode" with square arrows that takes up less space.</td><td>`False`</td></tr>
# <tr><td>`color`</td><td>unicode</td><td>Text color (HEX, RGB or color names).</td><td>`#000000`</td></tr>
# <tr><td>`bg`</td><td>unicode</td><td>Background color (HEX, RGB or color names).</td><td>`#ffffff`</td></tr>
# <tr><td>`font`</td><td>unicode</td><td>Font name or font family for all text.</td><td>`Arial`</td></tr>
# </table>
#
# For a full list of options visit https://spacy.io/api/top-level#displacy_options

# %%
options = {'distance': 90, 'compact': 'True', 'color': 'black', 'bg': '#09a3e0', 'font': 'Times'}

displacy.render(doc, style='dep',jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="87eca5c177004338a222b3673ae796a1-0" class="displacy" width="44420" height="1037.0" direction="ltr" style="max-width: none; height: 1037.0px; color: black; background: #09a3e0; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Defendida</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">agentes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">mercado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">financeiro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">bandeiras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">equipe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">econômica</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">governo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Jair</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Bolsonaro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">projeto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">autonomia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">Banco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Central (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">BC)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">deve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">avançar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Câmara</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">só</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">após</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor

# %% [markdown]
# References:
#
# * https://spacy.io/
# * https://www.udemy.com/course/nlp-natural-language-processing-with-python
