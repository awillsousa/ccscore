# %%
# Execute o código a seguir caso a instalação do newspaper3k ainda não tenha sido executada
# !pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (0.2.8)
# Requirement already satisfied: tldextract>=2.0.1 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (3.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: tinysegmenter==0.3 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: jieba3k>=0.35.1 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: feedfinder2>=0.0.4 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: requests>=2.10.0 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (2.24.0)
# Requirement already satisfied: feedparser>=5.2.1 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: nltk>=3.2.1 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (3.5)
# Requirement already satisfied: PyYAML>=3.11 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (5.3.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: Pillow>=3.3.0 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (8.0.1)
# Requirement already satisfied: lxml>=3.6.0 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from newspaper3k) (4.6.1)
# Requirement already satisfied: requests-file>=1.4 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: idna in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from tldextract>=2.0.1->newspaper3k) (2.10)
# Requirement already satisfied: filelock>=3.0.8 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from tldextract>=2.0.1->newspaper3k) (3.0.12)
# Requirement already satisfied: six in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from requests>=2.10.0->newspaper3k) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from requests>=2.10.0->newspaper3k) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: sgmllib3k in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: joblib in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from nltk>=3.2.1->newspaper3k) (0.17.0)
# Requirement already satisfied: regex in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from nltk>=3.2.1->newspaper3k) (2020.11.13)
# Requirement already satisfied: tqdm in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from nltk>=3.2.1->newspaper3k) (4.51.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.0.1)

# %%
from newspaper import Article

# %%
urls=['https://www.jota.info/casa-jota/casa-jota-ganhos-sociais-gerados-pelo-avanco-da-tecnologia-16112020',
     'https://economia.uol.com.br/noticias/estadao-conteudo/2020/11/06/reforma-tributaria-deve-vir-antes-de-autonomia-do-bc-na-camara-diz-maia.htm']

# %%
textos = [Article(url) for url in urls]

for texto in textos:
    texto.download()
    texto.parse()

# %%
# Execute o código a seguir caso o modelo não esteja instalado
# Se a execução for feita através do jupyter, o kernel do ambiente
# deve ser recarregado

#!python -m spacy download pt_core_news_lg
# ou
#!python -m spacy download pt_core_news_sm

# %%
import spacy
import itertools as itt
nlp = spacy.load("pt_core_news_lg")

# %%
doc_texto = nlp(textos[1].text)

documento = {'texto': doc_texto.text,
             'sentencas': list(doc_texto.sents),
             'nouns': list(itt.chain([n for n in doc_texto.noun_chunks]))
            }

# %%
documento['sentencas'][0].text
# Out:
# 'Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).'

# %%
print(doc_texto.text)
# Out:
# Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
#
# "Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
#
# O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei. O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País. O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
#
# Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida. Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
#
# Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal. Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
#
# Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto. "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura. Não vou conversar com a imprensa antes de conversar com o governo", disse.
#
# Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado. O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
#
# Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.

# %%
#dir(doc_texto)
#dir(doc_texto.vocab.vectors)
doc_texto.vocab.vectors.values()

# %%
# Avaliando as etiquetas de POS e dependency parsing

for word in documento['sentencas'][0]:
      print(word.text,  word.pos_, word.dep_)
# Out:
# Defendida VERB acl
# por ADP case
# agentes NOUN obl:agent
# do DET case
# mercado NOUN nmod
# financeiro ADJ amod
# e CCONJ cc
# uma NUM conj
# das DET case
# bandeiras NOUN nmod
# da DET case
# equipe NOUN nmod
# econômica ADJ amod
# do DET case
# governo NOUN nmod
# Jair PROPN appos
# Bolsonaro PROPN flat:name
# , PUNCT punct
# o DET det
# projeto NOUN nsubj
# de ADP case
# autonomia NOUN nmod
# do DET case
# Banco PROPN nmod
# Central PROPN flat:name
# ( PUNCT punct
# BC PROPN appos
# ) PUNCT punct
# deve VERB ROOT
# avançar VERB xcomp
# na DET case
# Câmara NOUN obl
# só ADV advmod
# após ADP case
# a DET det
# reforma NOUN obl
# tributária ADJ amod
# andar VERB acl
# , PUNCT punct
# no ADP mark
# que PRON fixed
# depender VERB advcl
# do DET case
# presidente NOUN obj
# da DET case
# Casa NOUN nmod
# , PUNCT punct
# Rodrigo PROPN appos
# Maia PROPN flat:name
# ( PUNCT punct
# DEM-RJ PROPN parataxis
# ) PUNCT punct
# . PUNCT punct

# %%
for i,sent in enumerate(doc_texto.sents):
    print(i,sent)
# Out:
# 0 Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).
# 1 Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
#
#
# 2 "
# 3 Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.
# 4 É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.
# 5 "
# 6 A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
#
#
# 7 O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei.
# 8 O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País.
# 9 O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
#
#
# 10 Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida.
# 11 Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
#
#
# 12 Ao jornal
# 13 O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal.
# 14 Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
#
#
# 15 Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto.
# 16 "
# 17 Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura.
# 18 Não vou conversar com a imprensa antes de conversar com o governo", disse.
#
#
# 19 Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado.
# 20 O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
#
#
# 21 Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.

# %%
# Visualizando árvore com Displacy
spacy.displacy.render(list(doc_texto.sents)[:2], style='dep', jupyter=True, options={'distance': 100, 'compact': True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="8404eb603b1a4e27a0fd8aa07d254eb2-0" class="displacy" width="4550" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Defendida</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">agentes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">mercado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">financeiro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">bandeiras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">equipe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">econômica</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">governo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Jair</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">Bolsonaro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">projeto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">autonomia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">Banco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">Central (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">BC)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">deve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">avançar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Câmara</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">só</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">após</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColo

# %%
# Visualizando árvore com Displacy
spacy.displacy.render(list(doc_texto.sents), style='ent', jupyter=True, options={'distance': 100, 'compact': True})
# Out:
# /home/willian/anaconda3/envs/ccscore/lib/python3.8/site-packages/spacy/displacy/__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jair Bolsonaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , o projeto de autonomia do
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Banco Central
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) deve avançar na
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Câmara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  só após a reforma tributária andar, no que depender do presidente da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Casa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rodrigo Maia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DEM-RJ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ). </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Para ele, o projeto sobre a instituição presidida por
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roberto Campos Neto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  não é urgente no curto prazo.
#
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">&quot;</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Aceito votar autonomia do
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Banco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">É só o governo ter boa vontade na reforma tributária&quot;, disse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , ao participar de evento organizado pelo
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Itaú
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">&quot;</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A reforma tributária tem importância muito maior que autonomia do
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Banco Central
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# &quot;, comentou.
#
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">O projeto de autonomia do
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  foi aprovado na terça-feira, 3, pelo
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Senado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e agora precisa do aval dos deputados para virar lei. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     País
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">O governo concordou com a redação da proposta, apesar de o
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ser historicamente contrário a ampliar o escopo da atuação.
#
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Na semana passada, acusou o presidente do
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Banco Central
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </m

# %%
from pathlib import Path

svg = spacy.displacy.render(list(doc_texto.sents)[:1], style='dep', jupyter=False, options={'distance': 100, 'compact': True})
file_name = "teste_plotagem_dep.svg"
output_path = Path("./images/" + file_name)
output_path.open("w", encoding="utf-8").write(svg)
# Out:
# 38304
