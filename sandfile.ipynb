# %% [markdown]
# ### Testes básicos do funcionamento do CCScore

# %%
import sys
sys.path.append('./ccscore/')
from infernal import feature_extraction as fe
from infernal import datastructures as ds
import spacy

# %%
nlp = spacy.load('pt_core_news_lg')

# %%
# Instalações de pacotes
#!python -m spacy download pt_core_news_lg
#!python -m spacy download pt_core_news_lg
#!pip install zss rdflib
#!conda install -y scipy
#!conda install -y pandas
#!pip install python-dotenv

# %%
texto = '''Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
'''

#O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei. O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País. O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
#Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida. Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
#Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal. Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
#Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto. "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura. Não vou conversar com a imprensa antes de conversar com o governo", disse.
#Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado. O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
#Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.'''
#'''

texto
# Out:
# 'Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.\n"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.\n'

# %% [markdown]
# Processamento básico dos textos é feito com Spacy,
# mas de forma interno às classes do ccscore

# %%
textdoc = nlp(texto)

# %%
def paragraphs(document):
    '''
    Generator to define start positions
    of paragraphs
    '''
    start = 0
    for token in document:
        if token.is_space and token.text.count("\n") > 1:
            yield document[start:token.i]
            start = token.i
    yield document[start:]

# %%
from itertools import tee

def pairwise(iterable):
    '''
    Receive an iterable and return
    an list with tuples of this elements
    is this way    
    s -> (s0,s1), (s1,s2), (s2, s3), ...
    '''
    a, b = tee(iterable)    
    next(b, None)  # next(b) it's Ok 
    return zip(a, b)

# %%
import helper_palavras as h_pal 
from text_document import TextDocument

ARQ_TEXTO = "./ccscore/data/texto_exemplo.txt"
ARQ_PALAVRAS = "./ccscore/data/texto_exemplo_anotado.html"
ARQ_PALAVRAS_ORIG = "./ccscore/data/texto_exemplo.txt"

try:
    with open(ARQ_TEXTO, 'r') as f_text:
            orig_text = " ".join(f_text.readlines())
except IOError:
    print(f"Erro ao tentar abrir o arquivo {ARQ_TEXTO}")

tp = h_pal.parse_file_toclass(ARQ_PALAVRAS,
                              ARQ_PALAVRAS_ORIG)
                              
td = TextDocument(orig_text, tp)

# %% [markdown]
# Listando:
# <ol>
#     <li>Foco Explícito (FE)</li>
#     <li>Lista intermediária do FE</li>
#     <li>Lista das Entidades Nomeadas</li>
#     <li>Menções da DBPedia</li>
# </ol>

# %%
for i, sent in enumerate(td.sentences):
    print()
    print("ID: ", str(i))    
    print("Texto Original: ", sent.text)    
    print()    
    print("Lista de Foco Explícito: ", [s for s in sent.list_fe])    
    print()
    print("Lista de Intermediária de FE: ", sent.list_fe_li)#[s for s in sent.list_fe_li])    
    print()    
    print("Lista de Entidades Nomeadas: ", sent.named_entities)    
    print()
    print("Lista de Menções DBPedia: ", str(sent.dbpedia_mentions))    
    
    print("-"*100)
    
#s_disp = td.nlp_processor(td.sentences[4].text)
#spacy.displacy.render(s_disp, style="dep", options = {"compact": True})
# Out:
# ID:  0
# Texto Original:  Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).
#
# Lista de Foco Explícito:  ['presidente', 'agentes', 'BC', 'projeto', 'reforma tributária', 'governo Jair Bolsonaro', 'que', 'Casa', 'DEM-RJ', 'bandeiras', 'Jair Bolsonaro', 'mercado financeiro', 'equipe', 'Câmara', 'Rodrigo Maia', 'autonomia', 'Banco Central']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Jair Bolsonaro, Banco Central, BC, Câmara, Casa, Rodrigo Maia, DEM-RJ]
#
# Lista de Menções DBPedia:  ['mercado financeiro', 'governo Jair Bolsonaro', 'Banco Central', 'reforma tributária', 'Rodrigo Maia']
# ----------------------------------------------------------------------------------------------------
#
# ID:  1
# Texto Original:  Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
#
# Lista de Foco Explícito:  ['projeto', 'ele', 'instituição', 'Roberto Campos Neto', 'prazo']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Roberto Campos Neto]
#
# Lista de Menções DBPedia:  ['Roberto Campos Neto']
# ----------------------------------------------------------------------------------------------------
#
# ID:  2
# Texto Original:  "Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.
#
# Lista de Foco Explícito:  ['ano', 'Banco', 'fim', 'pauta', 'depósitos', 'autonomia']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Banco]
#
# Lista de Menções DBPedia:  []
# ----------------------------------------------------------------------------------------------------
#
# ID:  3
# Texto Original:  É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.
#
# Lista de Foco Explícito:  ['vontade', 'evento', 'Maia', 'governo', 'reforma tributária', 'boa', 'Itaú']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Maia, Itaú]
#
# Lista de Menções DBPedia:  ['boa', 'reforma tributária', 'Itaú']
# ----------------------------------------------------------------------------------------------------
#
# ID:  4
# Texto Original:  "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
#
# Lista de Foco Explícito:  ['que', 'importância', 'reforma tributária', 'autonomia', 'Banco Central']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Banco Central]
#
# Lista de Menções DBPedia:  ['reforma tributária', 'Banco Central']
# ----------------------------------------------------------------------------------------------------
#
# ID:  5
# Texto Original:  O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei.
#
# Lista de Foco Explícito:  ['deputados', 'BC', 'Senado', 'terça-feira', 'projeto', 'aval', 'autonomia', 'lei']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [BC, Senado]
#
# Lista de Menções DBPedia:  ['terça-feira', 'Senado']
# ----------------------------------------------------------------------------------------------------
#
# ID:  6
# Texto Original:  O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País.
#
# Lista de Foco Explícito:  ['prejuízo', 'texto', 'País', 'pleno emprego', 'nível', 'atividade', 'principal', 'flutuações', 'metas', 'preços', 'objetivo', 'controle']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [País]
#
# Lista de Menções DBPedia:  ['pleno emprego']
# ----------------------------------------------------------------------------------------------------
#
# ID:  7
# Texto Original:  O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
#
# Lista de Foco Explícito:  ['proposta', 'escopo', 'redação', 'atuação', 'BC', 'governo']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [BC]
#
# Lista de Menções DBPedia:  []
# ----------------------------------------------------------------------------------------------------
#
# ID:  8
# Texto Original:  Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida.
#
# Lista de Foco Explícito:  ['medida', 'Maia', 'vezes', 'governo', 'se', 'atuação', 'empenho', 'falta']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Maia]
#
# Lista de Menções DBPedia:  []
# ----------------------------------------------------------------------------------------------------
#
# ID:  9
# Texto Original:  Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
#
# Lista de Foco Explícito:  ['decisão', 'conversa', 'ano', 'presidente', 'que', 'Roberto Campos Neto', 'Copom', 'dia', 'informações', 'semana', 'Comitê de Política Monetária', 'taxa', 'Selic', 'Banco Central']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Banco Central, Roberto Campos Neto, Comitê de Política Monetária, Copom, Selic]
#
# Lista de Menções DBPedia:  ['Banco Central', 'Roberto Campos Neto', 'Comitê de Política Monetária', 'Copom', 'Selic']
# ----------------------------------------------------------------------------------------------------
#
# ID:  10
# Texto Original:  Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal.
#
# Lista de Foco Explícito:  ['presidente', 'jornal', 'Maia', 'Estado', 'votações', 'BC', 'dificuldade', 'articulação', 'economia', 'ajuste', 'pauta', 'Congresso', 'reflexos']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Maia, BC, Congresso]
#
# Lista de Menções DBPedia:  ['economia']
# ----------------------------------------------------------------------------------------------------
#
# ID:  11
# Texto Original:  Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
#
# Lista de Foco Explícito:  ['presidente', 'Economia', 'Campos Neto', 'Câmara', 'ministros', 'articulação', 'Paulo Guedes', 'Luiz Eduardo Ramos', 'papel', 'que']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Campos Neto, Economia, Paulo Guedes, Luiz Eduardo Ramos]
#
# Lista de Menções DBPedia:  ['Paulo Guedes', 'Luiz Eduardo Ramos']
# ----------------------------------------------------------------------------------------------------
#
# ID:  12
# Texto Original:  Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto.
#
# Lista de Foco Explícito:  ['tema', 'sexta-feira', 'BC', 'governo', 'proposta', 'presidente da Câmara', 'assunto', 'autonomia', 'que']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [presidente da Câmara, BC, Câmara]
#
# Lista de Menções DBPedia:  ['sexta-feira']
# ----------------------------------------------------------------------------------------------------
#
# ID:  13
# Texto Original:  "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura.
#
# Lista de Foco Explícito:  ['te', 'alguém', 'eu', 'me', 'ninguém', 'governo']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  []
#
# Lista de Menções DBPedia:  []
# ----------------------------------------------------------------------------------------------------
#
# ID:  14
# Texto Original:  Não vou conversar com a imprensa antes de conversar com o governo", disse.
#
# Lista de Foco Explícito:  ['governo', 'imprensa']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  []
#
# Lista de Menções DBPedia:  []
# ----------------------------------------------------------------------------------------------------
#
# ID:  15
# Texto Original:  Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado.
#
# Lista de Foco Explícito:  ['deputados', 'sistema', 'notícias', 'quinta-feira', 'Grupo Estado', 'Câmara', 'Senado', 'se', 'projeto', 'tempo', 'Broadcast']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Broadcast, Grupo Estado, Câmara, Senado]
#
# Lista de Menções DBPedia:  ['Grupo Estado', 'quinta-feira', 'Senado']
# ----------------------------------------------------------------------------------------------------
#
# ID:  16
# Texto Original:  O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
#
# Lista de Foco Explícito:  ['que', 'exemplo', 'senadores', 'proposta', 'partido Novo', 'acessórios', 'aval', 'Banco Central']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [partido Novo, Banco Central]
#
# Lista de Menções DBPedia:  ['partido Novo', 'Banco Central']
# ----------------------------------------------------------------------------------------------------
#
# ID:  17
# Texto Original:  Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.
#
# Lista de Foco Explícito:  ['isso', 'Casa', 'presidência', 'Maia', 'projeto', 'acordo', 'reforma tributária', 'sinais']
#
# Lista de Intermediária de FE:  {'': {'cremoso'}}
#
# Lista de Entidades Nomeadas:  [Maia, Casa]
#
# Lista de Menções DBPedia:  ['reforma tributária']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Carga e alinhamento dos dados anotados pelo PALAVRAS

# %%
import helper_palavras as h_pal 
from text_document import TextDocument

ARQ_TEXTO = "./ccscore/data/texto_exemplo.txt"
ARQ_PALAVRAS = "./ccscore/data/texto_exemplo_anotado.html"
ARQ_PALAVRAS_ORIG = "./ccscore/data/texto_exemplo.txt"

try:
    with open(ARQ_TEXTO, 'r') as f_text:
            orig_text = " ".join(f_text.readlines())
except IOError:
    print(f"Erro ao tentar abrir o arquivo {ARQ_TEXTO}")

# %%
tp = h_pal.parse_file_toclass(ARQ_PALAVRAS,
                              ARQ_PALAVRAS_ORIG)
td = TextDocument(orig_text, tp)

# %%
t_doc = '"Aceito a oferta." disse ele'
doc = td.nlp_processor(t_doc)

for t in doc:
    print(t)
# Out:
# "
# Aceito
# a
# oferta
# .
# "
# disse
# ele

# %%
#print(td.sentences[1].text)
#print(td.sentences[2].text)
#print(td.sentences[3].text)
#print(td.sentences[4].text)
#print(td.sentences[5].text)

import split_utils as su
t_doc = '''"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.'''
su.split_by_sentence(t_doc)
# Out:
# ['"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.',
#  'É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.',
#  '"A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.']

# %%
#for s in td.sentences:
#    for t_sp, t_pal in zip(s.annotated, s.palavras_sentence):
#        print(t_sp.text, t_sp.pos_, t_pal.text)

from collections import defaultdict

aligned_sentences = defaultdict()
for idx_sentence, s in enumerate(td.sentences):

    aligned_pal_tokens = defaultdict()
    #aligned_spa_tokens = defaultdict()
    idx_token = 0
    pal_idx_token = 0
    spa_idx_token = 0
    pal_token_text = ""
    spa_token_text = ""
    pal_tokens_list = []
    spa_tokens_list = []
    it_t_spa = iter(s.annotated)
    for t_pal in s.palavras_sentence:   
        
        # tokens that has composition, stay together    
        if any("<sam->" in tag for tag,_ in t_pal.tags):
            pal_token_text += t_pal.text+" + " 
            pal_tokens_list.append(t_pal)    
            continue
        else:
            # first token from palavras
            pal_token_text += t_pal.text
            pal_tokens_list.append(t_pal)

        # first token from spacy
        token_spa = next(it_t_spa)
        spa_token_text += token_spa.text
        spa_tokens_list.append(token_spa)

        # tokens of proper names are grouped in palavras but,
        # in spacy not
        #if any(" " in tag for tag,_ in t_pal.tags):
        if " " in t_pal.text:
            for _ in range(len(t_pal.text.split(' '))-1):
                token_spa = next(it_t_spa)
                spa_token_text += " "+token_spa.text
                spa_tokens_list.append(token_spa)

        aligned_pal_tokens[idx_token] = {'text': pal_token_text,
                                        'pal_tokens': pal_tokens_list,
                                        'spa_tokens': spa_tokens_list,
                                        'pal_start_idx': pal_idx_token,
                                        'spa_start_idx': spa_idx_token
                                        }

        print(pal_token_text, " <-> ", spa_token_text)
        idx_token += 1
        pal_idx_token += len(pal_tokens_list)
        spa_idx_token += len(spa_tokens_list)
        pal_token_text = ""
        spa_token_text = ""
        pal_tokens_list = []
        spa_tokens_list = []

    aligned_sentences[idx_sentence] = aligned_pal_tokens
    #aligned_pal_tokens
# Out:
# Defendida  <->  Defendida
# por  <->  por
# agentes  <->  agentes
# de + o  <->  do
# mercado  <->  mercado
# financeiro  <->  financeiro
# e  <->  e
# uma  <->  uma
# de + as  <->  das
# bandeiras  <->  bandeiras
# de + a  <->  da
# equipe  <->  equipe
# econômica  <->  econômica
# de + o  <->  do
# governo  <->  governo
# Jair Bolsonaro  <->  Jair Bolsonaro
# ,  <->  ,
# o  <->  o
# projeto  <->  projeto
# de  <->  de
# autonomia  <->  autonomia
# de + o  <->  do
# Banco Central  <->  Banco Central
# (  <->  (
# BC  <->  BC
# )  <->  )
# deve  <->  deve
# avançar  <->  avançar
# em + a  <->  na
# Câmara  <->  Câmara
# só  <->  só
# após  <->  após
# a  <->  a
# reforma  <->  reforma
# tributária  <->  tributária
# andar  <->  andar
# ,  <->  ,
# em + o  <->  no
# que  <->  que
# depender  <->  depender
# de + o  <->  do
# presidente  <->  presidente
# de + a  <->  da
# Casa  <->  Casa
# ,  <->  ,
# Rodrigo Maia  <->  Rodrigo Maia
# (  <->  (
# DEM-RJ  <->  DEM-RJ
# )  <->  )
# .  <->  .
# Para  <->  Para
# ele  <->  ele
# ,  <->  ,
# o  <->  o
# projeto  <->  projeto
# sobre  <->  sobre
# a  <->  a
# instituição  <->  instituição
# presidida  <->  presidida
# por  <->  por
# Roberto Campos Neto  <->  Roberto Campos Neto
# não  <->  não
# é  <->  é
# urgente  <->  urgente
# em + o  <->  no
# curto  <->  curto
# prazo  <->  prazo
# .  <->  .
# "  <->  "
# Aceito  <->  Aceito
# votar  <->  votar
# autonomia  <->  autonomia
# de + o  <->  do
# Banco  <->  Banco
# ,  <->  ,
# aceito  <->  aceito
# ,  <->  ,
# é  <->  é
# claro  <->  claro
# ,  <->  ,
# votar  <->  votar
# os  <->  os
# depósitos  <->  depósitos
# voluntários  <->  voluntários
# ,  <->  ,
# mas  <->  mas
# aí  <->  aí
# temos  <->  temos
# que  <->  que
# organizar  <->  organizar
# melhor  <->  melhor
# a  <->  a
# pauta  <->  pauta
# até  <->  até
# o  <->  o
# fim  <->  fim
# de + o  <->  do
# ano  <->  ano
# .  <->  .
# É  <->  É
# só  <->  só
# o  <->  o
# governo  <->  governo
# ter  <->  ter
# boa vontade  <->  boa vontade
# em + a  <->  na
# reforma  <->  reforma
# tributária  <->  tributária
# "  <->  "
# ,  <->  ,
# disse  <->  disse
# Maia  <->  Maia
# ,  <->  ,
# a + o  <->  ao
# participar  <->  participar
# de  <->  de
# evento  <->  evento
# organizado  <->  organizado
# por + o  <->  pelo
# Itaú  <->  Itaú
# .  <->  .
# "  <->  "
# A  <->  A
# reforma  <->  reforma
# tributária  <->  tributária
# tem  <->  tem
# importância  <->  importância
# muito  <->  muito
# maior  <->  maior
# que  <->  que
# autonomia  <->  autonomia
# de + o  <->  do
# Banco Central  <->  Banco Central
# "  <->  "
# ,  <->  ,
# comentou  <->  comentou
# .  <->  .
# O  <->  O
# projeto  <->  projeto
# de  <->  de
# autonomia  <->  autonomia
# de + o  <->  do
# BC  <->  BC
# foi  <->  foi
# aprovado  <->  aprovado
# em + a  <->  na
# terça-feira  <->  terça-feira
# ,  <->  ,
# 3  <->  3
# ,  <->  ,
# por + o  <->  pelo
# Senado  <->  Senado
# e  <->  e
# agora  <->  agora
# precisa  <->  precisa
# de + o  <->  do
# aval  <->  aval
# de + os  <->  dos
# deputados  <->  deputados
# para  <->  para
# virar  <->  virar
# lei  <->  lei
# .  <->  .
# O  <->  O
# texto  <->  texto
# mantém  <->  mantém
# o  <->  o
# controle  <->  controle
# de + os  <->  dos
# preços  <->  preços
# como  <->  como
# objetivo  <->  objetivo
# central  <->  central
# ,  <->  ,
# mas  <->  mas
# inclui  <->  inclui
# ainda  <->  ainda
# duas  <->  duas
# novas  <->  novas
# metas  <->  metas
# acessórias  <->  acessórias
# ,  <->  ,
# sem  <->  sem
# prejuízo  <->  prejuízo
# a + a  <->  à
# principal  <->  principal
# :  <->  :
# suavizar  <->  suavizar
# as  <->  as
# flutuações  <->  flutuações
# de + o  <->  do
# nível  <->  nível
# de  <->  de
# atividade  <->  atividade
# econômica  <->  econômica
# e  <->  e
# fomentar  <->  fomentar
# o  <->  o
# pleno  <->  pleno
# emprego  <->  emprego
# em + o  <->  no
# País  <->  País
# .  <->  .
# O  <->  O
# governo  <->  governo
# concordou  <->  concordou
# com  <->  com
# a  <->  a
# redação  <->  redação
# de + a  <->  da
# proposta  <->  proposta
# ,  <->  ,
# apesar de  <->  apesar de
# o  <->  o
# BC  <->  BC
# ser  <->  ser
# historicamente  <->  historicamente
# contrário  <->  contrário
# a  <->  a
# ampliar  <->  ampliar
# o  <->  o
# escopo  <->  escopo
# de + a  <->  da
# atuação  <->  atuação
# .  <->  .
# Maia  <->  Maia
# já  <->  já
# reclamou  <->  reclamou
# outras  <->  outras
# vezes  <->  vezes
# de + a  <->  da
# falta  <->  falta
# de  <->  de
# empenho  <->  empenho
# e  <->  e
# atuação  <->  atuação
# de + o  <->  do
# governo  <->  governo
# para  <->  para
# se  <->  se
# aprovar  <->  aprovar
# a  <->  a
# medida  <->  medida
# .  <->  .
# Em + a  <->  Na
# semana  <->  semana
# passada  <->  passada
# ,  <->  ,
# acusou  <->  acusou
# o  <->  o
# presidente  <->  presidente
# de + o  <->  do
# Banco Central  <->  Banco Central
# ,  <->  ,
# Roberto Campos Neto  <->  Roberto Campos Neto
# ,  <->  ,
# de  <->  de
# ter  <->  ter
# vazado  <->  vazado
# informações  <->  informações
# sobre  <->  sobre
# conversa  <->  conversa
# que  <->  que
# os  <->  os
# dois  <->  dois
# tiveram  <->  tiveram
# em + o  <->  no
# dia  <->  dia
# de + a  <->  da
# decisão  <->  decisão
# de + o  <->  do
# Comitê de Política Monetária  <->  Comitê de Política Monetária
# (  <->  (
# Copom  <->  Copom
# )  <->  )
# ,  <->  ,
# que  <->  que
# manteve  <->  manteve
# a  <->  a
# taxa  <->  taxa
# Selic  <->  Selic
# em  <->  em
# 2  <->  2
# %  <->  %
# a + o  <->  ao
# ano  <->  ano
# .  <->  .
# A + o  <->  Ao
# jornal  <->  jornal
# O Estado de S. Paulo  <->  O Estado de S. Paulo
# ,  <->  ,
# Maia  <->  Maia
# criticou  <->  criticou
# a  <->  a
# articulação  <->  articulação
# de + o  <->  do
# presidente  <->  presidente
# de + o  <->  do
# BC  <->  BC
# em  <->  em
# alertar  <->  alertar
# sobre  <->  sobre
# os  <->  os
# reflexos  <->  reflexos
# para  <->  para
# a  <->  a
# economia  <->  economia
# de + a  <->  da
# dificuldade  <->  dificuldade
# de + o  <->  do
# Congresso  <->  Congresso
# em  <->  em
# avançar  <->  avançar
# com  <->  com
# as  <->  as
# votações  <->  votações
# de + a  <->  da
# pauta  <->  pauta
# de  <->  de
# ajuste  <->  ajuste
# fiscal  <->  fiscal
# .  <->  .
# Segundo  <->  Segundo
# o  <->  o
# presidente  <->  presidente
# de + a  <->  da
# Câmara  <->  Câmara
# ,  <->  ,
# Campos Neto  <->  Campos Neto
# tentou  <->  tentou
# fazer  <->  fazer
# uma  <->  uma
# articulação  <->  articulação
# política  <->  política
# ,  <->  ,
# sem  <->  sem
# combinar  <->  combinar
# ,  <->  ,
# o que  <->  o que
# não  <->  não
# seria  <->  seria
# papel  <->  papel
# de + ele  <->  dele
# ,  <->  ,
# mas  <->  mas
# de + os  <->  dos
# ministros  <->  ministros
# de + a  <->  da
# Economia  <->  Economia
# ,  <->  ,
# Paulo Guedes  <->  Paulo Guedes
# ,  <->  ,
# e  <->  e
# de + a  <->  da
# articulação  <->  articulação
# política  <->  política
# ,  <->  ,
# Luiz Eduardo Ramos  <->  Luiz Eduardo Ramos
# .  <->  .
# Em + esta  <->  Nesta
# sexta-feira  <->  sexta-feira
# ,  <->  ,
# o  <->  o
# presidente  <->  presidente
# de + a  <->  da
# Câmara  <->  Câmara
# lembrou  <->  lembrou
# que  <->  que
# havia  <->  havia
# uma  <->  uma
# proposta  <->  proposta
# de  <->  de
# autonomia  <->  autonomia
# de + o  <->  do
# BC  <->  BC
# semelhante  <->  semelhante
# em + a  <->  na
# Câmara  <->  Câmara
# ,  <->  ,
# mas  <->  mas
# que  <->  que
# não  <->  não
# foi  <->  foi
# votada  <->  votada
# ,  <->  ,
# e  <->  e
# disse  <->  disse
# que  <->  que
# não  <->  não
# comentou  <->  comentou
# até  <->  até
# agora  <->  agora
# sobre  <->  sobre
# o  <->  o
# tema  <->  tema
# porque  <->  porque
# não  <->  não
# foi  <->  foi
# procurado  <->  procurado
# por + o  <->  pelo
# governo  <->  governo
# para  <->  para
# falar  <->  falar
# sobre  <->  sobre
# o  <->  o
# assunto  <->  assunto
# .  <->  .
# "  <->  "
# Se  <->  Se
# eu  <->  eu
# conseguisse  <->  conseguisse
# conversar  <->  conversar
# com  <->  com
# alguém  <->  alguém
# de + o  <->  do
# governo  <->  governo
# ,  <->  ,
# eu  <->  eu
# poderia  <->  poderia
# te  <->  te
# responder  <->  responder
# ,  <->  ,
# mas  <->  mas
# ninguém  <->  ninguém
# me  <->  me
# procura  <->  procura
# .  <->  .
# Não  <->  Não
# vou  <->  vou
# conversar  <->  conversar
# com  <->  com
# a  <->  a
# imprensa  <->  imprensa
# antes  <->  antes
# de  <->  de
# conversar  <->  conversar
# com  <->  com
# o  <->  o
# governo  <->  governo
# "  <->  "
# ,  <->  ,
# disse  <->  disse
# .  <->  .
# Como  <->  Como
# o  <->  o
# Broadcast  <->  Broadcast
# (  <->  (
# sistema  <->  sistema
# de  <->  de
# notícias  <->  notícias
# em  <->  em
# tempo  <->  tempo
# real  <->  real
# de + o  <->  do
# Grupo Estado  <->  Grupo Estado
# )  <->  )
# mostrou  <->  mostrou
# em + a  <->  na
# quinta-feira  <->  quinta-feira
# ,  <->  ,
# deputados  <->  deputados
# já  <->  já
# se  <->  se
# articulam  <->  articulam
# em + a  <->  na
# Câmara  <->  Câmara
# para  <->  para
# modificar  <->  modificar
# o  <->  o
# projeto  <->  projeto
# aprovado  <->  aprovado
# por + o  <->  pelo
# Senado  <->  Senado
# .  <->  .
# O  <->  O
# partido  <->  partido
# Novo  <->  Novo
# ,  <->  ,
# por exemplo  <->  por exemplo
# ,  <->  ,
# quer  <->  quer
# enxugar  <->  enxugar
# a  <->  a
# proposta  <->  proposta
# que  <->  que
# recebeu  <->  recebeu
# aval  <->  aval
# de + os  <->  dos
# senadores  <->  senadores
# para  <->  para
# reduzir  <->  reduzir
# os  <->  os
# chamados  <->  chamados
# acessórios  <->  acessórios
# que  <->  que
# foram  <->  foram
# colocados  <->  colocados
# para  <->  para
# o  <->  o
# Banco Central  <->  Banco Central
# .  <->  .
# Sobre  <->  Sobre
# a  <->  a
# reforma  <->  reforma
# tributária  <->  tributária
# ,  <->  ,
# Maia  <->  Maia
# deu  <->  deu
# sinais  <->  sinais
# de  <->  de
# que  <->  que
# quer  <->  quer
# aprovar  <->  aprovar
# o  <->  o
# projeto  <->  projeto
# antes  <->  antes
# de  <->  de
# deixar  <->  deixar
# a  <->  a
# presidência  <->  presidência
# de + a  <->  da
# Casa  <->  Casa
# e  <->  e
# acredita  <->  acredita
# que  <->  que
# com  <->  com
# acordo  <->  acordo
# pode  <->  pode
# fazer  <->  fazer
# isso  <->  isso
# rapidamente  <->  rapidamente
# .  <->  .

# %%
for s in aligned_sentences.values():
    for apt in s.values():
        print(apt)
        print([str(x) for x in apt['pal_tokens']])
        print(f"{'='*100}\n")
# Out:
# {'text': 'Defendida', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be6aa90>], 'spa_tokens': [Defendida], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["Defendida [('<*>', 'TEXT_METAINFO'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@ICL-PRED>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'por', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be54f40>], 'spa_tokens': [por], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["por [('PRP', 'WORD_CLASS'), ('@<PASS', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'agentes', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25eb0>], 'spa_tokens': [agentes], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["agentes [('<Hprof>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf250d0>, <helper_palavras.TokenVISL object at 0x7f937becf6a0>], 'spa_tokens': [do], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["de [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<PIV', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'mercado', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf670>], 'spa_tokens': [mercado], 'pal_start_idx': 5, 'spa_start_idx': 4}
# ["mercado [('<inst>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'financeiro', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45880>], 'spa_tokens': [financeiro], 'pal_start_idx': 6, 'spa_start_idx': 5}
# ["financeiro [('<nh>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'e', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45ee0>], 'spa_tokens': [e], 'pal_start_idx': 7, 'spa_start_idx': 6}
# ["e [('KC', 'WORD_CLASS'), ('@CO', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'uma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7340>], 'spa_tokens': [uma], 'pal_start_idx': 8, 'spa_start_idx': 7}
# ["uma [('<card>', 'WORD_SUBCLASS'), ('NUM', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + as', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7580>, <helper_palavras.TokenVISL object at 0x7f937bea7490>], 'spa_tokens': [das], 'pal_start_idx': 9, 'spa_start_idx': 8}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "as [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('P', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'bandeiras', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea72b0>], 'spa_tokens': [bandeiras], 'pal_start_idx': 11, 'spa_start_idx': 9}
# ["bandeiras [('<cc-rag>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('P', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7820>, <helper_palavras.TokenVISL object at 0x7f937bf451f0>], 'spa_tokens': [da], 'pal_start_idx': 12, 'spa_start_idx': 10}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'equipe', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf160>], 'spa_tokens': [equipe], 'pal_start_idx': 14, 'spa_start_idx': 11}
# ["equipe [('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§POS', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'econômica', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf190>], 'spa_tokens': [econômica], 'pal_start_idx': 15, 'spa_start_idx': 12}
# ["econômica [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25ac0>, <helper_palavras.TokenVISL object at 0x7f937bf25670>], 'spa_tokens': [do], 'pal_start_idx': 16, 'spa_start_idx': 13}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'governo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be54e50>], 'spa_tokens': [governo], 'pal_start_idx': 18, 'spa_start_idx': 14}
# ["governo [('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Jair Bolsonaro', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be54df0>], 'spa_tokens': [Jair, Bolsonaro], 'pal_start_idx': 19, 'spa_start_idx': 15}
# ["Jair Bolsonaro [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bedc340>], 'spa_tokens': [,], 'pal_start_idx': 20, 'spa_start_idx': 17}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1ca30>], 'spa_tokens': [o], 'pal_start_idx': 21, 'spa_start_idx': 18}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'projeto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c6a0>], 'spa_tokens': [projeto], 'pal_start_idx': 22, 'spa_start_idx': 19}
# ["projeto [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bebdaf0>], 'spa_tokens': [de], 'pal_start_idx': 23, 'spa_start_idx': 20}
# ["de [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'autonomia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bebde20>], 'spa_tokens': [autonomia], 'pal_start_idx': 24, 'spa_start_idx': 21}
# ["autonomia [('<state>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bebd970>, <helper_palavras.TokenVISL object at 0x7f937bebdc70>], 'spa_tokens': [do], 'pal_start_idx': 25, 'spa_start_idx': 22}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Banco Central', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1cc10>], 'spa_tokens': [Banco, Central], 'pal_start_idx': 27, 'spa_start_idx': 23}
# ["Banco Central [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': '(', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c100>], 'spa_tokens': [(], 'pal_start_idx': 28, 'spa_start_idx': 25}
# ["( [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'BC', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bedca00>], 'spa_tokens': [BC], 'pal_start_idx': 29, 'spa_start_idx': 26}
# ["BC [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@APP', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ')', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be54070>], 'spa_tokens': [)], 'pal_start_idx': 30, 'spa_start_idx': 27}
# [") [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'deve', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be6a7f0>], 'spa_tokens': [deve], 'pal_start_idx': 31, 'spa_start_idx': 28}
# ["deve [('<fmc>', 'WORD_SUBCLASS'), ('<aux>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'avançar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25af0>], 'spa_tokens': [avançar], 'pal_start_idx': 32, 'spa_start_idx': 29}
# ["avançar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf880>, <helper_palavras.TokenVISL object at 0x7f937becf850>], 'spa_tokens': [na], 'pal_start_idx': 33, 'spa_start_idx': 30}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Câmara', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf458b0>], 'spa_tokens': [Câmara], 'pal_start_idx': 35, 'spa_start_idx': 31}
# ["Câmara [('<prop>', 'WORD_SUBCLASS'), ('<*>', 'TEXT_METAINFO'), ('<HH>', 'SEMANTIC'), ('<NER:org>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'só', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45910>], 'spa_tokens': [só], 'pal_start_idx': 36, 'spa_start_idx': 32}
# ["só [('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@>P', 'SYNTATIC'), ('§FOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'após', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7d90>], 'spa_tokens': [após], 'pal_start_idx': 37, 'spa_start_idx': 33}
# ["após [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93455013d0>], 'spa_tokens': [a], 'pal_start_idx': 38, 'spa_start_idx': 34}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'reforma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f9345501fa0>], 'spa_tokens': [reforma], 'pal_start_idx': 39, 'spa_start_idx': 35}
# ["reforma [('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§ADV', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'tributária', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f9345501190>], 'spa_tokens': [tributária], 'pal_start_idx': 40, 'spa_start_idx': 36}
# ["tributária [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'andar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7eb0>], 'spa_tokens': [andar], 'pal_start_idx': 41, 'spa_start_idx': 37}
# ["andar [('<vK>', 'VERBAL_VALENCY'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-UTT', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45b20>], 'spa_tokens': [,], 'pal_start_idx': 42, 'spa_start_idx': 38}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf453a0>, <helper_palavras.TokenVISL object at 0x7f937becfb80>], 'spa_tokens': [no], 'pal_start_idx': 43, 'spa_start_idx': 39}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25d60>], 'spa_tokens': [que], 'pal_start_idx': 45, 'spa_start_idx': 40}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('<rel>', 'WORD_SUBCLASS'), ('SPEC', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'depender', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25fd0>], 'spa_tokens': [depender], 'pal_start_idx': 46, 'spa_start_idx': 41}
# ["depender [('<mv>', 'VERBAL_VALENCY'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('FUT', 'INFLEXION'), ('3S', 'INFLEXION'), ('SUBJ', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-N<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be542e0>, <helper_palavras.TokenVISL object at 0x7f937bedc520>], 'spa_tokens': [do], 'pal_start_idx': 47, 'spa_start_idx': 42}
# ["de [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<PIV', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'presidente', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c130>], 'spa_tokens': [presidente], 'pal_start_idx': 49, 'spa_start_idx': 43}
# ["presidente [('<Hprof>', 'SEMANTIC'), ('<NER:official>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§CAU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c730>, <helper_palavras.TokenVISL object at 0x7f934549c790>], 'spa_tokens': [da], 'pal_start_idx': 50, 'spa_start_idx': 44}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<NER2:official>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('<NER2:official>', 'UNKNOWN'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Casa', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549cc40>], 'spa_tokens': [Casa], 'pal_start_idx': 52, 'spa_start_idx': 45}
# ["Casa [('<prop>', 'WORD_SUBCLASS'), ('<NER2:official>', 'UNKNOWN'), ('<*>', 'TEXT_METAINFO'), ('<build>', 'SEMANTIC'), ('<NER:site>', 'UNKNOWN'), ('<cle>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6040>], 'spa_tokens': [,], 'pal_start_idx': 53, 'spa_start_idx': 46}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Rodrigo Maia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549ceb0>], 'spa_tokens': [Rodrigo, Maia], 'pal_start_idx': 54, 'spa_start_idx': 47}
# ["Rodrigo Maia [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<np-long>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('@APP', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '(', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549cf10>], 'spa_tokens': [(], 'pal_start_idx': 55, 'spa_start_idx': 49}
# ["( [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'DEM-RJ', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549ca60>], 'spa_tokens': [DEM-RJ], 'pal_start_idx': 56, 'spa_start_idx': 50}
# ["DEM-RJ [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<heur>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@APP', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ')', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bebd1c0>], 'spa_tokens': [)], 'pal_start_idx': 57, 'spa_start_idx': 51}
# [") [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1cf40>], 'spa_tokens': [.], 'pal_start_idx': 58, 'spa_start_idx': 52}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Para', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bedc5e0>], 'spa_tokens': [Para], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["Para [('<*>', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'ele', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be54c10>], 'spa_tokens': [ele], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["ele [('PERS', 'WORD_CLASS'), ('M', 'INFLEXION'), ('3S', 'INFLEXION'), ('NOM/PIV', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§FIN', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf257f0>], 'spa_tokens': [,], 'pal_start_idx': 2, 'spa_start_idx': 2}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf253d0>], 'spa_tokens': [o], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'projeto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becffd0>], 'spa_tokens': [projeto], 'pal_start_idx': 4, 'spa_start_idx': 4}
# ["projeto [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'sobre', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45730>], 'spa_tokens': [sobre], 'pal_start_idx': 5, 'spa_start_idx': 5}
# ["sobre [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea70d0>], 'spa_tokens': [a], 'pal_start_idx': 6, 'spa_start_idx': 6}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'instituição', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f9345501d90>], 'spa_tokens': [instituição], 'pal_start_idx': 7, 'spa_start_idx': 7}
# ["instituição [('<inst>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'presidida', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6dc0>], 'spa_tokens': [presidida], 'pal_start_idx': 8, 'spa_start_idx': 8}
# ["presidida [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('PAS', 'UNKNOWN'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@ICL-N<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'por', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bfa30>], 'spa_tokens': [por], 'pal_start_idx': 9, 'spa_start_idx': 9}
# ["por [('PRP', 'WORD_CLASS'), ('@<PASS', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Roberto Campos Neto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b69d0>], 'spa_tokens': [Roberto, Campos, Neto], 'pal_start_idx': 10, 'spa_start_idx': 10}
# ["Roberto Campos Neto [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'não', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6820>], 'spa_tokens': [não], 'pal_start_idx': 11, 'spa_start_idx': 13}
# ["não [('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC'), ('§FOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'é', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7a30>], 'spa_tokens': [é], 'pal_start_idx': 12, 'spa_start_idx': 14}
# ["é [('<fmc>', 'WORD_SUBCLASS'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'urgente', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45130>], 'spa_tokens': [urgente], 'pal_start_idx': 13, 'spa_start_idx': 15}
# ["urgente [('<nh>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf970>, <helper_palavras.TokenVISL object at 0x7f937bf25a30>], 'spa_tokens': [no], 'pal_start_idx': 14, 'spa_start_idx': 16}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'curto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be6aac0>], 'spa_tokens': [curto], 'pal_start_idx': 16, 'spa_start_idx': 17}
# ["curto [('<nh>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'prazo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bedcbb0>], 'spa_tokens': [prazo], 'pal_start_idx': 17, 'spa_start_idx': 18}
# ["prazo [('<per>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC-TMP', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c2e0>], 'spa_tokens': [.], 'pal_start_idx': 18, 'spa_start_idx': 19}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '"', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549c9d0>], 'spa_tokens': ["], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ['" []']
# ====================================================================================================
#
# {'text': 'Aceito', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549c820>], 'spa_tokens': [Aceito], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["Aceito [('<*>', 'TEXT_METAINFO'), ('<*1>', 'TEXT_METAINFO'), ('<jh>', 'SEMANTIC'), ('<vH>', 'SEMANTIC'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@PRED>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'votar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bf670>], 'spa_tokens': [votar], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["votar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('@ICL-UTT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'autonomia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bfcd0>], 'spa_tokens': [autonomia], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["autonomia [('<state>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454c7340>, <helper_palavras.TokenVISL object at 0x7f93454bf610>], 'spa_tokens': [do], 'pal_start_idx': 4, 'spa_start_idx': 4}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Banco', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bf910>], 'spa_tokens': [Banco], 'pal_start_idx': 6, 'spa_start_idx': 5}
# ["Banco [('<prop>', 'WORD_SUBCLASS'), ('<*>', 'TEXT_METAINFO'), ('<inst>', 'SEMANTIC'), ('<NER:org>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549cd00>], 'spa_tokens': [,], 'pal_start_idx': 7, 'spa_start_idx': 6}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'aceito', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549c340>], 'spa_tokens': [aceito], 'pal_start_idx': 8, 'spa_start_idx': 7}
# ["aceito [('<jh>', 'SEMANTIC'), ('<vH>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<PRED', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1cdc0>], 'spa_tokens': [,], 'pal_start_idx': 9, 'spa_start_idx': 8}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'é', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bedca60>], 'spa_tokens': [é], 'pal_start_idx': 10, 'spa_start_idx': 9}
# ["é [('<fmc>', 'WORD_SUBCLASS'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'claro', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be6ab50>], 'spa_tokens': [claro], 'pal_start_idx': 11, 'spa_start_idx': 10}
# ["claro [('<nh>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25940>], 'spa_tokens': [,], 'pal_start_idx': 12, 'spa_start_idx': 11}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'votar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becfaf0>], 'spa_tokens': [votar], 'pal_start_idx': 13, 'spa_start_idx': 12}
# ["votar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<SUBJ', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'os', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45850>], 'spa_tokens': [os], 'pal_start_idx': 14, 'spa_start_idx': 13}
# ["os [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'depósitos', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bea7cd0>], 'spa_tokens': [depósitos], 'pal_start_idx': 15, 'spa_start_idx': 14}
# ["depósitos [('<mon>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§EXT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'voluntários', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454c79d0>], 'spa_tokens': [voluntários], 'pal_start_idx': 16, 'spa_start_idx': 15}
# ["voluntários [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454c7e20>], 'spa_tokens': [,], 'pal_start_idx': 17, 'spa_start_idx': 16}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'mas', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454cf040>], 'spa_tokens': [mas], 'pal_start_idx': 18, 'spa_start_idx': 17}
# ["mas [('<clb>', 'UNKNOWN'), ('KC', 'WORD_CLASS'), ('@CO', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'aí', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454cf4f0>], 'spa_tokens': [aí], 'pal_start_idx': 19, 'spa_start_idx': 18}
# ["aí [('<kc>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC'), ('§MNR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'temos', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf45c40>], 'spa_tokens': [temos], 'pal_start_idx': 20, 'spa_start_idx': 19}
# ["temos [('<nosubj>', 'UNKNOWN'), ('<fmc>', 'WORD_SUBCLASS'), ('<aux>', 'UNKNOWN'), ('<nosubj-safe>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('1P', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93b1be2040>], 'spa_tokens': [que], 'pal_start_idx': 21, 'spa_start_idx': 20}
# ["que [('KS', 'WORD_CLASS'), ('@PRT-AUX<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'organizar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25190>], 'spa_tokens': [organizar], 'pal_start_idx': 22, 'spa_start_idx': 21}
# ["organizar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'melhor', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be54ca0>], 'spa_tokens': [melhor], 'pal_start_idx': 23, 'spa_start_idx': 22}
# ["melhor [('<KOMP>', 'UNKNOWN'), ('<SUP>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('§MNR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c5e0>], 'spa_tokens': [a], 'pal_start_idx': 24, 'spa_start_idx': 23}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'pauta', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454c7f70>], 'spa_tokens': [pauta], 'pal_start_idx': 25, 'spa_start_idx': 24}
# ["pauta [('<cc-r>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'até', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454c7a60>], 'spa_tokens': [até], 'pal_start_idx': 26, 'spa_start_idx': 25}
# ["até [('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bf790>], 'spa_tokens': [o], 'pal_start_idx': 27, 'spa_start_idx': 26}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'fim', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bffd0>], 'spa_tokens': [fim], 'pal_start_idx': 28, 'spa_start_idx': 27}
# ["fim [('<temp>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC-TMP', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bf280>, <helper_palavras.TokenVISL object at 0x7f93454b6f40>], 'spa_tokens': [do], 'pal_start_idx': 29, 'spa_start_idx': 28}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'ano', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6100>], 'spa_tokens': [ano], 'pal_start_idx': 31, 'spa_start_idx': 29}
# ["ano [('<temp>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549caf0>], 'spa_tokens': [.], 'pal_start_idx': 32, 'spa_start_idx': 30}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'É', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549c310>], 'spa_tokens': [É], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["É [('<clb-fs>', 'UNKNOWN'), ('<*>', 'TEXT_METAINFO'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('<quote>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-ACC>>', 'SYNTATIC'), ('§RES', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'só', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549cb80>], 'spa_tokens': [só], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["só [('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@>N', 'SYNTATIC'), ('§FOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549cdf0>], 'spa_tokens': [o], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'governo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6250>], 'spa_tokens': [governo], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["governo [('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'ter', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6ca0>], 'spa_tokens': [ter], 'pal_start_idx': 4, 'spa_start_idx': 4}
# ["ter [('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<SUBJ', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'boa vontade', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bf070>], 'spa_tokens': [boa, vontade], 'pal_start_idx': 5, 'spa_start_idx': 5}
# ["boa vontade [('<f-psych>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454bf700>, <helper_palavras.TokenVISL object at 0x7f93454c7610>], 'spa_tokens': [na], 'pal_start_idx': 6, 'spa_start_idx': 7}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'reforma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454c76a0>], 'spa_tokens': [reforma], 'pal_start_idx': 8, 'spa_start_idx': 8}
# ["reforma [('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'tributária', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1cca0>], 'spa_tokens': [tributária], 'pal_start_idx': 9, 'spa_start_idx': 9}
# ["tributária [('<*2>', 'TEXT_METAINFO'), ('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': '"', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be541c0>], 'spa_tokens': ["], 'pal_start_idx': 10, 'spa_start_idx': 10}
# ['" []']
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25ca0>], 'spa_tokens': [,], 'pal_start_idx': 11, 'spa_start_idx': 11}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'disse', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf790>], 'spa_tokens': [disse], 'pal_start_idx': 12, 'spa_start_idx': 12}
# ["disse [('<fmc>', 'WORD_SUBCLASS'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<v-quote>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PS', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Maia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f9345501a60>], 'spa_tokens': [Maia], 'pal_start_idx': 13, 'spa_start_idx': 13}
# ["Maia [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SUBJ', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bebd280>], 'spa_tokens': [,], 'pal_start_idx': 14, 'spa_start_idx': 14}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'a + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bebd940>, <helper_palavras.TokenVISL object at 0x7f937bebd0d0>], 'spa_tokens': [ao], 'pal_start_idx': 15, 'spa_start_idx': 15}
# ["a [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'participar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93455019d0>], 'spa_tokens': [participar], 'pal_start_idx': 17, 'spa_start_idx': 16}
# ["participar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937becf490>], 'spa_tokens': [de], 'pal_start_idx': 18, 'spa_start_idx': 17}
# ["de [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'evento', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf25be0>], 'spa_tokens': [evento], 'pal_start_idx': 19, 'spa_start_idx': 18}
# ["evento [('<event>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'organizado', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bf1c640>], 'spa_tokens': [organizado], 'pal_start_idx': 20, 'spa_start_idx': 19}
# ["organizado [('<nh>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# ...
# ====================================================================================================
#
# {'text': 'chamados', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bb6d1c0>], 'spa_tokens': [chamados], 'pal_start_idx': 19, 'spa_start_idx': 19}
# ["chamados [('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'acessórios', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdd46a0>], 'spa_tokens': [acessórios], 'pal_start_idx': 20, 'spa_start_idx': 20}
# ["acessórios [('<n>', 'WORD_SUBCLASS'), ('<jh>', 'SEMANTIC'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde7a00>], 'spa_tokens': [que], 'pal_start_idx': 21, 'spa_start_idx': 21}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('<rel>', 'WORD_SUBCLASS'), ('SPEC', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'foram', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde7550>], 'spa_tokens': [foram], 'pal_start_idx': 22, 'spa_start_idx': 22}
# ["foram [('<aux>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PS/MQP', 'UNKNOWN'), ('3P', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'colocados', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde7fa0>], 'spa_tokens': [colocados], 'pal_start_idx': 23, 'spa_start_idx': 23}
# ["colocados [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('PAS', 'UNKNOWN'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'para', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde7ca0>], 'spa_tokens': [para], 'pal_start_idx': 24, 'spa_start_idx': 24}
# ["para [('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde0fa0>], 'spa_tokens': [o], 'pal_start_idx': 25, 'spa_start_idx': 25}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Banco Central', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdd41c0>], 'spa_tokens': [Banco, Central], 'pal_start_idx': 26, 'spa_start_idx': 26}
# ["Banco Central [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§FIN', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93455016d0>], 'spa_tokens': [.], 'pal_start_idx': 27, 'spa_start_idx': 28}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Sobre', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be38430>], 'spa_tokens': [Sobre], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["Sobre [('<*>', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be434f0>], 'spa_tokens': [a], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'reforma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdcc790>], 'spa_tokens': [reforma], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["reforma [('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'tributária', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f93454b6be0>], 'spa_tokens': [tributária], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["tributária [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bb65bb0>], 'spa_tokens': [,], 'pal_start_idx': 4, 'spa_start_idx': 4}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Maia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bddca90>], 'spa_tokens': [Maia], 'pal_start_idx': 5, 'spa_start_idx': 5}
# ["Maia [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'deu', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded6a0>], 'spa_tokens': [deu], 'pal_start_idx': 6, 'spa_start_idx': 6}
# ["deu [('<fmc>', 'WORD_SUBCLASS'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PS', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'sinais', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded190>], 'spa_tokens': [sinais], 'pal_start_idx': 7, 'spa_start_idx': 7}
# ["sinais [('<ac>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bddcc40>], 'spa_tokens': [de], 'pal_start_idx': 8, 'spa_start_idx': 8}
# ["de [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bddc8b0>], 'spa_tokens': [que], 'pal_start_idx': 9, 'spa_start_idx': 9}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('KS', 'WORD_CLASS'), ('@SUB', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'quer', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bb78070>], 'spa_tokens': [quer], 'pal_start_idx': 10, 'spa_start_idx': 10}
# ["quer [('<nosubj>', 'UNKNOWN'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-P<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'aprovar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdcc8e0>], 'spa_tokens': [aprovar], 'pal_start_idx': 11, 'spa_start_idx': 11}
# ["aprovar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be439d0>], 'spa_tokens': [o], 'pal_start_idx': 12, 'spa_start_idx': 12}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'projeto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be38d90>], 'spa_tokens': [projeto], 'pal_start_idx': 13, 'spa_start_idx': 13}
# ["projeto [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'antes', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f934549cf70>], 'spa_tokens': [antes], 'pal_start_idx': 14, 'spa_start_idx': 14}
# ["antes [('<atemp>', 'UNKNOWN'), ('ADV', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('§LOC-TMP', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bb41bb0>], 'spa_tokens': [de], 'pal_start_idx': 15, 'spa_start_idx': 15}
# ["de [('PRP', 'WORD_CLASS'), ('@A<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'deixar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde0400>], 'spa_tokens': [deixar], 'pal_start_idx': 16, 'spa_start_idx': 16}
# ["deixar [('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded9d0>], 'spa_tokens': [a], 'pal_start_idx': 17, 'spa_start_idx': 17}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'presidência', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded490>], 'spa_tokens': [presidência], 'pal_start_idx': 18, 'spa_start_idx': 18}
# ["presidência [('<pos-soc>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdedee0>, <helper_palavras.TokenVISL object at 0x7f937bdfb130>], 'spa_tokens': [da], 'pal_start_idx': 19, 'spa_start_idx': 19}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Casa', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded0d0>], 'spa_tokens': [Casa], 'pal_start_idx': 21, 'spa_start_idx': 20}
# ["Casa [('<prop>', 'WORD_SUBCLASS'), ('<*>', 'TEXT_METAINFO'), ('<build>', 'SEMANTIC'), ('<NER:site>', 'UNKNOWN'), ('<cle>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'e', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded1f0>], 'spa_tokens': [e], 'pal_start_idx': 22, 'spa_start_idx': 21}
# ["e [('<co-fin>', 'UNKNOWN'), ('<co-fmc>', 'WORD_SUBCLASS'), ('KC', 'WORD_CLASS'), ('@CO', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'acredita', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bded9a0>], 'spa_tokens': [acredita], 'pal_start_idx': 23, 'spa_start_idx': 22}
# ["acredita [('<nosubj>', 'UNKNOWN'), ('<fmc>', 'WORD_SUBCLASS'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<nosubj-safe>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-P<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bde7f70>], 'spa_tokens': [que], 'pal_start_idx': 24, 'spa_start_idx': 23}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('KS', 'WORD_CLASS'), ('@SUB', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'com', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdd4d90>], 'spa_tokens': [com], 'pal_start_idx': 25, 'spa_start_idx': 24}
# ["com [('PRP', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'acordo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bb819d0>], 'spa_tokens': [acordo], 'pal_start_idx': 26, 'spa_start_idx': 25}
# ["acordo [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§COM-ADV', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'pode', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be74af0>], 'spa_tokens': [pode], 'pal_start_idx': 27, 'spa_start_idx': 26}
# ["pode [('<aux>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-<ACC', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'fazer', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937be430d0>], 'spa_tokens': [fazer], 'pal_start_idx': 28, 'spa_start_idx': 27}
# ["fazer [('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§RES', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'isso', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937cd82d60>], 'spa_tokens': [isso], 'pal_start_idx': 29, 'spa_start_idx': 28}
# ["isso [('<dem>', 'WORD_SUBCLASS'), ('SPEC', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§RES', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'rapidamente', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bb78d30>], 'spa_tokens': [rapidamente], 'pal_start_idx': 30, 'spa_start_idx': 29}
# ["rapidamente [('<adv>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('§MNR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7f937bdfbca0>], 'spa_tokens': [.], 'pal_start_idx': 31, 'spa_start_idx': 30}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================

# %%
for token in td.sentences[0].annotated:
    print(token)
# Out:
# Defendida
# por
# agentes
# do
# mercado
# financeiro
# e
# uma
# das
# bandeiras
# da
# equipe
# econômica
# do
# governo
# Jair
# Bolsonaro
# ,
# o
# projeto
# de
# autonomia
# do
# Banco
# Central
# (
# BC
# )
# deve
# avançar
# na
# Câmara
# só
# após
# a
# reforma
# tributária
# andar
# ,
# no
# que
# depender
# do
# presidente
# da
# Casa
# ,
# Rodrigo
# Maia
# (
# DEM-RJ
# )
# .

# %%
import helper_palavras as h_pal 

tp = h_pal.parse_file_toclass("./ccscore/data/texto_exemplo_anotado.html",
                              "./ccscore/data/texto_exemplo.txt"  )

# %%
# Teste do extrator de features do pacote infernal
extrator = fe.FeatureExtractor(both=True)
extrator.get_feature_names()
# Out:
# ['Bleu T->H',
#  'Bleu H->T',
#  'Cosine TED',
#  'Cosine TED / Length T',
#  'Cosine TED / Length H',
#  'Depedency Overlap T',
#  'Depedency Overlap H',
#  'Nominalization in H',
#  'Nominalization in T',
#  'Length Ratio',
#  'Verb Structure T->H',
#  'Verb Structure H->T',
#  'Negated Verb',
#  'Quantity Match',
#  'Quantity Mismatch',
#  'Sentence Cosine',
#  'Simple TED',
#  'TED / Length T',
#  'TED / Length H',
#  'Soft Overlap T->H',
#  'Soft Overlap H->T',
#  'Overlap T',
#  'Overlap H',
#  'Synonym Overlap T',
#  'Synonym Overlap H',
#  'Non-aligned Entity T',
#  'Non-aligned Entity H',
#  'Has Aligned Entity']

# %%
from infernal.datastructures import Entailment 
s1,s2 = pares[0]

par = ds.Pair(s1,s2, 0, Entailment.none)

par
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-3994a7739490> in <module>
#       1 from infernal.datastructures import Entailment
# ----> 2 s1,s2 = pares[0]
#       3
#       4 par = ds.Pair(s1,s2, 0, Entailment.none)
#       5
#
# NameError: name 'pares' is not defined

# %%
s_ex = None
for i,s in enumerate(textdoc.sents):
    s_ex = s
    if i == 1:
        break
   # print(dir(s))
    print(type(s))

#dir(s_ex)

# %%
import helper_tools as htools
from tep2 import GrupoSinonimo

htools.dic_tep2.get_sinonimos("governo")

# %%
for i, sent in enumerate(td.sentences):
    print()
    print("ID: ", str(i))   
    print(sent.tokens_dbpedia_metions)
    print("Texto Original: ", sent.text)

# %%
import helper_tools as htools

#htools.get_dbpedia_mentions(texto)
dbpedia_mentions = []
dbpedia_mentions_entries = htools.get_dbpedia_entries(texto)
for key, entry in dbpedia_mentions_entries.items():
    if entry and key == 'raw_text':        
        dbpedia_mentions.append(entry['raw_text'].replace("'",''))

#print(dbpedia_mentions)
#print(dbpedia_mentions_entries)

print("\n\n".join(["{}: {}".format(k,v) for k,v in dbpedia_mentions_entries.items()]))

# %%
import requests
from bs4 import BeautifulSoup
import re

page = requests.get("http://pt.dbpedia.org/resource/Pleno_emprego")
soup = BeautifulSoup(page.text, 'html.parser')

a_elements = soup.find_all('a', text=re.compile(".*Categoria.*"))

def get_categorias_dbpedia(resource):
    page = requests.get("http://pt.dbpedia.org/resource/{}".format(resource))
    soup = BeautifulSoup(page.text, 'html.parser')
    a_elements = soup.find_all('a', text=re.compile(".*Categoria.*"))
    
    categorias = set([])
    for elem in a_elements:
        texto = "".join(elem.text.split())
        texto = texto.split("dbr:Categoria:")[1]
        texto = texto.replace("_", " ")
        categorias.add(texto)

    return categorias

# %%
categorias = set([])
for elem in a_elements:
    texto = "".join(elem.text.split())
    texto = texto.split("dbr:Categoria:")[1]
    texto = texto.replace("_", " ")
    categorias.add(texto)
    
categorias
# Out:
# {'Macroeconomia', 'Terminologia econômica'}

# %%
get_categorias_dbpedia("Reforma_tributária")

# %%
#print(list(dbpedia_mentions_entries.values())[5])
print(htools.get_dbpedia_entries(texto, formated=False))

# %%
# Recuperar os tokens que constituem os spans relacionados
# as menções obtidas da dbpedia spotlight

ent1 = list(dbpedia_mentions_entries.values())[0]

tk0 = None
for t in td.sentences[0].annotated:
    if  t.idx == int(ent1['pos']):
        tk0 = t


sp1 = td.sentences[0].annotated[tk0.i:tk0.i+len(ent1['raw_text'].split())]
for t in sp1:
    print(type(t))
    print(t.pos_)
    print(t.text)

# %%
from single_sentence import SingleSentence

for i,s in enumerate(td.sentences):
    if i == 1:
        break

id_sent = 1        
    
    
#for t in td.sentences[id_sent].list_fe:    
#    print(f"{t} -- {t.pos_} -- {t.dep_}")
    
#print(td.sentences[0].list_fe)    
#s_ano = td.nlp_processor(td.sentences[0].text)
#spacy.displacy.render(s_ano, style="dep", options = {"compact": True})

#print(td.sentences[1].list_fe)    
#s_ano = td.nlp_processor(td.sentences[1].text)
#spacy.displacy.render(s_ano, style="dep", options = {"compact": True})

# %%
#syns = own.find_synonyms("governo")
import helper_tools as htools


for sent in td.sentences:
    print("="*100)
    print(f"Sentenca: {sent.text}")
    print("="*100, '\n')
    
    for fe_elem in sent.list_fe:
        print(fe_elem, ":")
        try:
            print(f"WordNet: {own.find_synonyms(htools.cogroo_lemmatize(fe_elem.lower()))}")
            print(f"TeP2: {tep2.get_sinominos(htools.cogroo_lemmatize(fe_elem.lower()))}")
        except:
            print(None)
        print("-------------------------")
#own.are_synonyms("governo", "instituição")
# Out:
# ====================================================================================================
# Sentenca: Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).
# ====================================================================================================
#
# presidente :
# None
# -------------------------
# agentes :
# None
# -------------------------
# BC :
# None
# -------------------------
# projeto :
# None
# -------------------------
# reforma tributária :
# None
# -------------------------
# governo Jair Bolsonaro :
# None
# -------------------------
# que :
# None
# -------------------------
# Casa :
# None
# -------------------------
# DEM-RJ :
# None
# -------------------------
# bandeiras :
# None
# -------------------------
# Jair Bolsonaro :
# None
# -------------------------
# mercado financeiro :
# None
# -------------------------
# equipe :
# None
# -------------------------
# Câmara :
# None
# -------------------------
# Rodrigo Maia :
# None
# -------------------------
# autonomia :
# None
# -------------------------
# Banco Central :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
# ====================================================================================================
#
# projeto :
# None
# -------------------------
# ele :
# None
# -------------------------
# instituição :
# None
# -------------------------
# Roberto Campos Neto :
# None
# -------------------------
# prazo :
# None
# -------------------------
# ====================================================================================================
# Sentenca: "Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.
# ====================================================================================================
#
# ano :
# None
# -------------------------
# Banco :
# None
# -------------------------
# fim :
# None
# -------------------------
# pauta :
# None
# -------------------------
# depósitos :
# None
# -------------------------
# autonomia :
# None
# -------------------------
# ====================================================================================================
# Sentenca: É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.
# ====================================================================================================
#
# vontade :
# None
# -------------------------
# evento :
# None
# -------------------------
# Maia :
# None
# -------------------------
# governo :
# None
# -------------------------
# reforma tributária :
# None
# -------------------------
# boa :
# None
# -------------------------
# Itaú :
# None
# -------------------------
# ====================================================================================================
# Sentenca: "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
# ====================================================================================================
#
# que :
# None
# -------------------------
# importância :
# None
# -------------------------
# reforma tributária :
# None
# -------------------------
# autonomia :
# None
# -------------------------
# Banco Central :
# None
# -------------------------
# ====================================================================================================
# Sentenca: O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei.
# ====================================================================================================
#
# deputados :
# None
# -------------------------
# BC :
# None
# -------------------------
# Senado :
# None
# -------------------------
# terça-feira :
# None
# -------------------------
# projeto :
# None
# -------------------------
# aval :
# None
# -------------------------
# autonomia :
# None
# -------------------------
# lei :
# None
# -------------------------
# ====================================================================================================
# Sentenca: O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País.
# ====================================================================================================
#
# prejuízo :
# None
# -------------------------
# texto :
# None
# -------------------------
# País :
# None
# -------------------------
# pleno emprego :
# None
# -------------------------
# nível :
# None
# -------------------------
# atividade :
# None
# -------------------------
# principal :
# None
# -------------------------
# flutuações :
# None
# -------------------------
# metas :
# None
# -------------------------
# preços :
# None
# -------------------------
# objetivo :
# None
# -------------------------
# controle :
# None
# -------------------------
# ====================================================================================================
# Sentenca: O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
# ====================================================================================================
#
# proposta :
# None
# -------------------------
# escopo :
# None
# -------------------------
# redação :
# None
# -------------------------
# atuação :
# None
# -------------------------
# BC :
# None
# -------------------------
# governo :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida.
# ====================================================================================================
#
# medida :
# None
# -------------------------
# Maia :
# None
# -------------------------
# vezes :
# None
# -------------------------
# governo :
# None
# -------------------------
# se :
# None
# -------------------------
# atuação :
# None
# -------------------------
# empenho :
# None
# -------------------------
# falta :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
# ====================================================================================================
#
# decisão :
# None
# -------------------------
# conversa :
# None
# -------------------------
# ano :
# None
# -------------------------
# presidente :
# None
# -------------------------
# que :
# None
# -------------------------
# Roberto Campos Neto :
# None
# -------------------------
# Copom :
# None
# -------------------------
# dia :
# None
# -------------------------
# informações :
# None
# -------------------------
# semana :
# None
# -------------------------
# Comitê de Política Monetária :
# None
# -------------------------
# taxa :
# None
# -------------------------
# Selic :
# None
# -------------------------
# Banco Central :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal.
# ====================================================================================================
#
# presidente :
# None
# -------------------------
# jornal :
# None
# -------------------------
# Maia :
# None
# -------------------------
# Estado :
# None
# -------------------------
# votações :
# None
# -------------------------
# BC :
# None
# -------------------------
# dificuldade :
# None
# -------------------------
# articulação :
# None
# -------------------------
# economia :
# None
# -------------------------
# ajuste :
# None
# -------------------------
# pauta :
# None
# -------------------------
# Congresso :
# None
# -------------------------
# reflexos :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
# ====================================================================================================
#
# presidente :
# None
# -------------------------
# Economia :
# None
# -------------------------
# Campos Neto :
# None
# -------------------------
# Câmara :
# None
# -------------------------
# ministros :
# None
# -------------------------
# articulação :
# None
# -------------------------
# Paulo Guedes :
# None
# -------------------------
# Luiz Eduardo Ramos :
# None
# -------------------------
# papel :
# None
# -------------------------
# que :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto.
# ====================================================================================================
#
# tema :
# None
# -------------------------
# sexta-feira :
# None
# -------------------------
# BC :
# None
# -------------------------
# governo :
# None
# -------------------------
# proposta :
# None
# -------------------------
# presidente da Câmara :
# None
# -------------------------
# assunto :
# None
# -------------------------
# autonomia :
# None
# -------------------------
# que :
# None
# -------------------------
# ====================================================================================================
# Sentenca: "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura.
# ====================================================================================================
#
# te :
# None
# -------------------------
# alguém :
# None
# -------------------------
# eu :
# None
# -------------------------
# me :
# None
# -------------------------
# ninguém :
# None
# -------------------------
# governo :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Não vou conversar com a imprensa antes de conversar com o governo", disse.
# ====================================================================================================
#
# governo :
# None
# -------------------------
# imprensa :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado.
# ====================================================================================================
#
# deputados :
# None
# -------------------------
# sistema :
# None
# -------------------------
# notícias :
# None
# -------------------------
# quinta-feira :
# None
# -------------------------
# Grupo Estado :
# None
# -------------------------
# Câmara :
# None
# -------------------------
# Senado :
# None
# -------------------------
# se :
# None
# -------------------------
# projeto :
# None
# -------------------------
# tempo :
# None
# -------------------------
# Broadcast :
# None
# -------------------------
# ====================================================================================================
# Sentenca: O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
# ====================================================================================================
#
# que :
# None
# -------------------------
# exemplo :
# None
# -------------------------
# senadores :
# None
# -------------------------
# proposta :
# None
# -------------------------
# partido Novo :
# None
# -------------------------
# acessórios :
# None
# -------------------------
# aval :
# None
# -------------------------
# Banco Central :
# None
# -------------------------
# ====================================================================================================
# Sentenca: Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.
# ====================================================================================================
#
# isso :
# None
# -------------------------
# Casa :
# None
# -------------------------
# presidência :
# None
# -------------------------
# Maia :
# None
# -------------------------
# projeto :
# None
# -------------------------
# acordo :
# None
# -------------------------
# reforma tributária :
# None
# -------------------------
# sinais :
# None
# -------------------------

# %%
#print(td.sentences[0].dbpedia_mentions[0])
for i, sent in enumerate(td.sentences):
    for text_token in sent.list_fe:    
        pos_token = sent.tokens_fe_pos_tags[text_token].pos_ if text_token in sent.tokens_fe_pos_tags.keys() else None
        print(text_token, pos_token)

# %%
sent = td.sentences[0]

import itertools as itt

it_fe_pairs = itt.permutations(sent.list_fe, 2)


#print([elem_fe_pair for elem_fe_pair in it_fe_pairs])

# %%
import itertools as itt

it_fe_pairs = itt.permutations(sent.list_fe, 2)
head_elem = None
is_part_of_other = False
elems_to_exclude = set([])
for a,b in it_fe_pairs:    
    if len(a.split()) == 1:    
        if a in b:
            elems_to_exclude.add(a)
            is_part_of_other = True            
            
print(sent.list_fe,' - ', len(sent.list_fe))    
list_fe = list(set(sent.list_fe).difference(set(elems_to_exclude)))
print(list_fe,' - ', len(list_fe))

# %%
ss = td.sentences[3]

#print(dir(ss.anotated))
#ss.anotated.start

sentence_tokens = [token for token in ss.annotated]
type(sentence_tokens[0])
sentence_tokens

# %%
#!python -m spacy download en_core_web_sm

# %%
def get_sentences(text):
    doc = nlp(text)
    return (list(doc.sents)) # convert to string if required.

# %%
text = '''"É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. 
"A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou. O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei.'''

#get_sentences(text)
doc = nlp(text)
sents = [sent.text for sent in doc.sents]
print("After:", sents)
print("tamanho:", len(sents))

# %%
import split_utils as su
su.split_by_sentence(texto)

# %%
from infernal import openwordnetpt as own
own.load_wordnet("./data/own-pt.pickle")

# %%
try:
    print(own.find_synonyms("reitor"))
except:
    print(None)

# %%
from itertools import combinations 
from collections import defaultdict 

class GrupoSinonimo():
    
    def __init__(self):
        self.data = {}
        self.sinonimos = defaultdict(list)
        self.classes = defaultdict(str)
        self.idx_antonimos = defaultdict(int)
        
    def add(self, idx, dados_grupo):
        if dados_grupo:            
            self.data[idx] = dados_grupo
            self.set_sinonimos(idx)
            self.set_classes(idx)
        else:
            print("Sem dados para inserir")
    
    def get(self, idx):
        return self.data[idx]
    
    def set_sinonimos(self, idx):               
        all_sinoms = self.data[idx][1]
        
        pares_palavras = combinations(all_sinoms, 2)
        for sinonimo_left, sinonimo_right in pares_palavras:
            self.sinonimos[sinonimo_left].append(sinonimo_right)
            self.sinonimos[sinonimo_right].append(sinonimo_left)
                
    def get_sinonimos(self, palavra):
        return self.sinonimos[palavra]
    
    def set_classes(self, idx):
        all_sinoms = self.data[idx][1]
        classe = self.data[idx][0]
                
        for palavra in all_sinoms:
            #print("classe: " + classe + " " + "palavra: " + palavra)
            self.classes[palavra] = classe        
    
    def get_classe(self, palavra):
        return self.classes[palavra]
    
    def set_antonimos(self, idx):
        idx_antonimo = self.data[idx][2]
        all_sinoms = self.data[idx][1]
        
        for palavra in all_sinoms:
            self.idx_antonimos[palavra] = idx_antonimo
            
    def get_antonimos(self, palavra):
        if palavra in self.idx_antonimos.keys():
            data = self.get(self.idx_antonimos[palavra])        
            return data[1]
        else:
            return None
        
    def get_by_classe(self, classe):
        return [k for k,v in self.classes.items() if v == classe]

# %%
import pickle

tep2 = None
with open('./data/tep2.pickle', 'rb') as f:
    tep2 = pickle.load(f)
    
tep2 = tep2['objeto']

tep2.get_sinominos('governo')

# %%
from cogroo_interface import Cogroo
cogroo = Cogroo.Instance()
doc = cogroo.analyze('bandeiras')
print(f"token pos: {doc.sentences[0].tokens}")
print(f"token lemma: {cogroo.lemmatize('bandeiras')}")

print(f"token lemma: {cogroo.lemmatize('abacelara-lhe')}")

# %%
FE_POS_TAGS = {"NOUN", "PRON", "PROPN"}
POS_PLURAL = {}
tk_exemplo = None
for sent in td.sentences:
    print(f"Sentenca: {sent.text}")
    for token in sent.annotated:
        #if token.text == "agentes":
                #print(token.text, " ", token.tag_)
                                
                if tk_exemplo is None:
                    tk_exemplo = token
                if token.pos_ in FE_POS_TAGS and \
                   "Number=Plur" in token.tag_ :# and token.tag_ in POS_PLURAL:
                    print(f"Texto: {token.text}")
                    print(f"Lemma: {token.lemma_}")
                    print(f"Morph: {token.text}")
                    print(f"POS: {token.pos_}")
                    print(f"Lemma CoGroo: {cogroo.lemmatize(token.text)}")
                    print("--"*30)

#print(f"Texto: {tk_exemplo.text}")
#print(f"Lemma: {tk_exemplo.lemma_}")
#print(f"Morph: {tk_exemplo.text}")

#dir(tk_exemplo)

# %%
print("\n".join([l for l in nlp.get_pipe("tagger").labels if "Number=Plur" in l]))

# %%
from infernal import lemmatization

lemmatization.get_lemma("depósitos", "NOUN")

# %%
import random
from itertools import tee
#random.randint(10, 100)
l = [x for x in range(5)]
a,b = tee(l)
next(b)

list(zip(a,b))

# %%
sentencas = []

add_asspas = False
for s in textdoc.sents:
    if s.text == '"':
        add_asspas = True
    else:
        if add_asspas:
            sentencas.append('"'+s.text)
            add_asspas = False
        else:
            sentencas.append(s.text)
