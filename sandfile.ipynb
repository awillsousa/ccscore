# %% [markdown]
# ### Testes básicos do funcionamento do CCScore

# %%
from infernal import feature_extraction as fe
from infernal import datastructures as ds
import spacy

# %%
nlp = spacy.load('pt_core_news_lg')

# %%
# Instalações de pacotes
#!python -m spacy download pt_core_news_lg
#!python -m spacy download pt_core_news_lg
#!pip install zss rdflib
#!conda install -y scipy
#!conda install -y pandas
#!pip install python-dotenv

# %%
texto = '''Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
'''

#O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei. O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País. O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.
#Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida. Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.
#Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal. Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.
#Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto. "Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura. Não vou conversar com a imprensa antes de conversar com o governo", disse.
#Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado. O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.
#Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.'''
#'''

texto
# Out:
# 'Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ). Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.\n"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.\n'

# %% [markdown]
# Processamento básico dos textos é feito com Spacy,
# mas de forma interno às classes do ccscore

# %%
textdoc = nlp(texto)

# %%
def paragraphs(document):
    '''
    Generator to define start positions
    of paragraphs
    '''
    start = 0
    for token in document:
        if token.is_space and token.text.count("\n") > 1:
            yield document[start:token.i]
            start = token.i
    yield document[start:]

# %%
from itertools import tee

def pairwise(iterable):
    '''
    Receive an iterable and return
    an list with tuples of this elements
    is this way    
    s -> (s0,s1), (s1,s2), (s2, s3), ...
    '''
    a, b = tee(iterable)    
    next(b, None)  # next(b) it's Ok 
    return zip(a, b)

# %%
import helper_palavras as h_pal 
from text_document import TextDocument

ARQ_TEXTO = "./data/texto_exemplo.txt"
ARQ_PALAVRAS = "./data/texto_exemplo_anotado.html"
ARQ_PALAVRAS_ORIG = "./data/texto_exemplo.txt"

try:
    with open(ARQ_TEXTO, 'r') as f_text:
            orig_text = " ".join(f_text.readlines())
except IOError:
    print(f"Erro ao tentar abrir o arquivo {ARQ_TEXTO}")

tp = h_pal.parse_file_toclass(ARQ_PALAVRAS,
                              ARQ_PALAVRAS_ORIG)
                              
td = TextDocument(orig_text, tp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-814a4ff6da7a> in <module>
#       1 import helper_palavras as h_pal
# ----> 2 from text_document import TextDocument
#       3
#       4 ARQ_TEXTO = "./data/texto_exemplo.txt"
#       5 ARQ_PALAVRAS = "./data/texto_exemplo_anotado.html"
#
# ~/desenv/master/ccscore/ccscore/text_document.py in <module>
#       2 from spacy import load
#       3 import split_utils as su
# ----> 4 from single_sentence import SingleSentence
#       5 import confapp as config
#       6 from tep2 import GrupoSinonimo
#
# ~/desenv/master/ccscore/ccscore/single_sentence.py in <module>
#       2 from dependency import Dependency
#       3 from itertools import permutations
# ----> 4 import helper_tools as htools
#       5 from tep2 import GrupoSinonimo
#       6 from infernal import openwordnetpt as own
#
# ~/desenv/master/ccscore/ccscore/helper_tools.py in <module>
#      17
#      18 dic_tep2 = None
# ---> 19 with open(config.TEP2_PATH, 'rb') as f:
#      20     dic_tep2 = pickle.load(f)
#      21
#
# FileNotFoundError: [Errno 2] No such file or directory: './ccscore/data/tep2.pickle'

# %% [markdown]
# Listando:
# <ol>
#     <li>Foco Explícito (FE)</li>
#     <li>Lista intermediária do FE</li>
#     <li>Lista das Entidades Nomeadas</li>
#     <li>Menções da DBPedia</li>
# </ol>

# %%
for i, sent in enumerate(td.sentences):
    print()
    print("ID: ", str(i))    
    print("Texto Original: ", sent.text)    
    print()    
    print("Lista de Foco Explícito: ", [s for s in sent.list_fe])    
    print()
    print("Lista de Intermediária de FE: ", sent.list_fe_li)#[s for s in sent.list_fe_li])    
    print()    
    print("Lista de Entidades Nomeadas: ", sent.named_entities)    
    print()
    print("Lista de Menções DBPedia: ", str(sent.dbpedia_mentions))    
    
    print("-"*100)
    
#s_disp = td.nlp_processor(td.sentences[4].text)
#spacy.displacy.render(s_disp, style="dep", options = {"compact": True})
# Out:
# ID:  0
# Texto Original:  Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).
#
# Lista de Foco Explícito:  ['casa', 'agentes', 'jair bolsonaro', 'bc', 'equipe', 'mercado financeiro', 'governo jair bolsonaro', 'banco central', 'câmara', 'bandeiras', 'presidente', 'projeto', 'que', 'rodrigo maia', 'reforma tributária', 'dem-rj', 'autonomia']
#
# Lista de Intermediária de FE:  {'casa': {'botoeira', 'residência', 'habitação', 'teto', 'quartel', 'lar', 'moradia', 'tabernáculo', 'estabelecimento', 'domicílio', 'empresa', 'aselha', 'morada', 'vivenda'}, 'agente': {'detective', 'motor', 'polícia', 'pivô', 'impulsor', 'delegado', 'autor', 'policial', 'detetive', 'fator', 'propulsor', 'promotor', 'causador', 'investigador', 'causa'}, 'jair bolsonaro': set(), 'equipe': {'time', 'grupo', 'conjunto'}, 'governo jair bolsonaro': set(), 'banco central': set(), 'câmara': {'compartimento', 'quarto', 'assembléia', 'apartamento', 'repartimento', 'aposento', 'recâmara', 'alcova'}, 'bandeira': {'emblema', 'partido', 'signa', 'fação', 'lábaro', 'facção', 'estandarte', 'pendão', 'pavilhão'}, 'presidente': {'presidência'}, 'projeto': {'esquema', 'traçado', 'planta', 'desenho', 'plano'}, 'que': {'quão'}, 'rodrigo Maia': set(), 'autonomia': {'emancipação', 'desprendimento', 'independência', 'auto-suficiência', 'liberdade'}}
#
# Lista de Entidades Nomeadas:  [Jair Bolsonaro, Banco Central, BC, Câmara, Casa, Rodrigo Maia, DEM-RJ]
#
# Lista de Menções DBPedia:  ['mercado financeiro', 'governo Jair Bolsonaro', 'Banco Central', 'reforma tributária', 'Rodrigo Maia']
# ----------------------------------------------------------------------------------------------------
#
# ID:  1
# Texto Original:  Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.
#
# Lista de Foco Explícito:  ['prazo', 'ele', 'roberto campos neto', 'projeto', 'instituição']
#
# Lista de Intermediária de FE:  {'prazo': {'tempo', 'termo', 'dilação'}, 'ele': set(), 'roberto campo neto': set(), 'projeto': {'esquema', 'traçado', 'planta', 'desenho', 'plano'}, 'instituição': {'convenção', 'instituto', 'firma', 'advento', 'código', 'fundação', 'entidade', 'estabelecimento', 'associação', 'empresa', 'sociedade'}}
#
# Lista de Entidades Nomeadas:  [Roberto Campos Neto]
#
# Lista de Menções DBPedia:  ['Roberto Campos Neto']
# ----------------------------------------------------------------------------------------------------
#
# ID:  2
# Texto Original:  "Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.
#
# Lista de Foco Explícito:  ['pauta', 'fim', 'ano', 'autonomia', 'depósitos', 'banco']
#
# Lista de Intermediária de FE:  {'pauta': set(), 'fim': {'escopo', 'solução', 'fundo', 'acabamento', 'motivo', 'desenredo', 'extremidade', 'mira', 'destinação', 'ponto', 'objetivo', 'extinção', 'sina', 'morte', 'intuito', 'fito', 'ômega', 'finamento', 'resultado', 'desfecho', 'exterminação', 'finalidade', 'término', 'meta', 'final', 'intenção', 'perecimento', 'destino', 'extermínio', 'postimária', 'desenlace', 'intento', 'objeto', 'termo', 'conclusão', 'destruição', 'propósito', 'sorte', 'cabo', 'alvo', 'extremo', 'terminação', 'limite'}, 'ano': set(), 'autonomia': {'emancipação', 'desprendimento', 'independência', 'auto-suficiência', 'liberdade'}, 'depósito': {'represa', 'tanque', 'reservatório', 'alojamento', 'estoque', 'repositório', 'armazém', 'almoxarifado', 'arrecadação', 'custódia'}}
#
# Lista de Entidades Nomeadas:  [Banco]
#
# Lista de Menções DBPedia:  []
# ----------------------------------------------------------------------------------------------------
#
# ID:  3
# Texto Original:  É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.
#
# Lista de Foco Explícito:  ['vontade', 'governo', 'evento', 'boa', 'maia', 'reforma tributária', 'itaú']
#
# Lista de Intermediária de FE:  {'vontade': {'querença', 'talante', 'apetite', 'intenção', 'bel-prazer', 'fantasia', 'desejo', 'veleidade', 'querer', 'apetência', 'capricho', 'afã', 'intento', 'arbítrio', 'afano', 'desígnio', 'ânsia', 'interesse', 'disposição', 'deliberação', 'entusiasmo', 'pretensão', 'determinação'}, 'governo': {'regimento', 'orientação', 'direção', 'domínio', 'regência', 'regímen', 'governança', 'regime', 'norteamento', 'controle', 'norteio', 'estado', 'administração', 'governação'}, 'evento': {'acaso', 'acidente', 'eventualidade', 'caso', 'acontecimento', 'ocorrência', 'episódio', 'fato', 'vicissitude', 'contingência'}}
#
# Lista de Entidades Nomeadas:  [Maia, Itaú]
#
# Lista de Menções DBPedia:  ['boa', 'reforma tributária', 'Itaú']
# ----------------------------------------------------------------------------------------------------
#
# ID:  4
# Texto Original:  "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.
#
# Lista de Foco Explícito:  ['"', 'banco central', 'importância', 'que', 'reforma tributária', 'autonomia']
#
# Lista de Intermediária de FE:  {'banco central': set(), 'importância': {'valor', 'apreço', 'merecimento', 'proporções', 'monta', 'gravidade', 'profundura', 'polpa', 'valia', 'significatividade', 'alcance', 'profundez', 'relevância', 'consideração', 'significado', 'valimento', 'cifra', 'porte', 'peso', 'altura', 'profundeza', 'preço', 'soma', 'conseqüência', 'dimensão', 'intensidade', 'respeito', 'proporção', 'montante', 'profundidade'}, 'que': {'quão'}, 'autonomia': {'emancipação', 'desprendimento', 'independência', 'auto-suficiência', 'liberdade'}}
#
# Lista de Entidades Nomeadas:  [Banco Central]
#
# Lista de Menções DBPedia:  ['reforma tributária', 'Banco Central']
# ----------------------------------------------------------------------------------------------------

# %%
import helper_palavras as h_pal 
from text_document import TextDocument

ARQ_TEXTO = "./data/texto_exemplo.txt"
ARQ_PALAVRAS = "./data/texto_exemplo_anotado.html"
ARQ_PALAVRAS_ORIG = "./data/texto_exemplo.txt"

try:
    with open(ARQ_TEXTO, 'r') as f_text:
            orig_text = " ".join(f_text.readlines())
except IOError:
    print(f"Erro ao tentar abrir o arquivo {ARQ_TEXTO}")

# %%
tp = h_pal.parse_file_toclass(ARQ_PALAVRAS,
                              ARQ_PALAVRAS_ORIG)
td = TextDocument(orig_text, tp)

# %%
t_doc = '"Aceito a oferta." disse ele'
doc = td.nlp_processor(t_doc)

for t in doc:
    print(t)
# Out:
# "
# Aceito
# a
# oferta
# .
# "
# disse
# ele

# %%
#print(td.sentences[1].text)
#print(td.sentences[2].text)
#print(td.sentences[3].text)
#print(td.sentences[4].text)
#print(td.sentences[5].text)
import split_utils as su
t_doc = '''"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano. É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. "A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.'''
su.split_by_sentence(t_doc)
# Out:
# ['"Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.',
#  'É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.',
#  '"A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.']

# %%
#for s in td.sentences:
#    for t_sp, t_pal in zip(s.annotated, s.palavras_sentence):
#        print(t_sp.text, t_sp.pos_, t_pal.text)

from collections import defaultdict

aligned_sentences = defaultdict()
for idx_sentence, s in enumerate(td.sentences):

    aligned_pal_tokens = defaultdict()
    #aligned_spa_tokens = defaultdict()
    idx_token = 0
    pal_idx_token = 0
    spa_idx_token = 0
    pal_token_text = ""
    spa_token_text = ""
    pal_tokens_list = []
    spa_tokens_list = []
    it_t_spa = iter(s.annotated)
    for t_pal in s.palavras_sentence:   
        
        # tokens that has composition, stay together    
        if any("<sam->" in tag for tag,_ in t_pal.tags):
            pal_token_text += t_pal.text+" + " 
            pal_tokens_list.append(t_pal)    
            continue
        else:
            # first token from palavras
            pal_token_text += t_pal.text
            pal_tokens_list.append(t_pal)

        # first token from spacy
        token_spa = next(it_t_spa)
        spa_token_text += token_spa.text
        spa_tokens_list.append(token_spa)

        # tokens of proper names are grouped in palavras but,
        # in spacy not
        #if any(" " in tag for tag,_ in t_pal.tags):
        if " " in t_pal.text:
            for _ in range(len(t_pal.text.split(' '))-1):
                token_spa = next(it_t_spa)
                spa_token_text += " "+token_spa.text
                spa_tokens_list.append(token_spa)

        aligned_pal_tokens[idx_token] = {'text': pal_token_text,
                                        'pal_tokens': pal_tokens_list,
                                        'spa_tokens': spa_tokens_list,
                                        'pal_start_idx': pal_idx_token,
                                        'spa_start_idx': spa_idx_token
                                        }

        print(pal_token_text, " <-> ", spa_token_text)
        idx_token += 1
        pal_idx_token += len(pal_tokens_list)
        spa_idx_token += len(spa_tokens_list)
        pal_token_text = ""
        spa_token_text = ""
        pal_tokens_list = []
        spa_tokens_list = []

    aligned_sentences[idx_sentence] = aligned_pal_tokens
    #aligned_pal_tokens
# Out:
# Defendida  <->  Defendida
# por  <->  por
# agentes  <->  agentes
# de + o  <->  do
# mercado  <->  mercado
# financeiro  <->  financeiro
# e  <->  e
# uma  <->  uma
# de + as  <->  das
# bandeiras  <->  bandeiras
# de + a  <->  da
# equipe  <->  equipe
# econômica  <->  econômica
# de + o  <->  do
# governo  <->  governo
# Jair Bolsonaro  <->  Jair Bolsonaro
# ,  <->  ,
# o  <->  o
# projeto  <->  projeto
# de  <->  de
# autonomia  <->  autonomia
# de + o  <->  do
# Banco Central  <->  Banco Central
# (  <->  (
# BC  <->  BC
# )  <->  )
# deve  <->  deve
# avançar  <->  avançar
# em + a  <->  na
# Câmara  <->  Câmara
# só  <->  só
# após  <->  após
# a  <->  a
# reforma  <->  reforma
# tributária  <->  tributária
# andar  <->  andar
# ,  <->  ,
# em + o  <->  no
# que  <->  que
# depender  <->  depender
# de + o  <->  do
# presidente  <->  presidente
# de + a  <->  da
# Casa  <->  Casa
# ,  <->  ,
# Rodrigo Maia  <->  Rodrigo Maia
# (  <->  (
# DEM-RJ  <->  DEM-RJ
# )  <->  )
# .  <->  .
# Para  <->  Para
# ele  <->  ele
# ,  <->  ,
# o  <->  o
# projeto  <->  projeto
# sobre  <->  sobre
# a  <->  a
# instituição  <->  instituição
# presidida  <->  presidida
# por  <->  por
# Roberto Campos Neto  <->  Roberto Campos Neto
# não  <->  não
# é  <->  é
# urgente  <->  urgente
# em + o  <->  no
# curto  <->  curto
# prazo  <->  prazo
# .  <->  .
# "  <->  "
# Aceito  <->  Aceito
# votar  <->  votar
# autonomia  <->  autonomia
# de + o  <->  do
# Banco  <->  Banco
# ,  <->  ,
# aceito  <->  aceito
# ,  <->  ,
# é  <->  é
# claro  <->  claro
# ,  <->  ,
# votar  <->  votar
# os  <->  os
# depósitos  <->  depósitos
# voluntários  <->  voluntários
# ,  <->  ,
# mas  <->  mas
# aí  <->  aí
# temos  <->  temos
# que  <->  que
# organizar  <->  organizar
# melhor  <->  melhor
# a  <->  a
# pauta  <->  pauta
# até  <->  até
# o  <->  o
# fim  <->  fim
# de + o  <->  do
# ano  <->  ano
# .  <->  .
# É  <->  É
# só  <->  só
# o  <->  o
# governo  <->  governo
# ter  <->  ter
# boa vontade  <->  boa vontade
# em + a  <->  na
# reforma  <->  reforma
# tributária  <->  tributária
# "  <->  "
# ,  <->  ,
# disse  <->  disse
# Maia  <->  Maia
# ,  <->  ,
# a + o  <->  ao
# participar  <->  participar
# de  <->  de
# evento  <->  evento
# organizado  <->  organizado
# por + o  <->  pelo
# Itaú  <->  Itaú
# .  <->  .
# "  <->  "
# A  <->  A
# reforma  <->  reforma
# tributária  <->  tributária
# tem  <->  tem
# importância  <->  importância
# muito  <->  muito
# maior  <->  maior
# que  <->  que
# autonomia  <->  autonomia
# de + o  <->  do
# Banco Central  <->  Banco Central
# "  <->  "
# ,  <->  ,
# comentou  <->  comentou
# .  <->  .
# O  <->  O
# projeto  <->  projeto
# de  <->  de
# autonomia  <->  autonomia
# de + o  <->  do
# BC  <->  BC
# foi  <->  foi
# aprovado  <->  aprovado
# em + a  <->  na
# terça-feira  <->  terça-feira
# ,  <->  ,
# 3  <->  3
# ,  <->  ,
# por + o  <->  pelo
# Senado  <->  Senado
# e  <->  e
# agora  <->  agora
# precisa  <->  precisa
# de + o  <->  do
# aval  <->  aval
# de + os  <->  dos
# deputados  <->  deputados
# para  <->  para
# virar  <->  virar
# lei  <->  lei
# .  <->  .
# O  <->  O
# texto  <->  texto
# mantém  <->  mantém
# o  <->  o
# controle  <->  controle
# de + os  <->  dos
# preços  <->  preços
# como  <->  como
# objetivo  <->  objetivo
# central  <->  central
# ,  <->  ,
# mas  <->  mas
# inclui  <->  inclui
# ainda  <->  ainda
# duas  <->  duas
# novas  <->  novas
# metas  <->  metas
# acessórias  <->  acessórias
# ,  <->  ,
# sem  <->  sem
# prejuízo  <->  prejuízo
# a + a  <->  à
# principal  <->  principal
# :  <->  :
# suavizar  <->  suavizar
# as  <->  as
# flutuações  <->  flutuações
# de + o  <->  do
# nível  <->  nível
# de  <->  de
# atividade  <->  atividade
# econômica  <->  econômica
# e  <->  e
# fomentar  <->  fomentar
# o  <->  o
# pleno  <->  pleno
# emprego  <->  emprego
# em + o  <->  no
# País  <->  País
# .  <->  .
# O  <->  O
# governo  <->  governo
# concordou  <->  concordou
# com  <->  com
# a  <->  a
# redação  <->  redação
# de + a  <->  da
# proposta  <->  proposta
# ,  <->  ,
# apesar de  <->  apesar de
# o  <->  o
# BC  <->  BC
# ser  <->  ser
# historicamente  <->  historicamente
# contrário  <->  contrário
# a  <->  a
# ampliar  <->  ampliar
# o  <->  o
# escopo  <->  escopo
# de + a  <->  da
# atuação  <->  atuação
# .  <->  .
# Maia  <->  Maia
# já  <->  já
# reclamou  <->  reclamou
# outras  <->  outras
# vezes  <->  vezes
# de + a  <->  da
# falta  <->  falta
# de  <->  de
# empenho  <->  empenho
# e  <->  e
# atuação  <->  atuação
# de + o  <->  do
# governo  <->  governo
# para  <->  para
# se  <->  se
# aprovar  <->  aprovar
# a  <->  a
# medida  <->  medida
# .  <->  .
# Em + a  <->  Na
# semana  <->  semana
# passada  <->  passada
# ,  <->  ,
# acusou  <->  acusou
# o  <->  o
# presidente  <->  presidente
# de + o  <->  do
# Banco Central  <->  Banco Central
# ,  <->  ,
# Roberto Campos Neto  <->  Roberto Campos Neto
# ,  <->  ,
# de  <->  de
# ter  <->  ter
# vazado  <->  vazado
# informações  <->  informações
# sobre  <->  sobre
# conversa  <->  conversa
# que  <->  que
# os  <->  os
# dois  <->  dois
# tiveram  <->  tiveram
# em + o  <->  no
# dia  <->  dia
# de + a  <->  da
# decisão  <->  decisão
# de + o  <->  do
# Comitê de Política Monetária  <->  Comitê de Política Monetária
# (  <->  (
# Copom  <->  Copom
# )  <->  )
# ,  <->  ,
# que  <->  que
# manteve  <->  manteve
# a  <->  a
# taxa  <->  taxa
# Selic  <->  Selic
# em  <->  em
# 2  <->  2
# %  <->  %
# a + o  <->  ao
# ano  <->  ano
# .  <->  .
# A + o  <->  Ao
# jornal  <->  jornal
# O Estado de S. Paulo  <->  O Estado de S. Paulo
# ,  <->  ,
# Maia  <->  Maia
# criticou  <->  criticou
# a  <->  a
# articulação  <->  articulação
# de + o  <->  do
# presidente  <->  presidente
# de + o  <->  do
# BC  <->  BC
# em  <->  em
# alertar  <->  alertar
# sobre  <->  sobre
# os  <->  os
# reflexos  <->  reflexos
# para  <->  para
# a  <->  a
# economia  <->  economia
# de + a  <->  da
# dificuldade  <->  dificuldade
# de + o  <->  do
# Congresso  <->  Congresso
# em  <->  em
# avançar  <->  avançar
# com  <->  com
# as  <->  as
# votações  <->  votações
# de + a  <->  da
# pauta  <->  pauta
# de  <->  de
# ajuste  <->  ajuste
# fiscal  <->  fiscal
# .  <->  .
# Segundo  <->  Segundo
# o  <->  o
# presidente  <->  presidente
# de + a  <->  da
# Câmara  <->  Câmara
# ,  <->  ,
# Campos Neto  <->  Campos Neto
# tentou  <->  tentou
# fazer  <->  fazer
# uma  <->  uma
# articulação  <->  articulação
# política  <->  política
# ,  <->  ,
# sem  <->  sem
# combinar  <->  combinar
# ,  <->  ,
# o que  <->  o que
# não  <->  não
# seria  <->  seria
# papel  <->  papel
# de + ele  <->  dele
# ,  <->  ,
# mas  <->  mas
# de + os  <->  dos
# ministros  <->  ministros
# de + a  <->  da
# Economia  <->  Economia
# ,  <->  ,
# Paulo Guedes  <->  Paulo Guedes
# ,  <->  ,
# e  <->  e
# de + a  <->  da
# articulação  <->  articulação
# política  <->  política
# ,  <->  ,
# Luiz Eduardo Ramos  <->  Luiz Eduardo Ramos
# .  <->  .
# Em + esta  <->  Nesta
# sexta-feira  <->  sexta-feira
# ,  <->  ,
# o  <->  o
# presidente  <->  presidente
# de + a  <->  da
# Câmara  <->  Câmara
# lembrou  <->  lembrou
# que  <->  que
# havia  <->  havia
# uma  <->  uma
# proposta  <->  proposta
# de  <->  de
# autonomia  <->  autonomia
# de + o  <->  do
# BC  <->  BC
# semelhante  <->  semelhante
# em + a  <->  na
# Câmara  <->  Câmara
# ,  <->  ,
# mas  <->  mas
# que  <->  que
# não  <->  não
# foi  <->  foi
# votada  <->  votada
# ,  <->  ,
# e  <->  e
# disse  <->  disse
# que  <->  que
# não  <->  não
# comentou  <->  comentou
# até  <->  até
# agora  <->  agora
# sobre  <->  sobre
# o  <->  o
# tema  <->  tema
# porque  <->  porque
# não  <->  não
# foi  <->  foi
# procurado  <->  procurado
# por + o  <->  pelo
# governo  <->  governo
# para  <->  para
# falar  <->  falar
# sobre  <->  sobre
# o  <->  o
# assunto  <->  assunto
# .  <->  .
# "  <->  "
# Se  <->  Se
# eu  <->  eu
# conseguisse  <->  conseguisse
# conversar  <->  conversar
# com  <->  com
# alguém  <->  alguém
# de + o  <->  do
# governo  <->  governo
# ,  <->  ,
# eu  <->  eu
# poderia  <->  poderia
# te  <->  te
# responder  <->  responder
# ,  <->  ,
# mas  <->  mas
# ninguém  <->  ninguém
# me  <->  me
# procura  <->  procura
# .  <->  .
# Não  <->  Não
# vou  <->  vou
# conversar  <->  conversar
# com  <->  com
# a  <->  a
# imprensa  <->  imprensa
# antes  <->  antes
# de  <->  de
# conversar  <->  conversar
# com  <->  com
# o  <->  o
# governo  <->  governo
# "  <->  "
# ,  <->  ,
# disse  <->  disse
# .  <->  .
# Como  <->  Como
# o  <->  o
# Broadcast  <->  Broadcast
# (  <->  (
# sistema  <->  sistema
# de  <->  de
# notícias  <->  notícias
# em  <->  em
# tempo  <->  tempo
# real  <->  real
# de + o  <->  do
# Grupo Estado  <->  Grupo Estado
# )  <->  )
# mostrou  <->  mostrou
# em + a  <->  na
# quinta-feira  <->  quinta-feira
# ,  <->  ,
# deputados  <->  deputados
# já  <->  já
# se  <->  se
# articulam  <->  articulam
# em + a  <->  na
# Câmara  <->  Câmara
# para  <->  para
# modificar  <->  modificar
# o  <->  o
# projeto  <->  projeto
# aprovado  <->  aprovado
# por + o  <->  pelo
# Senado  <->  Senado
# .  <->  .
# O  <->  O
# partido  <->  partido
# Novo  <->  Novo
# ,  <->  ,
# por exemplo  <->  por exemplo
# ,  <->  ,
# quer  <->  quer
# enxugar  <->  enxugar
# a  <->  a
# proposta  <->  proposta
# que  <->  que
# recebeu  <->  recebeu
# aval  <->  aval
# de + os  <->  dos
# senadores  <->  senadores
# para  <->  para
# reduzir  <->  reduzir
# os  <->  os
# chamados  <->  chamados
# acessórios  <->  acessórios
# que  <->  que
# foram  <->  foram
# colocados  <->  colocados
# para  <->  para
# o  <->  o
# Banco Central  <->  Banco Central
# .  <->  .
# Sobre  <->  Sobre
# a  <->  a
# reforma  <->  reforma
# tributária  <->  tributária
# ,  <->  ,
# Maia  <->  Maia
# deu  <->  deu
# sinais  <->  sinais
# de  <->  de
# que  <->  que
# quer  <->  quer
# aprovar  <->  aprovar
# o  <->  o
# projeto  <->  projeto
# antes  <->  antes
# de  <->  de
# deixar  <->  deixar
# a  <->  a
# presidência  <->  presidência
# de + a  <->  da
# Casa  <->  Casa
# e  <->  e
# acredita  <->  acredita
# que  <->  que
# com  <->  com
# acordo  <->  acordo
# pode  <->  pode
# fazer  <->  fazer
# isso  <->  isso
# rapidamente  <->  rapidamente
# .  <->  .

# %%
for s in aligned_sentences.values():
    for apt in s.values():
        print(apt)
        print([str(x) for x in apt['pal_tokens']])
        print(f"{'='*100}\n")
# Out:
# {'text': 'Defendida', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc501481f0>], 'spa_tokens': [Defendida], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["Defendida [('<*>', 'TEXT_METAINFO'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@ICL-PRED>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'por', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbea2e0>], 'spa_tokens': [por], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["por [('PRP', 'WORD_CLASS'), ('@<PASS', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'agentes', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf1a90>], 'spa_tokens': [agentes], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["agentes [('<Hprof>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf9ac0>, <helper_palavras.TokenVISL object at 0x7fcc1fbe5d00>], 'spa_tokens': [do], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["de [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<PIV', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'mercado', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5760>], 'spa_tokens': [mercado], 'pal_start_idx': 5, 'spa_start_idx': 4}
# ["mercado [('<inst>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'financeiro', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe50d0>], 'spa_tokens': [financeiro], 'pal_start_idx': 6, 'spa_start_idx': 5}
# ["financeiro [('<nh>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'e', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbdabb0>], 'spa_tokens': [e], 'pal_start_idx': 7, 'spa_start_idx': 6}
# ["e [('KC', 'WORD_CLASS'), ('@CO', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'uma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5160>], 'spa_tokens': [uma], 'pal_start_idx': 8, 'spa_start_idx': 7}
# ["uma [('<card>', 'WORD_SUBCLASS'), ('NUM', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + as', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5190>, <helper_palavras.TokenVISL object at 0x7fcc1fbe5970>], 'spa_tokens': [das], 'pal_start_idx': 9, 'spa_start_idx': 8}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "as [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('P', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'bandeiras', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf9850>], 'spa_tokens': [bandeiras], 'pal_start_idx': 11, 'spa_start_idx': 9}
# ["bandeiras [('<cc-rag>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('P', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf1e50>, <helper_palavras.TokenVISL object at 0x7fcc1fb7ed30>], 'spa_tokens': [da], 'pal_start_idx': 12, 'spa_start_idx': 10}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'equipe', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbeadc0>], 'spa_tokens': [equipe], 'pal_start_idx': 14, 'spa_start_idx': 11}
# ["equipe [('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§POS', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'econômica', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbdadf0>], 'spa_tokens': [econômica], 'pal_start_idx': 15, 'spa_start_idx': 12}
# ["econômica [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbda2e0>, <helper_palavras.TokenVISL object at 0x7fcc1fbd1f10>], 'spa_tokens': [do], 'pal_start_idx': 16, 'spa_start_idx': 13}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'governo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1b80>], 'spa_tokens': [governo], 'pal_start_idx': 18, 'spa_start_idx': 14}
# ["governo [('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Jair Bolsonaro', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd16d0>], 'spa_tokens': [Jair, Bolsonaro], 'pal_start_idx': 19, 'spa_start_idx': 15}
# ["Jair Bolsonaro [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1340>], 'spa_tokens': [,], 'pal_start_idx': 20, 'spa_start_idx': 17}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd10a0>], 'spa_tokens': [o], 'pal_start_idx': 21, 'spa_start_idx': 18}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'projeto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbcacd0>], 'spa_tokens': [projeto], 'pal_start_idx': 22, 'spa_start_idx': 19}
# ["projeto [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1310>], 'spa_tokens': [de], 'pal_start_idx': 23, 'spa_start_idx': 20}
# ["de [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'autonomia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1700>], 'spa_tokens': [autonomia], 'pal_start_idx': 24, 'spa_start_idx': 21}
# ["autonomia [('<state>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1a00>, <helper_palavras.TokenVISL object at 0x7fcc1fbd1e80>], 'spa_tokens': [do], 'pal_start_idx': 25, 'spa_start_idx': 22}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Banco Central', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbda220>], 'spa_tokens': [Banco, Central], 'pal_start_idx': 27, 'spa_start_idx': 23}
# ["Banco Central [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': '(', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbda4c0>], 'spa_tokens': [(], 'pal_start_idx': 28, 'spa_start_idx': 25}
# ["( [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'BC', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc22e0dd60>], 'spa_tokens': [BC], 'pal_start_idx': 29, 'spa_start_idx': 26}
# ["BC [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@APP', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ')', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbeaa60>], 'spa_tokens': [)], 'pal_start_idx': 30, 'spa_start_idx': 27}
# [") [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'deve', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf1a00>], 'spa_tokens': [deve], 'pal_start_idx': 31, 'spa_start_idx': 28}
# ["deve [('<fmc>', 'WORD_SUBCLASS'), ('<aux>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'avançar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf9640>], 'spa_tokens': [avançar], 'pal_start_idx': 32, 'spa_start_idx': 29}
# ["avançar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5a30>, <helper_palavras.TokenVISL object at 0x7fcc1fbe54f0>], 'spa_tokens': [na], 'pal_start_idx': 33, 'spa_start_idx': 30}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Câmara', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbcaf40>], 'spa_tokens': [Câmara], 'pal_start_idx': 35, 'spa_start_idx': 31}
# ["Câmara [('<prop>', 'WORD_SUBCLASS'), ('<*>', 'TEXT_METAINFO'), ('<HH>', 'SEMANTIC'), ('<NER:org>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'só', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbca3a0>], 'spa_tokens': [só], 'pal_start_idx': 36, 'spa_start_idx': 32}
# ["só [('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@>P', 'SYNTATIC'), ('§FOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'após', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbca700>], 'spa_tokens': [após], 'pal_start_idx': 37, 'spa_start_idx': 33}
# ["após [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbca5e0>], 'spa_tokens': [a], 'pal_start_idx': 38, 'spa_start_idx': 34}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'reforma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbcaf10>], 'spa_tokens': [reforma], 'pal_start_idx': 39, 'spa_start_idx': 35}
# ["reforma [('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§ADV', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'tributária', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe58b0>], 'spa_tokens': [tributária], 'pal_start_idx': 40, 'spa_start_idx': 36}
# ["tributária [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'andar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf9f10>], 'spa_tokens': [andar], 'pal_start_idx': 41, 'spa_start_idx': 37}
# ["andar [('<vK>', 'VERBAL_VALENCY'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-UTT', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf1490>], 'spa_tokens': [,], 'pal_start_idx': 42, 'spa_start_idx': 38}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbea3a0>, <helper_palavras.TokenVISL object at 0x7fcc1fbda490>], 'spa_tokens': [no], 'pal_start_idx': 43, 'spa_start_idx': 39}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbda3a0>], 'spa_tokens': [que], 'pal_start_idx': 45, 'spa_start_idx': 40}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('<rel>', 'WORD_SUBCLASS'), ('SPEC', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'depender', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1d00>], 'spa_tokens': [depender], 'pal_start_idx': 46, 'spa_start_idx': 41}
# ["depender [('<mv>', 'VERBAL_VALENCY'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('FUT', 'INFLEXION'), ('3S', 'INFLEXION'), ('SUBJ', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-N<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd19d0>, <helper_palavras.TokenVISL object at 0x7fcc1fbd1610>], 'spa_tokens': [do], 'pal_start_idx': 47, 'spa_start_idx': 42}
# ["de [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<PIV', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'presidente', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc29a0>], 'spa_tokens': [presidente], 'pal_start_idx': 49, 'spa_start_idx': 43}
# ["presidente [('<Hprof>', 'SEMANTIC'), ('<NER:official>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§CAU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc25e0>, <helper_palavras.TokenVISL object at 0x7fcc1fbc2070>], 'spa_tokens': [da], 'pal_start_idx': 50, 'spa_start_idx': 44}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<NER2:official>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('<NER2:official>', 'UNKNOWN'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Casa', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc2340>], 'spa_tokens': [Casa], 'pal_start_idx': 52, 'spa_start_idx': 45}
# ["Casa [('<prop>', 'WORD_SUBCLASS'), ('<NER2:official>', 'UNKNOWN'), ('<*>', 'TEXT_METAINFO'), ('<build>', 'SEMANTIC'), ('<NER:site>', 'UNKNOWN'), ('<cle>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc2670>], 'spa_tokens': [,], 'pal_start_idx': 53, 'spa_start_idx': 46}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Rodrigo Maia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc2880>], 'spa_tokens': [Rodrigo, Maia], 'pal_start_idx': 54, 'spa_start_idx': 47}
# ["Rodrigo Maia [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<np-long>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('@APP', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '(', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd14c0>], 'spa_tokens': [(], 'pal_start_idx': 55, 'spa_start_idx': 49}
# ["( [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'DEM-RJ', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd18e0>], 'spa_tokens': [DEM-RJ], 'pal_start_idx': 56, 'spa_start_idx': 50}
# ["DEM-RJ [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('<heur>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@APP', 'SYNTATIC'), ('§ID', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ')', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1e50>], 'spa_tokens': [)], 'pal_start_idx': 57, 'spa_start_idx': 51}
# [") [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbda0d0>], 'spa_tokens': [.], 'pal_start_idx': 58, 'spa_start_idx': 52}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Para', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbea460>], 'spa_tokens': [Defendida], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["Para [('<*>', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'ele', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf15b0>], 'spa_tokens': [por], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["ele [('PERS', 'WORD_CLASS'), ('M', 'INFLEXION'), ('3S', 'INFLEXION'), ('NOM/PIV', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§FIN', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf9520>], 'spa_tokens': [agentes], 'pal_start_idx': 2, 'spa_start_idx': 2}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5f40>], 'spa_tokens': [do], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'projeto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbcadc0>], 'spa_tokens': [mercado], 'pal_start_idx': 4, 'spa_start_idx': 4}
# ["projeto [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'sobre', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b8e0>], 'spa_tokens': [financeiro], 'pal_start_idx': 5, 'spa_start_idx': 5}
# ["sobre [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b2e0>], 'spa_tokens': [e], 'pal_start_idx': 6, 'spa_start_idx': 6}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'instituição', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36cd0>], 'spa_tokens': [uma], 'pal_start_idx': 7, 'spa_start_idx': 7}
# ["instituição [('<inst>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'presidida', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b520>], 'spa_tokens': [das], 'pal_start_idx': 8, 'spa_start_idx': 8}
# ["presidida [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('PAS', 'UNKNOWN'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@ICL-N<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'por', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b640>], 'spa_tokens': [bandeiras], 'pal_start_idx': 9, 'spa_start_idx': 9}
# ["por [('PRP', 'WORD_CLASS'), ('@<PASS', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Roberto Campos Neto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbca4f0>], 'spa_tokens': [da, equipe, econômica], 'pal_start_idx': 10, 'spa_start_idx': 10}
# ["Roberto Campos Neto [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'não', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5b50>], 'spa_tokens': [do], 'pal_start_idx': 11, 'spa_start_idx': 13}
# ["não [('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC'), ('§FOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'é', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf9970>], 'spa_tokens': [governo], 'pal_start_idx': 12, 'spa_start_idx': 14}
# ["é [('<fmc>', 'WORD_SUBCLASS'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'urgente', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fb7e5e0>], 'spa_tokens': [Jair], 'pal_start_idx': 13, 'spa_start_idx': 15}
# ["urgente [('<nh>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbda4f0>, <helper_palavras.TokenVISL object at 0x7fcc1fbda070>], 'spa_tokens': [Bolsonaro], 'pal_start_idx': 14, 'spa_start_idx': 16}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'curto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1a90>], 'spa_tokens': [,], 'pal_start_idx': 16, 'spa_start_idx': 17}
# ["curto [('<nh>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'prazo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1400>], 'spa_tokens': [o], 'pal_start_idx': 17, 'spa_start_idx': 18}
# ["prazo [('<per>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC-TMP', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc29d0>], 'spa_tokens': [projeto], 'pal_start_idx': 18, 'spa_start_idx': 19}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '"', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36490>], 'spa_tokens': [Defendida], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ['" []']
# ====================================================================================================
#
# {'text': 'Aceito', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31fa0>], 'spa_tokens': [por], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["Aceito [('<*>', 'TEXT_METAINFO'), ('<*1>', 'TEXT_METAINFO'), ('<jh>', 'SEMANTIC'), ('<vH>', 'SEMANTIC'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@PRED>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'votar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc319d0>], 'spa_tokens': [agentes], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["votar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('@ICL-UTT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'autonomia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36670>], 'spa_tokens': [do], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["autonomia [('<state>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36fd0>, <helper_palavras.TokenVISL object at 0x7fcc1fbc2af0>], 'spa_tokens': [mercado], 'pal_start_idx': 4, 'spa_start_idx': 4}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Banco', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1430>], 'spa_tokens': [financeiro], 'pal_start_idx': 6, 'spa_start_idx': 5}
# ["Banco [('<prop>', 'WORD_SUBCLASS'), ('<*>', 'TEXT_METAINFO'), ('<inst>', 'SEMANTIC'), ('<NER:org>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1cd0>], 'spa_tokens': [e], 'pal_start_idx': 7, 'spa_start_idx': 6}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'aceito', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbdad00>], 'spa_tokens': [uma], 'pal_start_idx': 8, 'spa_start_idx': 7}
# ["aceito [('<jh>', 'SEMANTIC'), ('<vH>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<PRED', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbea6a0>], 'spa_tokens': [das], 'pal_start_idx': 9, 'spa_start_idx': 8}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'é', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf19a0>], 'spa_tokens': [bandeiras], 'pal_start_idx': 10, 'spa_start_idx': 9}
# ["é [('<fmc>', 'WORD_SUBCLASS'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'claro', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5a90>], 'spa_tokens': [da], 'pal_start_idx': 11, 'spa_start_idx': 10}
# ["claro [('<nh>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe55b0>], 'spa_tokens': [equipe], 'pal_start_idx': 12, 'spa_start_idx': 11}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'votar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbca490>], 'spa_tokens': [econômica], 'pal_start_idx': 13, 'spa_start_idx': 12}
# ["votar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<SUBJ', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'os', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31dc0>], 'spa_tokens': [do], 'pal_start_idx': 14, 'spa_start_idx': 13}
# ["os [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'depósitos', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31070>], 'spa_tokens': [governo], 'pal_start_idx': 15, 'spa_start_idx': 14}
# ["depósitos [('<mon>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§EXT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'voluntários', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc2c8e0>], 'spa_tokens': [Jair], 'pal_start_idx': 16, 'spa_start_idx': 15}
# ["voluntários [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc2c190>], 'spa_tokens': [Bolsonaro], 'pal_start_idx': 17, 'spa_start_idx': 16}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'mas', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc2c6a0>], 'spa_tokens': [,], 'pal_start_idx': 18, 'spa_start_idx': 17}
# ["mas [('<clb>', 'UNKNOWN'), ('KC', 'WORD_CLASS'), ('@CO', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'aí', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc2cf40>], 'spa_tokens': [o], 'pal_start_idx': 19, 'spa_start_idx': 18}
# ["aí [('<kc>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC'), ('§MNR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'temos', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31af0>], 'spa_tokens': [projeto], 'pal_start_idx': 20, 'spa_start_idx': 19}
# ["temos [('<nosubj>', 'UNKNOWN'), ('<fmc>', 'WORD_SUBCLASS'), ('<aux>', 'UNKNOWN'), ('<nosubj-safe>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('1P', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b790>], 'spa_tokens': [de], 'pal_start_idx': 21, 'spa_start_idx': 20}
# ["que [('KS', 'WORD_CLASS'), ('@PRT-AUX<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'organizar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5490>], 'spa_tokens': [autonomia], 'pal_start_idx': 22, 'spa_start_idx': 21}
# ["organizar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'melhor', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbe5cd0>], 'spa_tokens': [do], 'pal_start_idx': 23, 'spa_start_idx': 22}
# ["melhor [('<KOMP>', 'UNKNOWN'), ('<SUP>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('§MNR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fb7ebb0>], 'spa_tokens': [Banco], 'pal_start_idx': 24, 'spa_start_idx': 23}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'pauta', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbdacd0>], 'spa_tokens': [Central], 'pal_start_idx': 25, 'spa_start_idx': 24}
# ["pauta [('<cc-r>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'até', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1df0>], 'spa_tokens': [(], 'pal_start_idx': 26, 'spa_start_idx': 25}
# ["até [('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbd1520>], 'spa_tokens': [BC], 'pal_start_idx': 27, 'spa_start_idx': 26}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'fim', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc27c0>], 'spa_tokens': [)], 'pal_start_idx': 28, 'spa_start_idx': 27}
# ["fim [('<temp>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC-TMP', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc27ac0>, <helper_palavras.TokenVISL object at 0x7fcc1fc27310>], 'spa_tokens': [deve], 'pal_start_idx': 29, 'spa_start_idx': 28}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'ano', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc21c10>], 'spa_tokens': [avançar], 'pal_start_idx': 31, 'spa_start_idx': 29}
# ["ano [('<temp>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbea4c0>], 'spa_tokens': [na], 'pal_start_idx': 32, 'spa_start_idx': 30}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'É', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbf1880>], 'spa_tokens': [Defendida], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["É [('<clb-fs>', 'UNKNOWN'), ('<*>', 'TEXT_METAINFO'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('<quote>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-ACC>>', 'SYNTATIC'), ('§RES', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'só', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc27430>], 'spa_tokens': [por], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["só [('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@>N', 'SYNTATIC'), ('§FOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc27b80>], 'spa_tokens': [agentes], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'governo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc2cee0>], 'spa_tokens': [do], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["governo [('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'ter', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc2c460>], 'spa_tokens': [mercado], 'pal_start_idx': 4, 'spa_start_idx': 4}
# ["ter [('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<SUBJ', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'boa vontade', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31e80>], 'spa_tokens': [financeiro, e], 'pal_start_idx': 5, 'spa_start_idx': 5}
# ["boa vontade [('<f-psych>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'em + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31850>, <helper_palavras.TokenVISL object at 0x7fcc1fc363d0>], 'spa_tokens': [uma], 'pal_start_idx': 6, 'spa_start_idx': 7}
# ["em [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'reforma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36a00>], 'spa_tokens': [das], 'pal_start_idx': 8, 'spa_start_idx': 8}
# ["reforma [('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'tributária', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b130>], 'spa_tokens': [bandeiras], 'pal_start_idx': 9, 'spa_start_idx': 9}
# ["tributária [('<*2>', 'TEXT_METAINFO'), ('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': '"', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3bdf0>], 'spa_tokens': [da], 'pal_start_idx': 10, 'spa_start_idx': 10}
# ['" []']
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc26d0>], 'spa_tokens': [equipe], 'pal_start_idx': 11, 'spa_start_idx': 11}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'disse', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc2a30>], 'spa_tokens': [econômica], 'pal_start_idx': 12, 'spa_start_idx': 12}
# ["disse [('<fmc>', 'WORD_SUBCLASS'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<v-quote>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PS', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Maia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc2c70>], 'spa_tokens': [do], 'pal_start_idx': 13, 'spa_start_idx': 13}
# ["Maia [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SUBJ', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc24f0>], 'spa_tokens': [governo], 'pal_start_idx': 14, 'spa_start_idx': 14}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'a + o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbc23a0>, <helper_palavras.TokenVISL object at 0x7fcc1fbc27f0>], 'spa_tokens': [Jair], 'pal_start_idx': 15, 'spa_start_idx': 15}
# ["a [('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]", "o [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'participar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc3b880>], 'spa_tokens': [Bolsonaro], 'pal_start_idx': 17, 'spa_start_idx': 16}
# ["participar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36af0>], 'spa_tokens': [,], 'pal_start_idx': 18, 'spa_start_idx': 17}
# ["de [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'evento', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc36d30>], 'spa_tokens': [o], 'pal_start_idx': 19, 'spa_start_idx': 18}
# ["evento [('<event>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'organizado', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc31880>], 'spa_tokens': [projeto], 'pal_start_idx': 20, 'spa_start_idx': 19}
# ["organizado [('<nh>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# ...
# ====================================================================================================
#
# {'text': 'chamados', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcab340>], 'spa_tokens': [projeto], 'pal_start_idx': 19, 'spa_start_idx': 19}
# ["chamados [('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'acessórios', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcab5e0>], 'spa_tokens': [de], 'pal_start_idx': 20, 'spa_start_idx': 20}
# ["acessórios [('<n>', 'WORD_SUBCLASS'), ('<jh>', 'SEMANTIC'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcabac0>], 'spa_tokens': [autonomia], 'pal_start_idx': 21, 'spa_start_idx': 21}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('<rel>', 'WORD_SUBCLASS'), ('SPEC', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'foram', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcabc40>], 'spa_tokens': [do], 'pal_start_idx': 22, 'spa_start_idx': 22}
# ["foram [('<aux>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PS/MQP', 'UNKNOWN'), ('3P', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'colocados', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbcae80>], 'spa_tokens': [Banco], 'pal_start_idx': 23, 'spa_start_idx': 23}
# ["colocados [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PCP', 'INFLEXION'), ('PAS', 'UNKNOWN'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'para', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc75e20>], 'spa_tokens': [Central], 'pal_start_idx': 24, 'spa_start_idx': 24}
# ["para [('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcb9a00>], 'spa_tokens': [(], 'pal_start_idx': 25, 'spa_start_idx': 25}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Banco Central', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc41d30>], 'spa_tokens': [BC, )], 'pal_start_idx': 26, 'spa_start_idx': 26}
# ["Banco Central [('<org>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§FIN', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc41250>], 'spa_tokens': [deve], 'pal_start_idx': 27, 'spa_start_idx': 28}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Sobre', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc21220>], 'spa_tokens': [Defendida], 'pal_start_idx': 0, 'spa_start_idx': 0}
# ["Sobre [('<*>', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc12bb0>], 'spa_tokens': [por], 'pal_start_idx': 1, 'spa_start_idx': 1}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'reforma', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fca59a0>], 'spa_tokens': [agentes], 'pal_start_idx': 2, 'spa_start_idx': 2}
# ["reforma [('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'tributária', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fca5430>], 'spa_tokens': [do], 'pal_start_idx': 3, 'spa_start_idx': 3}
# ["tributária [('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': ',', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc9ee80>], 'spa_tokens': [mercado], 'pal_start_idx': 4, 'spa_start_idx': 4}
# [", [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'Maia', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fca51f0>], 'spa_tokens': [financeiro], 'pal_start_idx': 5, 'spa_start_idx': 5}
# ["Maia [('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@SUBJ>', 'SYNTATIC'), ('§AG', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'deu', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fca55b0>], 'spa_tokens': [e], 'pal_start_idx': 6, 'spa_start_idx': 6}
# ["deu [('<fmc>', 'WORD_SUBCLASS'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PS', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'sinais', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fca5ac0>], 'spa_tokens': [uma], 'pal_start_idx': 7, 'spa_start_idx': 7}
# ["sinais [('<ac>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('P', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§TH', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc17d60>], 'spa_tokens': [das], 'pal_start_idx': 8, 'spa_start_idx': 8}
# ["de [('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc4b190>], 'spa_tokens': [bandeiras], 'pal_start_idx': 9, 'spa_start_idx': 9}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('KS', 'WORD_CLASS'), ('@SUB', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'quer', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc41730>], 'spa_tokens': [da], 'pal_start_idx': 10, 'spa_start_idx': 10}
# ["quer [('<nosubj>', 'UNKNOWN'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-P<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'aprovar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcb9a90>], 'spa_tokens': [equipe], 'pal_start_idx': 11, 'spa_start_idx': 11}
# ["aprovar [('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'o', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbfe730>], 'spa_tokens': [econômica], 'pal_start_idx': 12, 'spa_start_idx': 12}
# ["o [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'projeto', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc5ca90>], 'spa_tokens': [do], 'pal_start_idx': 13, 'spa_start_idx': 13}
# ["projeto [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'antes', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc0e250>], 'spa_tokens': [governo], 'pal_start_idx': 14, 'spa_start_idx': 14}
# ["antes [('<atemp>', 'UNKNOWN'), ('ADV', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('§LOC-TMP', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcaba00>], 'spa_tokens': [Jair], 'pal_start_idx': 15, 'spa_start_idx': 15}
# ["de [('PRP', 'WORD_CLASS'), ('@A<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'deixar', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc9e430>], 'spa_tokens': [Bolsonaro], 'pal_start_idx': 16, 'spa_start_idx': 16}
# ["deixar [('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc98d00>], 'spa_tokens': [,], 'pal_start_idx': 17, 'spa_start_idx': 17}
# ["a [('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'presidência', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc9e610>], 'spa_tokens': [o], 'pal_start_idx': 18, 'spa_start_idx': 18}
# ["presidência [('<pos-soc>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§PAT', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'de + a', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc9e850>, <helper_palavras.TokenVISL object at 0x7fcc1fcabbb0>], 'spa_tokens': [projeto], 'pal_start_idx': 19, 'spa_start_idx': 19}
# ["de [('<sam->', 'TEXT_METAINFO'), ('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')]", "a [('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'Casa', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fbca7c0>], 'spa_tokens': [de], 'pal_start_idx': 21, 'spa_start_idx': 20}
# ["Casa [('<prop>', 'WORD_SUBCLASS'), ('<*>', 'TEXT_METAINFO'), ('<build>', 'SEMANTIC'), ('<NER:site>', 'UNKNOWN'), ('<cle>', 'UNKNOWN'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'e', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc75a60>], 'spa_tokens': [autonomia], 'pal_start_idx': 22, 'spa_start_idx': 21}
# ["e [('<co-fin>', 'UNKNOWN'), ('<co-fmc>', 'WORD_SUBCLASS'), ('KC', 'WORD_CLASS'), ('@CO', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'acredita', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fcb9e80>], 'spa_tokens': [do], 'pal_start_idx': 23, 'spa_start_idx': 22}
# ["acredita [('<nosubj>', 'UNKNOWN'), ('<fmc>', 'WORD_SUBCLASS'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<nosubj-safe>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-P<', 'SYNTATIC'), ('§ATR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'que', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc41cd0>], 'spa_tokens': [Banco], 'pal_start_idx': 24, 'spa_start_idx': 23}
# ["que [('<clb>', 'UNKNOWN'), ('<clb-fs>', 'UNKNOWN'), ('KS', 'WORD_CLASS'), ('@SUB', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'com', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc65d30>], 'spa_tokens': [Central], 'pal_start_idx': 25, 'spa_start_idx': 24}
# ["com [('PRP', 'WORD_CLASS'), ('@ADVL>', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'acordo', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc12f10>], 'spa_tokens': [(], 'pal_start_idx': 26, 'spa_start_idx': 25}
# ["acordo [('<sem-c>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§COM-ADV', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'pode', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fca57c0>], 'spa_tokens': [BC], 'pal_start_idx': 27, 'spa_start_idx': 26}
# ["pode [('<aux>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-<ACC', 'SYNTATIC')]"]
# ====================================================================================================
#
# {'text': 'fazer', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc98760>], 'spa_tokens': [)], 'pal_start_idx': 28, 'spa_start_idx': 27}
# ["fazer [('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-AUX<', 'SYNTATIC'), ('§RES', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'isso', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc98310>], 'spa_tokens': [deve], 'pal_start_idx': 29, 'spa_start_idx': 28}
# ["isso [('<dem>', 'WORD_SUBCLASS'), ('SPEC', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§RES', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': 'rapidamente', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc91e50>], 'spa_tokens': [avançar], 'pal_start_idx': 30, 'spa_start_idx': 29}
# ["rapidamente [('<adv>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC'), ('§MNR', 'UNKNOWN')]"]
# ====================================================================================================
#
# {'text': '.', 'pal_tokens': [<helper_palavras.TokenVISL object at 0x7fcc1fc98550>], 'spa_tokens': [na], 'pal_start_idx': 31, 'spa_start_idx': 30}
# [". [('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')]"]
# ====================================================================================================

# %%
for token in td.sentences[0].annotated:
    print(token.)
# Out:
# Defendida
# por
# agentes
# do
# mercado
# financeiro
# e
# uma
# das
# bandeiras
# da
# equipe
# econômica
# do
# governo
# Jair
# Bolsonaro
# ,
# o
# projeto
# de
# autonomia
# do
# Banco
# Central
# (
# BC
# )
# deve
# avançar
# na
# Câmara
# só
# após
# a
# reforma
# tributária
# andar
# ,
# no
# que
# depender
# do
# presidente
# da
# Casa
# ,
# Rodrigo
# Maia
# (
# DEM-RJ
# )
# .

# %%
from palavras_dic_tags import *

d = SEMANTIC_TAGSET

# %%
import split_utils as su
orig_sentences = []
try:
    with open("./data/texto_exemplo.txt", 'r') as f_text:
        orig_sentences = su.split_by_sentence("\n".join(f_text.readlines()))
except IOError:
    print(f"Erro ao tentar abrir o arquivo {original_text}")
orig_sentences
# Out:
# ['Defendida por agentes do mercado financeiro e uma das bandeiras da equipe econômica do governo Jair Bolsonaro, o projeto de autonomia do Banco Central (BC) deve avançar na Câmara só após a reforma tributária andar, no que depender do presidente da Casa, Rodrigo Maia (DEM-RJ).',
#  'Para ele, o projeto sobre a instituição presidida por Roberto Campos Neto não é urgente no curto prazo.',
#  'Aceito votar autonomia do Banco, aceito, é claro, votar os depósitos voluntários, mas aí temos que organizar melhor a pauta até o fim do ano.',
#  'É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú.',
#  '"A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou.',
#  'O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei.',
#  'O texto mantém o controle dos preços como objetivo central, mas inclui ainda duas novas metas acessórias, sem prejuízo à principal: suavizar as flutuações do nível de atividade econômica e fomentar o pleno emprego no País.',
#  'O governo concordou com a redação da proposta, apesar de o BC ser historicamente contrário a ampliar o escopo da atuação.',
#  'Maia já reclamou outras vezes da falta de empenho e atuação do governo para se aprovar a medida.',
#  'Na semana passada, acusou o presidente do Banco Central, Roberto Campos Neto, de ter vazado informações sobre conversa que os dois tiveram no dia da decisão do Comitê de Política Monetária (Copom), que manteve a taxa Selic em 2% ao ano.',
#  'Ao jornal O Estado de S. Paulo, Maia criticou a articulação do presidente do BC em alertar sobre os reflexos para a economia da dificuldade do Congresso em avançar com as votações da pauta de ajuste fiscal.',
#  'Segundo o presidente da Câmara, Campos Neto tentou fazer uma articulação política, sem combinar, o que não seria papel dele, mas dos ministros da Economia, Paulo Guedes, e da articulação política, Luiz Eduardo Ramos.',
#  'Nesta sexta-feira, o presidente da Câmara lembrou que havia uma proposta de autonomia do BC semelhante na Câmara, mas que não foi votada, e disse que não comentou até agora sobre o tema porque não foi procurado pelo governo para falar sobre o assunto.',
#  '"Se eu conseguisse conversar com alguém do governo, eu poderia te responder, mas ninguém me procura.',
#  'Não vou conversar com a imprensa antes de conversar com o governo", disse.',
#  'Como o Broadcast (sistema de notícias em tempo real do Grupo Estado) mostrou na quinta-feira, deputados já se articulam na Câmara para modificar o projeto aprovado pelo Senado.',
#  'O partido Novo, por exemplo, quer enxugar a proposta que recebeu aval dos senadores para reduzir os chamados acessórios que foram colocados para o Banco Central.',
#  'Sobre a reforma tributária, Maia deu sinais de que quer aprovar o projeto antes de deixar a presidência da Casa e acredita que com acordo pode fazer isso rapidamente.']

# %%
import helper_palavras as h_pal 

tp = h_pal.parse_file_toclass("./data/texto_exemplo_anotado.html",
                              "./data/texto_exemplo.txt"  )
# Out:
# ["É\n([('<clb-fs>', 'UNKNOWN'), ('<*>', 'TEXT_METAINFO'), ('<vK>', 'VERBAL_VALENCY'), ('<mv>', 'VERBAL_VALENCY'), ('<quote>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PR', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-ACC>>', 'SYNTATIC'), ('§RES', 'UNKNOWN')], '#1->13')", "só\n([('<setop>', 'WORD_SUBCLASS'), ('ADV', 'WORD_CLASS'), ('@>N', 'SYNTATIC'), ('§FOC', 'UNKNOWN')], '#2->4')", "o\n([('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')], '#3->4')", "governo\n([('<HH>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SC', 'SYNTATIC'), ('§ATR', 'UNKNOWN')], '#4->1')", "ter\n([('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-<SUBJ', 'SYNTATIC')], '#5->1')", "boa vontade\n([('<f-psych>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<ACC', 'SYNTATIC'), ('§TH', 'UNKNOWN')], '#6->5')", "em\n([('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')], '#7->5')", "a\n([('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')], '#8->9')", "reforma\n([('<activity>', 'SEMANTIC'), ('<act-d>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC'), ('§LOC', 'UNKNOWN')], '#9->7')", "tributária\n([('<*2>', 'TEXT_METAINFO'), ('<jh>', 'SEMANTIC'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('F', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')], '#10->9')", '"\n([], \'\')', ",\n([('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')], '#12->0')", "disse\n([('<fmc>', 'WORD_SUBCLASS'), ('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<v-quote>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('PS', 'INFLEXION'), ('3S', 'INFLEXION'), ('IND', 'INFLEXION'), ('VFIN', 'INFLEXION'), ('@FS-STA', 'UNKNOWN'), ('§PRED', 'UNKNOWN')], '#13->0')", "Maia\n([('<hum>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M/F', 'INFLEXION'), ('S', 'INFLEXION'), ('@<SUBJ', 'SYNTATIC'), ('§AG', 'UNKNOWN')], '#14->13')", ",\n([('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')], '#15->0')", "a\n([('<sam->', 'TEXT_METAINFO'), ('PRP', 'WORD_CLASS'), ('@<ADVL', 'SYNTATIC')], '#16->13')", "o\n([('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')], '#17->18')", "participar\n([('<vH>', 'SEMANTIC'), ('<mv>', 'VERBAL_VALENCY'), ('<uninfl>', 'UNKNOWN'), ('V', 'WORD_CLASS'), ('INF', 'INFLEXION'), ('3S', 'INFLEXION'), ('@ICL-P<', 'SYNTATIC')], '#18->16')", "de\n([('<np-close>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')], '#19->14')", "evento\n([('<event>', 'SEMANTIC'), ('N', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')], '#20->19')", "organizado\n([('<nh>', 'UNKNOWN'), ('<np-close>', 'UNKNOWN'), ('ADJ', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@N<', 'SYNTATIC')], '#21->20')", "por\n([('<sam->', 'TEXT_METAINFO'), ('<np-long>', 'UNKNOWN'), ('PRP', 'WORD_CLASS'), ('@N<', 'SYNTATIC')], '#22->20')", "o\n([('<-sam>', 'TEXT_METAINFO'), ('<artd>', 'WORD_SUBCLASS'), ('DET', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@>N', 'SYNTATIC')], '#23->24')", "Itaú\n([('<civ>', 'SEMANTIC'), ('<*>', 'TEXT_METAINFO'), ('PROP', 'WORD_CLASS'), ('M', 'INFLEXION'), ('S', 'INFLEXION'), ('@P<', 'SYNTATIC')], '#24->22')", ".\n([('PU', 'UNKNOWN'), ('@PU', 'UNKNOWN')], '#25->0')"]

# %%
# Teste do extrator de features do pacote infernal
extrator = fe.FeatureExtractor(both=True)
extrator.get_feature_names()

# %%
from infernal.datastructures import Entailment 
s1,s2 = pares[0]


par = ds.Pair(s1,s2, 0, Entailment.none)

par

# %%
s_ex = None
for i,s in enumerate(textdoc.sents):
    s_ex = s
    if i == 1:
        break
   # print(dir(s))
    print(type(s))

#dir(s_ex)

# %%
import helper_tools as htools
from tep2 import GrupoSinonimo

htools.dic_tep2.get_sinonimos("governo")

# %%
for i, sent in enumerate(td.sentences):
    print()
    print("ID: ", str(i))   
    print(sent.tokens_dbpedia_metions)
    print("Texto Original: ", sent.text)

# %%
import helper_tools as htools

#htools.get_dbpedia_mentions(texto)
dbpedia_mentions = []
dbpedia_mentions_entries = htools.get_dbpedia_entries(texto)
for key, entry in dbpedia_mentions_entries.items():
    if entry and key == 'raw_text':        
        dbpedia_mentions.append(entry['raw_text'].replace("'",''))

#print(dbpedia_mentions)
#print(dbpedia_mentions_entries)

print("\n\n".join(["{}: {}".format(k,v) for k,v in dbpedia_mentions_entries.items()]))

# %%
import requests
from bs4 import BeautifulSoup
import re

page = requests.get("http://pt.dbpedia.org/resource/Pleno_emprego")
soup = BeautifulSoup(page.text, 'html.parser')

a_elements = soup.find_all('a', text=re.compile(".*Categoria.*"))

def get_categorias_dbpedia(resource):
    page = requests.get("http://pt.dbpedia.org/resource/{}".format(resource))
    soup = BeautifulSoup(page.text, 'html.parser')
    a_elements = soup.find_all('a', text=re.compile(".*Categoria.*"))
    
    categorias = set([])
    for elem in a_elements:
        texto = "".join(elem.text.split())
        texto = texto.split("dbr:Categoria:")[1]
        texto = texto.replace("_", " ")
        categorias.add(texto)

    return categorias

# %%
categorias = set([])
for elem in a_elements:
    texto = "".join(elem.text.split())
    texto = texto.split("dbr:Categoria:")[1]
    texto = texto.replace("_", " ")
    categorias.add(texto)
    
categorias

# %%
get_categorias_dbpedia("Reforma_tributária")

# %%
#print(list(dbpedia_mentions_entries.values())[5])
print(htools.get_dbpedia_entries(texto, formated=False))

# %%
# Recuperar os tokens que constituem os spans relacionados
# as menções obtidas da dbpedia spotlight

ent1 = list(dbpedia_mentions_entries.values())[0]

tk0 = None
for t in td.sentences[0].annotated:
    if  t.idx == int(ent1['pos']):
        tk0 = t


sp1 = td.sentences[0].annotated[tk0.i:tk0.i+len(ent1['raw_text'].split())]
for t in sp1:
    print(type(t))
    print(t.pos_)
    print(t.text)

# %%
from single_sentence import SingleSentence

for i,s in enumerate(td.sentences):
    if i == 1:
        break

id_sent = 1        
    
    
#for t in td.sentences[id_sent].list_fe:    
#    print(f"{t} -- {t.pos_} -- {t.dep_}")
    
#print(td.sentences[0].list_fe)    
#s_ano = td.nlp_processor(td.sentences[0].text)
#spacy.displacy.render(s_ano, style="dep", options = {"compact": True})

#print(td.sentences[1].list_fe)    
#s_ano = td.nlp_processor(td.sentences[1].text)
#spacy.displacy.render(s_ano, style="dep", options = {"compact": True})

# %%
#syns = own.find_synonyms("governo")
import helper_tools as htools


for sent in td.sentences:
    print("="*100)
    print(f"Sentenca: {sent.text}")
    print("="*100, '\n')
    
    for fe_elem in sent.list_fe:
        print(fe_elem, ":")
        try:
            print(f"WordNet: {own.find_synonyms(htools.cogroo_lemmatize(fe_elem.lower()))}")
            print(f"TeP2: {tep2.get_sinominos(htools.cogroo_lemmatize(fe_elem.lower()))}")
        except:
            print(None)
        print("-------------------------")
#own.are_synonyms("governo", "instituição")

# %%
#print(td.sentences[0].dbpedia_mentions[0])
for i, sent in enumerate(td.sentences):
    for text_token in sent.list_fe:    
        pos_token = sent.tokens_fe_pos_tags[text_token].pos_ if text_token in sent.tokens_fe_pos_tags.keys() else None
        print(text_token, pos_token)

# %%
sent = td.sentences[0]

import itertools as itt

it_fe_pairs = itt.permutations(sent.list_fe, 2)


#print([elem_fe_pair for elem_fe_pair in it_fe_pairs])

# %%
import itertools as itt

it_fe_pairs = itt.permutations(sent.list_fe, 2)
head_elem = None
is_part_of_other = False
elems_to_exclude = set([])
for a,b in it_fe_pairs:    
    if len(a.split()) == 1:    
        if a in b:
            elems_to_exclude.add(a)
            is_part_of_other = True            
            
print(sent.list_fe,' - ', len(sent.list_fe))    
list_fe = list(set(sent.list_fe).difference(set(elems_to_exclude)))
print(list_fe,' - ', len(list_fe))

# %%
ss = td.sentences[3]

#print(dir(ss.anotated))
#ss.anotated.start

sentence_tokens = [token for token in ss.annotated]
type(sentence_tokens[0])
sentence_tokens

# %%
#!python -m spacy download en_core_web_sm

# %%
def get_sentences(text):
    doc = nlp(text)
    return (list(doc.sents)) # convert to string if required.

# %%
text = '''"É só o governo ter boa vontade na reforma tributária", disse Maia, ao participar de evento organizado pelo Itaú. 
"A reforma tributária tem importância muito maior que autonomia do Banco Central", comentou. O projeto de autonomia do BC foi aprovado na terça-feira, 3, pelo Senado e agora precisa do aval dos deputados para virar lei.'''

#get_sentences(text)
doc = nlp(text)
sents = [sent.text for sent in doc.sents]
print("After:", sents)
print("tamanho:", len(sents))

# %%
import split_utils as su
su.split_by_sentence(texto)

# %%
from infernal import openwordnetpt as own
own.load_wordnet("./data/own-pt.pickle")

# %%
try:
    print(own.find_synonyms("reitor"))
except:
    print(None)

# %%
from itertools import combinations 
from collections import defaultdict 

class GrupoSinonimo():
    
    def __init__(self):
        self.data = {}
        self.sinonimos = defaultdict(list)
        self.classes = defaultdict(str)
        self.idx_antonimos = defaultdict(int)
        
    def add(self, idx, dados_grupo):
        if dados_grupo:            
            self.data[idx] = dados_grupo
            self.set_sinonimos(idx)
            self.set_classes(idx)
        else:
            print("Sem dados para inserir")
    
    def get(self, idx):
        return self.data[idx]
    
    def set_sinonimos(self, idx):               
        all_sinoms = self.data[idx][1]
        
        pares_palavras = combinations(all_sinoms, 2)
        for sinonimo_left, sinonimo_right in pares_palavras:
            self.sinonimos[sinonimo_left].append(sinonimo_right)
            self.sinonimos[sinonimo_right].append(sinonimo_left)
                
    def get_sinonimos(self, palavra):
        return self.sinonimos[palavra]
    
    def set_classes(self, idx):
        all_sinoms = self.data[idx][1]
        classe = self.data[idx][0]
                
        for palavra in all_sinoms:
            #print("classe: " + classe + " " + "palavra: " + palavra)
            self.classes[palavra] = classe        
    
    def get_classe(self, palavra):
        return self.classes[palavra]
    
    def set_antonimos(self, idx):
        idx_antonimo = self.data[idx][2]
        all_sinoms = self.data[idx][1]
        
        for palavra in all_sinoms:
            self.idx_antonimos[palavra] = idx_antonimo
            
    def get_antonimos(self, palavra):
        if palavra in self.idx_antonimos.keys():
            data = self.get(self.idx_antonimos[palavra])        
            return data[1]
        else:
            return None
        
    def get_by_classe(self, classe):
        return [k for k,v in self.classes.items() if v == classe]

# %%
import pickle

tep2 = None
with open('./data/tep2.pickle', 'rb') as f:
    tep2 = pickle.load(f)
    
tep2 = tep2['objeto']

tep2.get_sinominos('governo')

# %%
from cogroo_interface import Cogroo
cogroo = Cogroo.Instance()
doc = cogroo.analyze('bandeiras')
print(f"token pos: {doc.sentences[0].tokens}")
print(f"token lemma: {cogroo.lemmatize('bandeiras')}")

print(f"token lemma: {cogroo.lemmatize('abacelara-lhe')}")

# %%
FE_POS_TAGS = {"NOUN", "PRON", "PROPN"}
POS_PLURAL = {}
tk_exemplo = None
for sent in td.sentences:
    print(f"Sentenca: {sent.text}")
    for token in sent.annotated:
        #if token.text == "agentes":
                #print(token.text, " ", token.tag_)
                                
                if tk_exemplo is None:
                    tk_exemplo = token
                if token.pos_ in FE_POS_TAGS and \
                   "Number=Plur" in token.tag_ :# and token.tag_ in POS_PLURAL:
                    print(f"Texto: {token.text}")
                    print(f"Lemma: {token.lemma_}")
                    print(f"Morph: {token.text}")
                    print(f"POS: {token.pos_}")
                    print(f"Lemma CoGroo: {cogroo.lemmatize(token.text)}")
                    print("--"*30)

#print(f"Texto: {tk_exemplo.text}")
#print(f"Lemma: {tk_exemplo.lemma_}")
#print(f"Morph: {tk_exemplo.text}")

#dir(tk_exemplo)

# %%
print("\n".join([l for l in nlp.get_pipe("tagger").labels if "Number=Plur" in l]))

# %%
from infernal import lemmatization

lemmatization.get_lemma("depósitos", "NOUN")

# %%
import random
from itertools import tee
#random.randint(10, 100)
l = [x for x in range(5)]
a,b = tee(l)
next(b)

list(zip(a,b))

# %%
sentencas = []

add_asspas = False
for s in textdoc.sents:
    if s.text == '"':
        add_asspas = True
    else:
        if add_asspas:
            sentencas.append('"'+s.text)
            add_asspas = False
        else:
            sentencas.append(s.text)
